# %%
from flask import Flask, render_template, redirect, jsonify

import requests
import json
import pandas as pd

import pymongo

import nba_api
from nba_api.stats.static import players, teams
from nba_api.stats.endpoints import shotchartdetail, commonplayerinfo, commonallplayers

from resources import mongo_user, mongo_pass, mongo_clusteruri

# %%
#mongo db initialization/test
conn = (f'mongodb+srv://{mongo_user}:{mongo_pass}@{mongo_clusteruri}')
client = pymongo.MongoClient(conn)

db = client.nba_db
collection = db.nba_reddit.find()

# %%
source = db.active_players.find()
destination = db.active_players_copy

# %%
for document in source:
    destination.replace_one(document, document, True)

# %%
player = 2738

# allshots = shotchartdetail.ShotChartDetail(player_id=player, season_nullable='2018-19').get_dict()

playerinfo = commonplayerinfo.CommonPlayerInfo(player_id=player).get_dict()

# %%
playerinfo['resultSets']
# Out:
# [{'name': 'CommonPlayerInfo',
#   'headers': ['PERSON_ID',
#    'FIRST_NAME',
#    'LAST_NAME',
#    'DISPLAY_FIRST_LAST',
#    'DISPLAY_LAST_COMMA_FIRST',
#    'DISPLAY_FI_LAST',
#    'BIRTHDATE',
#    'SCHOOL',
#    'COUNTRY',
#    'LAST_AFFILIATION',
#    'HEIGHT',
#    'WEIGHT',
#    'SEASON_EXP',
#    'JERSEY',
#    'POSITION',
#    'ROSTERSTATUS',
#    'TEAM_ID',
#    'TEAM_NAME',
#    'TEAM_ABBREVIATION',
#    'TEAM_CODE',
#    'TEAM_CITY',
#    'PLAYERCODE',
#    'FROM_YEAR',
#    'TO_YEAR',
#    'DLEAGUE_FLAG',
#    'NBA_FLAG',
#    'GAMES_PLAYED_FLAG',
#    'DRAFT_YEAR',
#    'DRAFT_ROUND',
#    'DRAFT_NUMBER'],
#   'rowSet': [[2738,
#     'Andre',
#     'Iguodala',
#     'Andre Iguodala',
#     'Iguodala, Andre',
#     'A. Iguodala',
#     '1984-01-28T00:00:00',
#     'Arizona',
#     'USA',
#     'Arizona/USA',
#     '6-6',
#     '215',
#     15,
#     '9',
#     'Guard-Forward',
#     'Active',
#     1610612763,
#     'Grizzlies',
#     'MEM',
#     'grizzlies',
#     'Memphis',
#     'andre_iguodala',
#     2004,
#     2019,
#     'N',
#     'Y',
#     'Y',
#     '2004',
#     '1',
#     '9']]},
#  {'name': 'PlayerHeadlineStats',
#   'headers': ['PLAYER_ID',
#    'PLAYER_NAME',
#    'TimeFrame',
#    'PTS',
#    'AST',
#    'REB',
#    'PIE'],
#   'rowSet': [[2738, 'Andre Iguodala', '2018-19', 5.7, 3.2, 3.7, 0.09]]},
#  {'name': 'AvailableSeasons',
#   'headers': ['SEASON_ID'],
#   'rowSet': [['12004'],
#    ['22004'],
#    ['42004'],
#    ['12005'],
#    ['22005'],
#    ['12006'],
#    ['22006'],
#    ['12007'],
#    ['22007'],
#    ['42007'],
#    ['12008'],
#    ['22008'],
#    ['42008'],
#    ['12009'],
#    ['22009'],
#    ['12010'],
#    ['22010'],
#    ['42010'],
#    ['12011'],
#    ['22011'],
#    ['32011'],
#    ['42011'],
#    ['12012'],
#    ['22012'],
#    ['42012'],
#    ['12013'],
#    ['22013'],
#    ['42013'],
#    ['12014'],
#    ['22014'],
#    ['42014'],
#    ['12015'],
#    ['22015'],
#    ['42015'],
#    ['12016'],
#    ['22016'],
#    ['42016'],
#    ['12017'],
#    ['22017'],
#    ['42017'],
#    ['12018'],
#    ['22018'],
#    ['42018']]}]

# %%
playerdict = commonallplayers.CommonAllPlayers(season=2018, is_only_current_season=1).get_dict()
playerdict
# Out:
# {'resource': 'commonallplayers',
#  'parameters': {'LeagueID': '00', 'Season': '2018', 'IsOnlyCurrentSeason': 1},
#  'resultSets': [{'name': 'CommonAllPlayers',
#    'headers': ['PERSON_ID',
#     'DISPLAY_LAST_COMMA_FIRST',
#     'DISPLAY_FIRST_LAST',
#     'ROSTERSTATUS',
#     'FROM_YEAR',
#     'TO_YEAR',
#     'PLAYERCODE',
#     'TEAM_ID',
#     'TEAM_CITY',
#     'TEAM_NAME',
#     'TEAM_ABBREVIATION',
#     'TEAM_CODE',
#     'GAMES_PLAYED_FLAG',
#     'OTHERLEAGUE_EXPERIENCE_CH'],
#    'rowSet': [[203518,
#      'Abrines, Alex',
#      'Alex Abrines',
#      0,
#      '2016',
#      '2018',
#      'alex_abrines',
#      0,
#      '',
#      '',
#      '',
#      '',
#      'Y',
#      '00'],
#     [203112,
#      'Acy, Quincy',
#      'Quincy Acy',
#      0,
#      '2012',
#      '2018',
#      'quincy_acy',
#      0,
#      '',
#      '',
#      '',
#      '',
#      'Y',
#      '11'],
#     [1629121,
#      'Adams, Jaylen',
#      'Jaylen Adams',
#      1,
#      '2018',
#      '2019',
#      'jaylen_adams',
#      1610612737,
#      'Atlanta',
#      'Hawks',
#      'ATL',
#      'hawks',
#      'Y',
#      '11'],
#     [203500,
#      'Adams, Steven',
#      'Steven Adams',
#      1,
#      '2013',
#      '2019',
#      'steven_adams',
#      1610612760,
#      'Oklahoma City',
#      'Thunder',
#      'OKC',
#      'thunder',
#      'Y',
#      '00'],
#     [1628389,
#      'Adebayo, Bam',
#      'Bam Adebayo',
#      1,
#      '2017',
#      '2019',
#      'bam_adebayo',
#      1610612748,
#      'Miami',
#      'Heat',
#      'MIA',
#      'heat',
#      'Y',
#      '00'],
#     [1629061,
#      'Adel, Deng',
#      'Deng Adel',
#      1,
#      '2018',
#      '2018',
#      'deng_adel',
#      1610612739,
#      'Cleveland',
#      'Cavaliers',
#      'CLE',
#      'cavaliers',
#      'Y',
#      '11'],
#     [1629152,
#      'Akoon-Purcell, DeVaughn',
#      'DeVaughn Akoon-Purcell',
#      0,
#      '2018',
#      '2018',
#      'devaughn_akoon-purcell',
#      0,
#      '',
#      '',
#      '',
#      '',
#      'Y',
#      '11'],
#     [200746,
#      'Aldridge, LaMarcus',
#      'LaMarcus Aldridge',
#      1,
#      '2006',
#      '2019',
#      'lamarcus_aldridge',
#      1610612759,
#      'San Antonio',
#      'Spurs',
#      'SAS',
#      'spurs',
#      'Y',
#      '00'],
#     [1628959,
#      'Alkins, Rawle',
#      'Rawle Alkins',
#      1,
#      '2018',
#      '2018',
#      'rawle_alkins',
#      1610612741,
#      'Chicago',
#      'Bulls',
#      'CHI',
#      'bulls',
#      'Y',
#      '11'],
#     [1628960,
#      'Allen, Grayson',
#      'Grayson Allen',
#      1,
#      '2018',
#      '2019',
#      'grayson_allen',
#      1610612762,
#      'Utah',
#      'Jazz',
#      'UTA',
#      'jazz',
#      'Y',
#      '11'],
#     [1628386,
#      'Allen, Jarrett',
#      'Jarrett Allen',
#      1,
#      '2017',
#      '2019',
#      'jarrett_allen',
#      1610612751,
#      'Brooklyn',
#      'Nets',
#      'BKN',
#      'nets',
#      'Y',
#      '00'],
#     [1628443,
#      'Allen, Kadeem',
#      'Kadeem Allen',
#      1,
#      '2017',
#      '2019',
#      'kadeem_allen',
#      1610612752,
#      'New York',
#      'Knicks',
#      'NYK',
#      'knicks',
#      'Y',
#      '11'],
#     [202329,
#      'Aminu, Al-Farouq',
#      'Al-Farouq Aminu',
#      1,
#      '2010',
#      '2019',
#      'al-farouq_aminu',
#      1610612757,
#      'Portland',
#      'Trail Blazers',
#      'POR',
#      'blazers',
#      'Y',
#      '00'],
#     [1626147,
#      'Anderson, Justin',
#      'Justin Anderson',
#      1,
#      '2015',
#      '2018',
#      'justin_anderson',
#      1610612737,
#      'Atlanta',
#      'Hawks',
#      'ATL',
#      'hawks',
#      'Y',
#      '01'],
#     [203937,
#      'Anderson, Kyle',
#      'Kyle Anderson',
#      1,
#      '2014',
#      '2019',
#      'kyle_anderson',
#      1610612763,
#      'Memphis',
#      'Grizzlies',
#      'MEM',
#      'grizzlies',
#      'Y',
#      '01'],
#     [201583,
#      'Anderson, Ryan',
#      'Ryan Anderson',
#      1,
#      '2008',
#      '2019',
#      'ryan_anderson',
#      1610612748,
#      'Miami',
#      'Heat',
#      'MIA',
#      'heat',
#      'Y',
#      '00'],
#     [1628387,
#      'Anigbogu, Ike',
#      'Ike Anigbogu',
#      0,
#      '2017',
#      '2018',
#      'ike_anigbogu',
#      0,
#      '',
#      '',
#      '',
#      '',
#      'Y',
#      '11'],
#     [203507,
#      'Antetokounmpo, Giannis',
#      'Giannis Antetokounmpo',
#      1,
#      '2013',
#      '2019',
#      'giannis_antetokounmpo',
#      1610612749,
#      'Milwaukee',
#      'Bucks',
#      'MIL',
#      'bucks',
#      'Y',
#      '00'],
#     [1628961,
#      'Antetokounmpo, Kostas',
#      'Kostas Antetokounmpo',
#      1,
#      '2018',
#      '2019',
#      'kostas_antetokounmpo',
#      1610612742,
#      'Dallas',
#      'Mavericks',
#      'DAL',
#      'mavericks',
#      'Y',
#      '11'],
#     [2546,
#      'Anthony, Carmelo',
#      'Carmelo Anthony',
#      0,
#      '2003',
#      '2018',
#      'carmelo_anthony',
#      0,
#      '',
#      '',
#      '',
#      '',
#      'Y',
#      '00'],
#     [1628384,
#      'Anunoby, OG',
#      'OG Anunoby',
#      1,
#      '2017',
#      '2019',
#      'og_anunoby',
#      1610612761,
#      'Toronto',
#      'Raptors',
#      'TOR',
#      'raptors',
#      'Y',
#      '00'],
#     [1627853,
#      'Arcidiacono, Ryan',
#      'Ryan Arcidiacono',
#      1,
#      '2017',
#      '2019',
#      'ryan_arcidiacono',
#      1610612741,
#      'Chicago',
#      'Bulls',
#      'CHI',
#      'bulls',
#      'Y',
#      '01'],
#     [2772,
#      'Ariza, Trevor',
#      'Trevor Ariza',
#      1,
#      '2004',
#      '2019',
#      'trevor_ariza',
#      1610612764,
#      'Washington',
#      'Wizards',
#      'WAS',
#      'wizards',
#      'Y',
#      '00'],
#     [201571,
#      'Augustin, D.J.',
#      'D.J. Augustin',
#      1,
#      '2008',
#      '2019',
#      'd.j._augustin',
#      1610612753,
#      'Orlando',
#      'Magic',
#      'ORL',
#      'magic',
#      'Y',
#      '00'],
#     [1629028,
#      'Ayton, Deandre',
#      'Deandre Ayton',
#      1,
#      '2018',
#      '2019',
#      'deandre_ayton',
#      1610612756,
#      'Phoenix',
#      'Suns',
#      'PHX',
#      'suns',
#      'Y',
#      '00'],
#     [1628407,
#      'Bacon, Dwayne',
#      'Dwayne Bacon',
#      1,
#      '2017',
#      '2019',
#      'dwayne_bacon',
#      1610612766,
#      'Charlotte',
#      'Hornets',
#      'CHA',
#      'hornets',
#      'Y',
#      '11'],
#     [1628963,
#      'Bagley III, Marvin',
#      'Marvin Bagley III',
#      1,
#      '2018',
#      '2019',
#      'marvin_bagley_iii',
#      1610612758,
#      'Sacramento',
#      'Kings',
#      'SAC',
#      'kings',
#      'Y',
#      '00'],
#     [1627758,
#      'Baker, Ron',
#      'Ron Baker',
#      0,
#      '2016',
#      '2018',
#      'ron_baker',
#      0,
#      '',
#      '',
#      '',
#      '',
#      'Y',
#      '01'],
#     [1627735,
#      'Baldwin IV, Wade',
#      'Wade Baldwin IV',
#      0,
#      '2016',
#      '2018',
#      'wade_baldwin iv',
#      0,
#      '',
#      '',
#      '',
#      '',
#      'Y',
#      '11'],
#     [1628366,
#      'Ball, Lonzo',
#      'Lonzo Ball',
#      1,
#      '2017',
#      '2019',
#      'lonzo_ball',
#      1610612747,
#      'Los Angeles',
#      'Lakers',
#      'LAL',
#      'lakers',
#      'Y',
#      '00'],
#     [1628964,
#      'Bamba, Mo',
#      'Mo Bamba',
#      1,
#      '2018',
#      '2019',
#      'mohamed_bamba',
#      1610612753,
#      'Orlando',
#      'Magic',
#      'ORL',
#      'magic',
#      'Y',
#      '00'],
#     [200826,
#      'Barea, J.J.',
#      'J.J. Barea',
#      1,
#      '2006',
#      '2019',
#      'j.j._barea',
#      1610612742,
#      'Dallas',
#      'Mavericks',
#      'DAL',
#      'mavericks',
#      'Y',
#      '01'],
#     [203084,
#      'Barnes, Harrison',
#      'Harrison Barnes',
#      1,
#      '2012',
#      '2019',
#      'harrison_barnes',
#      1610612758,
#      'Sacramento',
#      'Kings',
#      'SAC',
#      'kings',
#      'Y',
#      '00'],
#     [203115,
#      'Barton, Will',
#      'Will Barton',
#      1,
#      '2012',
#      '2019',
#      'will_barton',
#      1610612743,
#      'Denver',
#      'Nuggets',
#      'DEN',
#      'nuggets',
#      'Y',
#      '01'],
#     [1628966,
#      'Bates-Diop, Keita',
#      'Keita Bates-Diop',
#      1,
#      '2018',
#      '2019',
#      'keita_bates-diop',
#      1610612750,
#      'Minnesota',
#      'Timberwolves',
#      'MIN',
#      'timberwolves',
#      'Y',
#      '11'],
#     [201587,
#      'Batum, Nicolas',
#      'Nicolas Batum',
#      1,
#      '2008',
#      '2019',
#      'nicolas_batum',
#      1610612766,
#      'Charlotte',
#      'Hornets',
#      'CHA',
#      'hornets',
#      'Y',
#      '00'],
#     [201573,
#      'Bayless, Jerryd',
#      'Jerryd Bayless',
#      1,
#      '2008',
#      '2018',
#      'jerryd_bayless',
#      1610612750,
#      'Minnesota',
#      'Timberwolves',
#      'MIN',
#      'timberwolves',
#      'Y',
#      '00'],
#     [203382,
#      'Baynes, Aron',
#      'Aron Baynes',
#      1,
#      '2012',
#      '2019',
#      'aron_baynes',
#      1610612738,
#      'Boston',
#      'Celtics',
#      'BOS',
#      'celtics',
#      'Y',
#      '01'],
#     [203145,
#      'Bazemore, Kent',
#      'Kent Bazemore',
#      1,
#      '2012',
#      '2019',
#      'kent_bazemore',
#      1610612737,
#      'Atlanta',
#      'Hawks',
#      'ATL',
#      'hawks',
#      'Y',
#      '01'],
#     [203078,
#      'Beal, Bradley',
#      'Bradley Beal',
#      1,
#      '2012',
#      '2019',
#      'bradley_beal',
#      1610612764,
#      'Washington',
#      'Wizards',
#      'WAS',
#      'wizards',
#      'Y',
#      '00'],
#     [1627736,
#      'Beasley, Malik',
#      'Malik Beasley',
#      1,
#      '2016',
#      '2019',
#      'malik_beasley',
#      1610612743,
#      'Denver',
#      'Nuggets',
#      'DEN',
#      'nuggets',
#      'Y',
#      '01'],
#     [201563,
#      'Beasley, Michael',
#      'Michael Beasley',
#      0,
#      '2008',
#      '2018',
#      'michael_beasley',
#      0,
#      '',
#      '',
#      '',
#      '',
#      'Y',
#      '00'],
#     [201158,
#      'Belinelli, Marco',
#      'Marco Belinelli',
#      1,
#      '2007',
#      '2019',
#      'marco_belinelli',
#      1610612759,
#      'San Antonio',
#      'Spurs',
#      'SAS',
#      'spurs',
#      'Y',
#      '00'],
#     [1628395,
#      'Bell, Jordan',
#      'Jordan Bell',
#      1,
#      '2017',
#      '2019',
#      'jordan_bell',
#      1610612744,
#      'Golden State',
#      'Warriors',
#      'GSW',
#      'warriors',
#      'Y',
#      '01'],
#     [1627761,
#      "Bembry, DeAndre'",
#      "DeAndre' Bembry",
#      1,
#      '2016',
#      '2019',
#      "deandre'_bembry",
#      1610612737,
#      'Atlanta',
#      'Hawks',
#      'ATL',
#      'hawks',
#      'Y',
#      '01'],
#     [1627733,
#      'Bender, Dragan',
#      'Dragan Bender',
#      1,
#      '2016',
#      '2019',
#      'dragan_bender',
#      1610612756,
#      'Phoenix',
#      'Suns',
#      'PHX',
#      'suns',
#      'Y',
#      '00'],
#     [1629541,
#      'Bertans, Dairis',
#      'Dairis Bertans',
#      1,
#      '2018',
#      '2018',
#      'tmp_dairis_bertans',
#      1610612740,
#      'New Orleans',
#      'Pelicans',
#      'NOP',
#      'pelicans',
#      'Y',
#      '00'],
#     [202722,
#      'Bertans, Davis',
#      'Davis Bertans',
#      1,
#      '2016',
#      '2019',
#      'davis_bertans',
#      1610612759,
#      'San Antonio',
#      'Spurs',
#      'SAS',
#      'spurs',
#      'Y',
#      '01'],
#     [201976,
#      'Beverley, Patrick',
#      'Patrick Beverley',
#      1,
#      '2012',
#      '2019',
#      'patrick_beverley',
#      1610612746,
#      'LA',
#      'Clippers',
#      'LAC',
#      'clippers',
#      'Y',
#      '01'],
#     [203920,
#      'Birch, Khem',
#      'Khem Birch',
#      1,
#      '2017',
#      '2019',
#      'khem_birch',
#      1610612753,
#      'Orlando',
#      'Magic',
#      'ORL',
#      'magic',
#      'Y',
#      '01'],
#     [202687,
#      'Biyombo, Bismack',
#      'Bismack Biyombo',
#      1,
#      '2011',
#      '2019',
#      'bismack_biyombo',
#      1610612766,
#      'Charlotte',
#      'Hornets',
#      'CHA',
#      'hornets',
#      'Y',
#      '00'],
#     [202357,
#      'Bjelica, Nemanja',
#      'Nemanja Bjelica',
#      1,
#      '2015',
#      '2019',
#      'nemanja_bjelica',
#      1610612758,
#      'Sacramento',
#      'Kings',
#      'SAC',
#      'kings',
#      'Y',
#      '00'],
#     [1628469,
#      'Blakeney, Antonio',
#      'Antonio Blakeney',
#      1,
#      '2017',
#      '2018',
#      'antonio_blakeney',
#      1610612741,
#      'Chicago',
#      'Bulls',
#      'CHI',
#      'bulls',
#      'Y',
#      '11'],
#     [202339,
#      'Bledsoe, Eric',
#      'Eric Bledsoe',
#      1,
#      '2010',
#      '2019',
#      'eric_bledsoe',
#      1610612749,
#      'Milwaukee',
#      'Bucks',
#      'MIL',
#      'bucks',
#      'Y',
#      '01'],
#     [1628417,
#      'Blossomgame, Jaron',
#      'Jaron Blossomgame',
#      1,
#      '2018',
#      '2018',
#      'jaron_blossomgame',
#      1610612739,
#      'Cleveland',
#      'Cavaliers',
#      'CLE',
#      'cavaliers',
#      'Y',
#      '11'],
#     [1629129,
#      'Bluiett, Trevon',
#      'Trevon Bluiett',
#      1,
#      '2018',
#      '2018',
#      'trevon_bluiett',
#      1610612740,
#      'New Orleans',
#      'Pelicans',
#      'NOP',
#      'pelicans',
#      'Y',
#      '11'],
#     [203992,
#      'Bogdanovic, Bogdan',
#      'Bogdan Bogdanovic',
#      1,
#      '2017',
#      '2019',
#      'bogdan_bogdanovic',
#      1610612758,
#      'Sacramento',
#      'Kings',
#      'SAC',
#      'kings',
#      'Y',
#      '00'],
#     [202711,
#      'Bogdanovic, Bojan',
#      'Bojan Bogdanovic',
#      1,
#      '2014',
#      '2019',
#      'bojan_bogdanovic',
#      1610612754,
#      'Indiana',
#      'Pacers',
#      'IND',
#      'pacers',
#      'Y',
#      '00'],
#     [101106,
#      'Bogut, Andrew',
#      'Andrew Bogut',
#      1,
#      '2005',
#      '2018',
#      'andrew_bogut',
#      1610612744,
#      'Golden State',
#      'Warriors',
#      'GSW',
#      'warriors',
#      'Y',
#      '00'],
#     [1628413,
#      'Bolden, Jonah',
#      'Jonah Bolden',
#      1,
#      '2018',
#      '2019',
#      'jonah_bolden',
#      1610612755,
#      'Philadelphia',
#      '76ers',
#      'PHI',
#      'sixers',
#      'Y',
#      '11'],
#     [1629067,
#      'Bonga, Isaac',
#      'Isaac Bonga',
#      1,
#      '2018',
#      '2019',
#      'isaac_bonga',
#      1610612747,
#      'Los Angeles',
#      'Lakers',
#      'LAL',
#      'lakers',
#      'Y',
#      '11'],
#     [1626164,
#      'Booker, Devin',
#      'Devin Booker',
#      1,
#      '2015',
#      '2019',
#      'devin_booker',
#      1610612756,
#      'Phoenix',
#      'Suns',
#      'PHX',
#      'suns',
#      'Y',
#      '00'],
#     [1628449,
#      'Boucher, Chris',
#      'Chris Boucher',
#      1,
#      '2017',
#      '2019',
#      'chris_boucher',
#      1610612761,
#      'Toronto',
#      'Raptors',
#      'TOR',
#      'raptors',
#      'Y',
#      '11'],
#     [202340,
#      'Bradley, Avery',
#      'Avery Bradley',
#      1,
#      '2010',
#      '2019',
#      'avery_bradley',
#      1610612763,
#      'Memphis',
#      'Grizzlies',
#      'MEM',
#      'grizzlies',
#      'Y',
#      '01'],
#     [1628396,
#      'Bradley, Tony',
#      'Tony Bradley',
#      1,
#      '2017',
#      '2019',
#      'tony_bradley',
#      1610612762,
#      'Utah',
#      'Jazz',
#      'UTA',
#      'jazz',
#      'Y',
#      '11'],
#     [201147,
#      'Brewer, Corey',
#      'Corey Brewer',
#      1,
#      '2007',
#      '2018',
#      'corey_brewer',
#      1610612758,
#      'Sacramento',
#      'Kings',
#      'SAC',
#      'kings',
#      'Y',
#      '00'],
#     [1628969,
#      'Bridges, Mikal',
#      'Mikal Bridges',
#      1,
#      '2018',
#      '2019',
#      'mikal_bridges',
#      1610612756,
#      'Phoenix',
#      'Suns',
#      'PHX',
#      'suns',
#      'Y',
#      '00'],
#     [1628970,
#      'Bridges, Miles',
#      'Miles Bridges',
#      1,
#      '2018',
#      '2019',
#      'miles_bridges',
#      1610612766,
#      'Charlotte',
#      'Hornets',
#      'CHA',
#      'hornets',
#      'Y',
#      '00'],
#     [1628515,
#      'Briscoe, Isaiah',
#      'Isaiah Briscoe',
#      0,
#      '2018',
#      '2018',
#      'isaiah_briscoe',
#      0,
#      '',
#      '',
#      '',
#      '',
#      'Y',
#      '11'],
#     [1629151,
#      'Broekhoff, Ryan',
#      'Ryan Broekhoff',
#      1,
#      '2018',
#      '2019',
#      'ryan_broekhoff',
#      1610612742,
#      'Dallas',
#      'Mavericks',
#      'DAL',
#      'mavericks',
#      'Y',
#      '00'],
#     [1627763,
#      'Brogdon, Malcolm',
#      'Malcolm Brogdon',
#      1,
#      '2016',
#      '2019',
#      'malcolm_brogdon',
#      1610612749,
#      'Milwaukee',
#      'Bucks',
#      'MIL',
#      'bucks',
#      'Y',
#      '00'],
#     [1628415,
#      'Brooks, Dillon',
#      'Dillon Brooks',
#      1,
#      '2017',
#      '2019',
#      'dillon_brooks',
#      1610612763,
#      'Memphis',
#      'Grizzlies',
#      'MEM',
#      'grizzlies',
#      'Y',
#      '00'],
#     [202705,
#      'Brooks, MarShon',
#      'MarShon Brooks',
#      0,
#      '2011',
#      '2018',
#      'marshon_brooks',
#      0,
#      '',
#      '',
#      '',
#      '',
#      'Y',
#      '01'],
#     [1628971,
#      'Brown, Bruce',
#      'Bruce Brown',
#      1,
#      '2018',
#      '2019',
#      'tmp_bruce_brown',
#      1610612765,
#      'Detroit',
#      'Pistons',
#      'DET',
#      'pistons',
#      'Y',
#      '11'],
#     [1627759,
#      'Brown, Jaylen',
#      'Jaylen Brown',
#      1,
#      '2016',
#      '2019',
#      'jaylen_brown',
#      1610612738,
#      'Boston',
#      'Celtics',
#      'BOS',
#      'celtics',
#      'Y',
#      '00'],
#     [203485,
#      'Brown, Lorenzo',
#      'Lorenzo Brown',
#      0,
#      '2013',
#      '2018',
#      'lorenzo_brown',
#      0,
#      '',
#      '',
#      '',
#      '',
#      'Y',
#      '01'],
#     [1628425,
#      'Brown, Sterling',
#      'Sterling Brown',
#      1,
#      '2017',
#      '2019',
#      'sterling_brown',
#      1610612749,
#      'Milwaukee',
#      'Bucks',
#      'MIL',
#      'bucks',
#      'Y',
#      '11'],
#     [1628972,
#      'Brown Jr., Troy',
#      'Troy Brown Jr.',
#      1,
#      '2018',
#      '2019',
#      'troy_brown_jr',
#      1610612764,
#      'Washington',
#      'Wizards',
#      'WAS',
#      'wizards',
#      'Y',
#      '11'],
#     [1628973,
#      'Brunson, Jalen',
#      'Jalen Brunson',
#      1,
#      '2018',
#      '2019',
#      'jalen_brunson',
#      1610612742,
#      'Dallas',
#      'Mavericks',
#      'DAL',
#      'mavericks',
#      'Y',
#      '00'],
#     [1628418,
#      'Bryant, Thomas',
#      'Thomas Bryant',
#      1,
#      '2017',
#      '2019',
#      'thomas_bryant',
#      1610612764,
#      'Washington',
#      'Wizards',
#      'WAS',
#      'wizards',
#      'Y',
#      '11'],
#     [203493,
#      'Bullock, Reggie',
#      'Reggie Bullock',
#      1,
#      '2013',
#      '2019',
#      'reggie_bullock',
#      1610612747,
#      'Los Angeles',
#      'Lakers',
#      'LAL',
#      'lakers',
#      'Y',
#      '01'],
#     [203504,
#      'Burke, Trey',
#      'Trey Burke',
#      1,
#      '2013',
#      '2019',
#      'trey_burke',
#      1610612742,
#      'Dallas',
#      'Mavericks',
#      'DAL',
#      'mavericks',
#      'Y',
#      '01'],
#     [202692,
#      'Burks, Alec',
#      'Alec Burks',
#      1,
#      '2011',
#      '2019',
#      'alec_burks',
#      1610612758,
#      'Sacramento',
#      'Kings',
#      'SAC',
#      'kings',
#      'Y',
#      '01'],
#     [1629126,
#      'Burton, Deonte',
#      'Deonte Burton',
#      1,
#      '2018',
#      '2019',
#      'deonte_burton',
#      1610612760,
#      'Oklahoma City',
#      'Thunder',
#      'OKC',
#      'thunder',
#      'Y',
#      '11'],
#     [202710,
#      'Butler, Jimmy',
#      'Jimmy Butler',
#      1,
#      '2011',
#      '2019',
#      'jimmy_butler',
#      1610612755,
#      'Philadelphia',
#      '76ers',
#      'PHI',
#      'sixers',
#      'Y',
#      '00'],
#     [203998,
#      'Caboclo, Bruno',
#      'Bruno Caboclo',
#      1,
#      '2014',
#      '2019',
#      'bruno_caboclo',
#      1610612763,
#      'Memphis',
#      'Grizzlies',
#      'MEM',
#      'grizzlies',
#      'Y',
#      '11'],
#     [101181,
#      'Calderon, Jose',
#      'Jose Calderon',
#      1,
#      '2005',
#      '2018',
#      'jose_calderon',
#      1610612765,
#      'Detroit',
#      'Pistons',
#      'DET',
#      'pistons',
#      'Y',
#      '00'],
#     [203484,
#      'Caldwell-Pope, Kentavious',
#      'Kentavious Caldwell-Pope',
#      1,
#      '2013',
#      '2019',
#      'kentavious_caldwell-pope',
#      1610612747,
#      'Los Angeles',
#      'Lakers',
#      'LAL',
#      'lakers',
#      'Y',
#      '00'],
#     [203477,
#      'Canaan, Isaiah',
#      'Isaiah Canaan',
#      0,
#      '2013',
#      '2018',
#      'isaiah_canaan',
#      0,
#      '',
#      '',
#      '',
#      '',
#      'Y',
#      '01'],
#     [203991,
#      'Capela, Clint',
#      'Clint Capela',
#      1,
#      '2014',
#      '2019',
#      'clint_capela',
#      1610612745,
#      'Houston',
#      'Rockets',
#      'HOU',
#      'rockets',
#      'Y',
#      '01'],
#     [201960,
#      'Carroll, DeMarre',
#      'DeMarre Carroll',
#      1,
#      '2009',
#      '2019',
#      'demarre_carroll',
#      1610612751,
#      'Brooklyn',
#      'Nets',
#      'BKN',
#      'nets',
#      'Y',
#      '01'],
#     [1628975,
#      'Carter, Jevon',
#      'Jevon Carter',
#      1,
#      '2018',
#      '2019',
#      'jevon_carter',
#      1610612763,
#      'Memphis',
#      'Grizzlies',
#      'MEM',
#      'grizzlies',
#      'Y',
#      '11'],
#     [1713,
#      'Carter, Vince',
#      'Vince Carter',
#      1,
#      '1998',
#      '2019',
#      'vince_carter',
#      1610612737,
#      'Atlanta',
#      'Hawks',
#      'ATL',
#      'hawks',
#      'Y',
#      '00'],
#     [1628976,
#      'Carter Jr., Wendell',
#      'Wendell Carter Jr.',
#      1,
#      '2018',
#      '2019',
#      'wendell_carter_jr',
#      1610612741,
#      'Chicago',
#      'Bulls',
#      'CHI',
#      'bulls',
#      'Y',
#      '00'],
#     [203487,
#      'Carter-Williams, Michael',
#      'Michael Carter-Williams',
#      1,
#      '2013',
#      '2019',
#      'michael_carter-williams',
#      1610612753,
#      'Orlando',
#      'Magic',
#      'ORL',
#      'magic',
#      'Y',
#      '00'],
#     [1627936,
#      'Caruso, Alex',
#      'Alex Caruso',
#      1,
#      '2017',
#      '2019',
#      'alex_caruso',
#      1610612747,
#      'Los Angeles',
#      'Lakers',
#      'LAL',
#      'lakers',
#      'Y',
#      '11'],
#     [201956,
#      'Casspi, Omri',
#      'Omri Casspi',
#      0,
#      '2009',
#      '2018',
#      'omri_casspi',
#      0,
#      '',
#      '',
#      '',
#      '',
#      'Y',
#      '00'],
#     [1626161,
#      'Cauley-Stein, Willie',
#      'Willie Cauley-Stein',
#      1,
#      '2015',
#      '2019',
#      'willie_cauley-stein',
#      1610612758,
#      'Sacramento',
#      'Kings',
#      'SAC',
#      'kings',
#      'Y',
#      '00'],
#     [1628505,
#      'Caupain, Troy',
#      'Troy Caupain',
#      1,
#      '2018',
#      '2018',
#      'troy_caupain',
#      1610612753,
#      'Orlando',
#      'Magic',
#      'ORL',
#      'magic',
#      'Y',
#      '11'],
#     [1628463,
#      'Cavanaugh, Tyler',
#      'Tyler Cavanaugh',
#      1,
#      '2017',
#      '2018',
#      'tyler_cavanaugh',
#      1610612762,
#      'Utah',
#      'Jazz',
#      'UTA',
#      'jazz',
#      'Y',
#      '11'],
#     [2199,
#      'Chandler, Tyson',
#      'Tyson Chandler',
#      1,
#      '2001',
#      '2019',
#      'tyson_chandler',
#      1610612747,
#      'Los Angeles',
#      'Lakers',
#      'LAL',
#      'lakers',
#      'Y',
#      '00'],
#     [201163,
#      'Chandler, Wilson',
#      'Wilson Chandler',
#      1,
#      '2007',
#      '2019',
#      'wilson_chandler',
#      1610612746,
#      'LA',
#      'Clippers',
#      'LAC',
#      'clippers',
#      'Y',
#      '00'],
#     [1629147,
#      'Chealey, Joe',
#      'Joe Chealey',
#      1,
#      '2018',
#      '2018',
#      'joe_chealey',
#      1610612766,
#      'Charlotte',
#      'Hornets',
#      'CHA',
#      'hornets',
#      'Y',
#      '11'],
#     [1629185,
#      'Chiozza, Chris',
#      'Chris Chiozza',
#      1,
#      '2018',
#      '2019',
#      'chris_chiozza',
#      1610612745,
#      'Houston',
#      'Rockets',
#      'HOU',
#      'rockets',
#      'Y',
#      '11'],
#     [1627737,
#      'Chriss, Marquese',
#      'Marquese Chriss',
#      1,
#      '2016',
#      '2019',
#      'marquese_chriss',
#      1610612739,
#      'Cleveland',
#      'Cavaliers',
#      'CLE',
#      'cavaliers',
#      'Y',
#      '00'],
#     [1629109,
#      'Clark, Gary',
#      'Gary Clark',
#      1,
#      '2018',
#      '2019',
#      'gary_clark',
#      1610612745,
#      'Houston',
#      'Rockets',
#      'HOU',
#      'rockets',
#      'Y',
#      '11'],
#     [203546,
#      'Clark, Ian',
#      'Ian Clark',
#      1,
#      '2013',
#      '2018',
#      'ian_clark',
#      1610612740,
#      'New Orleans',
#      'Pelicans',
#      'NOP',
#      'pelicans',
#      'Y',
#      '01'],
#     [203903,
#      'Clarkson, Jordan',
#      'Jordan Clarkson',
#      1,
#      '2014',
#      '2019',
#      'jordan_clarkson',
#      1610612739,
#      'Cleveland',
#      'Cavaliers',
#      'CLE',
#      'cavaliers',
#      'Y',
#      '01'],
#     [1628381,
#      'Collins, John',
#      'John Collins',
#      1,
#      '2017',
#      '2019',
#      'john_collins',
#      1610612737,
#      'Atlanta',
#      'Hawks',
#      'ATL',
#      'hawks',
#      'Y',
#      '00'],
#     [1628380,
#      'Collins, Zach',
#      'Zach Collins',
#      1,
#      '2017',
#      '2019',
#      'zach_collins',
#      1610612757,
#      'Portland',
#      'Trail Blazers',
#      'POR',
#      'blazers',
#      'Y',
#      '00'],
#     [201954,
#      'Collison, Darren',
#      'Darren Collison',
#      1,
#      '2009',
#      '2018',
#      'darren_collison',
#      1610612754,
#      'Indiana',
#      'Pacers',
#      'IND',
#      'pacers',
#      'Y',
#      '00'],
#     [1629045,
#      'Colson, Bonzie',
#      'Bonzie Colson',
#      1,
#      '2018',
#      '2018',
#      'bonzie_colson',
#      1610612749,
#      'Milwaukee',
#      'Bucks',
#      'MIL',
#      'bucks',
#      'Y',
#      '11'],
#     [201144,
#      'Conley, Mike',
#      'Mike Conley',
#      1,
#      '2007',
#      '2019',
#      'mike_conley',
#      1610612763,
#      'Memphis',
#      'Grizzlies',
#      'MEM',
#      'grizzlies',
#      'Y',
#      '00'],
#     [1626192,
#      'Connaughton, Pat',
#      'Pat Connaughton',
#      1,
#      '2015',
#      '2019',
#      'pat_connaughton',
#      1610612749,
#      'Milwaukee',
#      'Bucks',
#      'MIL',
#      'bucks',
#      'Y',
#      '00'],
#     [1626188,
#      'Cook, Quinn',
#      'Quinn Cook',
#      1,
#      '2016',
#      '2019',
#      'quinn_cook',
#      1610612744,
#      'Golden State',
#      'Warriors',
#      'GSW',
#      'warriors',
#      'Y',
#      '01'],
#     [202326,
#      'Cousins, DeMarcus',
#      'DeMarcus Cousins',
#      1,
#      '2010',
#      '2019',
#      'demarcus_cousins',
#      1610612744,
#      'Golden State',
#      'Warriors',
#      'GSW',
#      'warriors',
#      'Y',
#      '00'],
#     [203496,
#      'Covington, Robert',
#      'Robert Covington',
#      1,
#      '2013',
#      '2019',
#      'robert_covington',
#      1610612750,
#      'Minnesota',
#      'Timberwolves',
#      'MIN',
#      'timberwolves',
#      'Y',
#      '01'],
#     [203459,
#      'Crabbe, Allen',
#      'Allen Crabbe',
#      1,
#      '2013',
#      '2019',
#      'allen_crabbe',
#      1610612751,
#      'Brooklyn',
#      'Nets',
#      'BKN',
#      'nets',
#      'Y',
#      '01'],
#     [1628470,
#      'Craig, Torrey',
#      'Torrey Craig',
#      1,
#      '2017',
#      '2019',
#      'torrey_craig',
#      1610612743,
#      'Denver',
#      'Nuggets',
#      'DEN',
#      'nuggets',
#      'Y',
#      '01'],
#     [2037,
#      'Crawford, Jamal',
#      'Jamal Crawford',
#      1,
#      '2000',
#      '2018',
#      'jamal_crawford',
#      1610612756,
#      'Phoenix',
#      'Suns',
#      'PHX',
#      'suns',
#      'Y',
#      '00'],
#     [1628249,
#      'Creek, Mitchell',
#      'Mitchell Creek',
#      1,
#      '2018',
#      '2018',
#      'mitchell_creek',
#      1610612750,
#      'Minnesota',
#      'Timberwolves',
#      'MIN',
#      'timberwolves',
#      'Y',
#      '11'],
#     [203109,
#      'Crowder, Jae',
#      'Jae Crowder',
#      1,
#      '2012',
#      '2019',
#      'jae_crowder',
#      1610612762,
#      'Utah',
#      'Jazz',
#      'UTA',
#      'jazz',
#      'Y',
#      '01'],
#     [201967,
#      'Cunningham, Dante',
#      'Dante Cunningham',
#      1,
#      '2009',
#      '2018',
#      'dante_cunningham',
#      1610612759,
#      'San Antonio',
#      'Spurs',
#      'SAS',
#      'spurs',
#      'Y',
#      '00'],
#     [203552,
#      'Curry, Seth',
#      'Seth Curry',
#      1,
#      '2013',
#      '2019',
#      'seth_curry',
#      1610612757,
#      'Portland',
#      'Trail Blazers',
#      'POR',
#      'blazers',
#      'Y',
#      '01'],
#     [201939,
#      'Curry, Stephen',
#      'Stephen Curry',
#      1,
#      '2009',
#      '2019',
#      'stephen_curry',
#      1610612744,
#      'Golden State',
#      'Warriors',
#      'GSW',
#      'warriors',
#      'Y',
#      '00'],
#     [203584,
#      'Daniels, Troy',
#      'Troy Daniels',
#      1,
#      '2013',
#      '2019',
#      'troy_daniels',
#      1610612756,
#      'Phoenix',
#      'Suns',
#      'PHX',
#      'suns',
#      'Y',
#      '01'],
#     [203076,
#      'Davis, Anthony',
#      'Anthony Davis',
#      1,
#      '2012',
#      '2019',
#      'anthony_davis',
#      1610612740,
#      'New Orleans',
#      'Pelicans',
#      'NOP',
#      'pelicans',
#      'Y',
#      '00'],
#     [1627738,
#      'Davis, Deyonta',
#      'Deyonta Davis',
#      0,
#      '2016',
#      '2018',
#      'deyonta_davis',
#      0,
#      '',
#      '',
#      '',
#      '',
#      'Y',
#      '11'],
#     [202334,
#      'Davis, Ed',
#      'Ed Davis',
#      1,
#      '2010',
#      '2019',
#      'ed_davis',
#      1610612751,
#      'Brooklyn',
#      'Nets',
#      'BKN',
#      'nets',
#      'Y',
#      '01'],
#     [1629093,
#      'Davis, Tyler',
#      'Tyler Davis',
#      0,
#      '2018',
#      '2018',
#      'tyler_davis',
#      0,
#      '',
#      '',
#      '',
#      '',
#      'Y',
#      '11'],
#     [201942,
#      'DeRozan, DeMar',
#      'DeMar DeRozan',
#      1,
#      '2009',
#      '2019',
#      'demar_derozan',
#      1610612759,
#      'San Antonio',
#      'Spurs',
#      'SAS',
#      'spurs',
#      'Y',
#      '00'],
#     [203473,
#      'Dedmon, Dewayne',
#      'Dewayne Dedmon',
#      1,
#      '2013',
#      '2019',
#      'dewayne_dedmon',
#      1610612737,
#      'Atlanta',
#      'Hawks',
#      'ATL',
#      'hawks',
#      'Y',
#      '01'],
#     [1626155,
#      'Dekker, Sam',
#      'Sam Dekker',
#      1,
#      '2015',
#      '2018',
#      'sam_dekker',
#      1610612764,
#      'Washington',
#      'Wizards',
#      'WAS',
#      'wizards',
#      'Y',
#      '01'],
#     [1629116,
#      'Delgado, Angel',
#      'Angel Delgado',
#      1,
#      '2018',
#      '2018',
#      'angel_delgado',
#      1610612746,
#      'LA',
#      'Clippers',
#      'LAC',
#      'clippers',
#      'Y',
#      '11'],
#     [203521,
#      'Dellavedova, Matthew',
#      'Matthew Dellavedova',
#      1,
#      '2013',
#      '2019',
#      'matthew_dellavedova',
#      1610612739,
#      'Cleveland',
#      'Cavaliers',
#      'CLE',
#      'cavaliers',
#      'Y',
#      '00'],
#     [2736,
#      'Deng, Luol',
#      'Luol Deng',
#      1,
#      '2004',
#      '2018',
#      'luol_deng',
#      1610612750,
#      'Minnesota',
#      'Timberwolves',
#      'MIN',
#      'timberwolves',
#      'Y',
#      '00'],
#     [1629094,
#      'Derrickson, Marcus',
#      'Marcus Derrickson',
#      1,
#      '2018',
#      '2018',
#      'marcus_derrickson',
#      1610612744,
#      'Golden State',
#      'Warriors',
#      'GSW',
#      'warriors',
#      'Y',
#      '11'],
#     [1628978,
#      'DiVincenzo, Donte',
#      'Donte DiVincenzo',
#      1,
#      '2018',
#      '2019',
#      'donte_divincenzo',
#      1610612749,
#      'Milwaukee',
#      'Bucks',
#      'MIL',
#      'bucks',
#      'Y',
#      '11'],
#     [1627767,
#      'Diallo, Cheick',
#      'Cheick Diallo',
#      1,
#      '2016',
#      '2019',
#      'cheick_diallo',
#      1610612740,
#      'New Orleans',
#      'Pelicans',
#      'NOP',
#      'pelicans',
#      'Y',
#      '01'],
#     [1628977,
#      'Diallo, Hamidou',
#      'Hamidou Diallo',
#      1,
#      '2018',
#      '2019',
#      'hamidou_diallo',
#      1610612760,
#      'Oklahoma City',
#      'Thunder',
#      'OKC',
#      'thunder',
#      'Y',
#      '11'],
#     [203476,
#      'Dieng, Gorgui',
#      'Gorgui Dieng',
#      1,
#      '2013',
#      '2019',
#      'gorgui_dieng',
#      1610612750,
#      'Minnesota',
#      'Timberwolves',
#      'MIN',
#      'timberwolves',
#      'Y',
#      '00'],
#     [203915,
#      'Dinwiddie, Spencer',
#      'Spencer Dinwiddie',
#      1,
#      '2014',
#      '2019',
#      'spencer_dinwiddie',
#      1610612751,
#      'Brooklyn',
#      'Nets',
#      'BKN',
#      'nets',
#      'Y',
#      '01'],
#     [1629029,
#      'Doncic, Luka',
#      'Luka Doncic',
#      1,
#      '2018',
#      '2019',
#      'luka_don',
#      1610612742,
#      'Dallas',
#      'Mavericks',
#      'DAL',
#      'mavericks',
#      'Y',
#      '00'],
#     [1628416,
#      'Dorsey, Tyler',
#      'Tyler Dorsey',
#      1,
#      '2017',
#      '2018',
#      'tyler_dorsey',
#      1610612763,
#      'Memphis',
#      'Grizzlies',
#      'MEM',
#      'grizzlies',
#      'Y',
#      '11'],
#     [1628422,
#      'Dotson, Damyean',
#      'Damyean Dotson',
#      1,
#      '2017',
#      '2019',
#      'damyean_dotson',
#      1610612752,
#      'New York',
#      'Knicks',
#      'NYK',
#      'knicks',
#      'Y',
#      '01'],
#     [1628408,
#      'Dozier, PJ',
#      'PJ Dozier',
#      1,
#      '2017',
#      '2019',
#      'pj_dozier',
#      1610612738,
#      'Boston',
#      'Celtics',
#      'BOS',
#      'celtics',
#      'Y',
#      '11'],
#     [201609,
#      'Dragic, Goran',
#      'Goran Dragic',
#      1,
#      '2008',
#      '2019',
#      'goran_dragic',
#      1610612748,
#      'Miami',
#      'Heat',
#      'MIA',
#      'heat',
#      'Y',
#      '00'],
#     [203083,
#      'Drummond, Andre',
#      'Andre Drummond',
#      1,
#      '2012',
#      '2019',
#      'andre_drummond',
#      1610612765,
#      'Detroit',
#      'Pistons',
#      'DET',
#      'pistons',
#      'Y',
#      '00'],
#     [201162,
#      'Dudley, Jared',
#      'Jared Dudley',
#      1,
#      '2007',
#      '2019',
#      'jared_dudley',
#      1610612751,
#      'Brooklyn',
#      'Nets',
#      'BKN',
#      'nets',
#      'Y',
#      '00'],
#     [1627739,
#      'Dunn, Kris',
#      'Kris Dunn',
#      1,
#      '2016',
#      '2019',
#      'kris_dunn',
#      1610612741,
#      'Chicago',
#      'Bulls',
#      'CHI',
#      'bulls',
#      'Y',
#      '00'],
#     [201142,
#      'Durant, Kevin',
#      'Kevin Durant',
#      1,
#      '2007',
#      '2019',
#      'kevin_durant',
#      1610612744,
#      'Golden State',
#      'Warriors',
#      'GSW',
#      'warriors',
#      'Y',
#      '00'],
#     [1628979,
#      'Duval, Trevon',
#      'Trevon Duval',
#      1,
#      '2018',
#      '2018',
#      'trevon_duval',
#      1610612745,
#      'Houston',
#      'Rockets',
#      'HOU',
#      'rockets',
#      'Y',
#      '11'],
#     [1629053,
#      'Edwards, Vincent',
#      'Vincent Edwards',
#      1,
#      '2018',
#      '2018',
#      'vincent_edwards',
#      1610612745,
#      'Houston',
#      'Rockets',
#      'HOU',
#      'rockets',
#      'Y',
#      '11'],
#     [1627740,
#      'Ellenson, Henry',
#      'Henry Ellenson',
#      1,
#      '2016',
#      '2019',
#      'henry_ellenson',
#      1610612752,
#      'New York',
#      'Knicks',
#      'NYK',
#      'knicks',
#      'Y',
#      '11'],
#     [201961,
#      'Ellington, Wayne',
#      'Wayne Ellington',
#      1,
#      '2009',
#      '2019',
#      'wayne_ellington',
#      1610612765,
#      'Detroit',
#      'Pistons',
#      'DET',
#      'pistons',
#      'Y',
#      '00'],
#     [203954,
#      'Embiid, Joel',
#      'Joel Embiid',
#      1,
#      '2014',
#      '2019',
#      'joel_embiid',
#      1610612755,
#      'Philadelphia',
#      '76ers',
#      'PHI',
#      'sixers',
#      'Y',
#      '00'],
#     [203516,
#      'Ennis III, James',
#      'James Ennis III',
#      1,
#      '2014',
#      '2019',
#      'james_ennis iii',
#      1610612755,
#      'Philadelphia',
#      '76ers',
#      'PHI',
#      'sixers',
#      'Y',
#      '01'],
#     [1629234,
#      'Eubanks, Drew',
#      'Drew Eubanks',
#      1,
#      '2018',
#      '2019',
#      'drew_eubanks',
#      1610612759,
#      'San Antonio',
#      'Spurs',
#      'SAS',
#      'spurs',
#      'Y',
#      '11'],
#     [1628980,
#      'Evans, Jacob',
#      'Jacob Evans',
#      1,
#      '2018',
#      '2019',
#      'jacob_evans',
#      1610612744,
#      'Golden State',
#      'Warriors',
#      'GSW',
#      'warriors',
#      'Y',
#      '11'],
#     [1628393,
#      'Evans, Jawun',
#      'Jawun Evans',
#      1,
#      '2017',
#      '2018',
#      'jawun_evans',
#      1610612760,
#      'Oklahoma City',
#      'Thunder',
#      'OKC',
#      'thunder',
#      'Y',
#      '11'],
#     [201936,
#      'Evans, Tyreke',
#      'Tyreke Evans',
#      0,
#      '2009',
#      '2018',
#      'tyreke_evans',
#      0,
#      '',
#      '',
#      '',
#      '',
#      'Y',
#      '00'],
#     [203957,
#      'Exum, Dante',
#      'Dante Exum',
#      1,
#      '2014',
#      '2019',
#      'dante_exum',
#      1610612762,
#      'Utah',
#      'Jazz',
#      'UTA',
#      'jazz',
#      'Y',
#      '00'],
#     [202702,
#      'Faried, Kenneth',
#      'Kenneth Faried',
#      1,
#      '2011',
#      '2018',
#      'kenneth_faried',
#      1610612745,
#      'Houston',
#      'Rockets',
#      'HOU',
#      'rockets',
#      'Y',
#      '00'],
#     [202324,
#      'Favors, Derrick',
#      'Derrick Favors',
#      1,
#      '2010',
#      '2019',
#      'derrick_favors',
#      1610612762,
#      'Utah',
#      'Jazz',
#      'UTA',
#      'jazz',
#      'Y',
#      '00'],
#     [1626245,
#      'Felicio, Cristiano',
#      'Cristiano Felicio',
#      1,
#      '2015',
#      '2019',
#      'cristiano_felicio',
#      1610612741,
#      'Chicago',
#      'Bulls',
#      'CHI',
#      'bulls',
#      'Y',
#      '01'],
#     [101109,
#      'Felton, Raymond',
#      'Raymond Felton',
#      1,
#      '2005',
#      '2018',
#      'raymond_felton',
#      1610612760,
#      'Oklahoma City',
#      'Thunder',
#      'OKC',
#      'thunder',
#      'Y',
#      '00'],
#     [1628390,
#      'Ferguson, Terrance',
#      'Terrance Ferguson',
#      1,
#      '2017',
#      '2019',
#      'terrance_ferguson',
#      1610612760,
#      'Oklahoma City',
#      'Thunder',
#      'OKC',
#      'thunder',
#      'Y',
#      '01'],
#     [1627812,
#      'Ferrell, Yogi',
#      'Yogi Ferrell',
#      1,
#      '2016',
#      '2019',
#      'yogi_ferrell',
#      1610612758,
#      'Sacramento',
#      'Kings',
#      'SAC',
#      'kings',
#      'Y',
#      '01'],
#     [1627827,
#      'Finney-Smith, Dorian',
#      'Dorian Finney-Smith',
#      1,
#      '2016',
#      '2019',
#      'dorian_finney-smith',
#      1610612742,
#      'Dallas',
#      'Mavericks',
#      'DAL',
#      'mavericks',
#      'Y',
#      '00'],
#     [1627854,
#      'Forbes, Bryn',
#      'Bryn Forbes',
#      1,
#      '2016',
#      '2019',
#      'bryn_forbes',
#      1610612759,
#      'San Antonio',
#      'Spurs',
#      'SAS',
#      'spurs',
#      'Y',
#      '01'],
#     [203095,
#      'Fournier, Evan',
#      'Evan Fournier',
#      1,
#      '2012',
#      '2019',
#      'evan_fournier',
#      1610612753,
#      'Orlando',
#      'Magic',
#      'ORL',
#      'magic',
#      'Y',
#      '00'],
#     [1628368,
#      "Fox, De'Aaron",
#      "De'Aaron Fox",
#      1,
#      '2017',
#      '2019',
#      "de'aaron_fox",
#      1610612758,
#      'Sacramento',
#      'Kings',
#      'SAC',
#      'kings',
#      'Y',
#      '00'],
#     [1626187,
#      'Frazier, Michael',
#      'Michael Frazier',
#      1,
#      '2018',
#      '2018',
#      'michael_frazier',
#      1610612745,
#      'Houston',
#      'Rockets',
#      'HOU',
#      'rockets',
#      'Y',
#      '11'],
#     [204025,
#      'Frazier, Tim',
#      'Tim Frazier',
#      1,
#      '2014',
#      '2019',
#      'tim_frazier',
#      1610612749,
#      'Milwaukee',
#      'Bucks',
#      'MIL',
#      'bucks',
#      'Y',
#      '01'],
#     [1628982,
#      'Frazier Jr., Melvin',
#      'Melvin Frazier Jr.',
#      1,
#      '2018',
#      '2019',
#      'melvin_frazier_jr',
#      1610612753,
#      'Orlando',
#      'Magic',
#      'ORL',
#      'magic',
#      'Y',
#      '11'],
#     [202690,
#      'Fredette, Jimmer',
#      'Jimmer Fredette',
#      1,
#      '2011',
#      '2018',
#      'jimmer_fredette',
#      1610612756,
#      'Phoenix',
#      'Suns',
#      'PHX',
#      'suns',
#      'Y',
#      '01'],
#     [101112,
#      'Frye, Channing',
#      'Channing Frye',
#      1,
#      '2005',
#      '2018',
#      'channing_frye',
#      1610612739,
#      'Cleveland',
#      'Cavaliers',
#      'CLE',
#      'cavaliers',
#      'Y',
#      '00'],
#     [1628365,
#      'Fultz, Markelle',
#      'Markelle Fultz',
#      1,
#      '2017',
#      '2019',
#      'markelle_fultz',
#      1610612753,
#      'Orlando',
#      'Magic',
#      'ORL',
#      'magic',
#      'Y',
#      '00'],
#     [201568,
#      'Gallinari, Danilo',
#      'Danilo Gallinari',
#      1,
#      '2008',
#      '2019',
#      'danilo_gallinari',
#      1610612746,
#      'LA',
#      'Clippers',
#      'LAC',
#      'clippers',
#      'Y',
#      '00'],
#     [204038,
#      'Galloway, Langston',
#      'Langston Galloway',
#      1,
#      '2014',
#      '2019',
#      'langston_galloway',
#      1610612765,
#      'Detroit',
#      'Pistons',
#      'DET',
#      'pistons',
#      'Y',
#      '01'],
#     [1628656,
#      'Garrett, Billy',
#      'Billy Garrett',
#      1,
#      '2018',
#      '2018',
#      'billy_garrett',
#      1610612752,
#      'New York',
#      'Knicks',
#      'NYK',
#      'knicks',
#      'Y',
#      '11'],
#     [201188,
#      'Gasol, Marc',
#      'Marc Gasol',
#      1,
#      '2008',
#      '2019',
#      'marc_gasol',
#      1610612761,
#      'Toronto',
#      'Raptors',
#      'TOR',
#      'raptors',
#      'Y',
#      '00'],
#     [2200,
#      'Gasol, Pau',
#      'Pau Gasol',
#      1,
#      '2001',
#      '2019',
#      'pau_gasol',
#      1610612749,
#      'Milwaukee',
#      'Bucks',
#      'MIL',
#      'bucks',
#      'Y',
#      '00'],
#     [200752,
#      'Gay, Rudy',
#      'Rudy Gay',
#      1,
#      '2006',
#      '2019',
#      'rudy_gay',
#      1610612759,
#      'San Antonio',
#      'Spurs',
#      'SAS',
#      'spurs',
#      'Y',
#      '00'],
#     [202331,
#      'George, Paul',
#      'Paul George',
#      1,
#      '2010',
#      '2019',
#      'paul_george',
#      1610612760,
#      'Oklahoma City',
#      'Thunder',
#      'OKC',
#      'thunder',
#      'Y',
#      '00'],
#     [1626780,
#      'Gibson, Jonathan',
#      'Jonathan Gibson',
#      1,
#      '2016',
#      '2018',
#      'jonathan_gibson',
#      1610612738,
#      'Boston',
#      'Celtics',
#      'BOS',
#      'celtics',
#      'Y',
#      '00'],
#     [201959,
#      'Gibson, Taj',
#      'Taj Gibson',
#      1,
#      '2009',
#      '2019',
#      'taj_gibson',
#      1610612750,
#      'Minnesota',
#      'Timberwolves',
#      'MIN',
#      'timberwolves',
#      'Y',
#      '00'],
#     [1628385,
#      'Giles III, Harry',
#      'Harry Giles III',
#      1,
#      '2017',
#      '2019',
#      'harry_giles',
#      1610612758,
#      'Sacramento',
#      'Kings',
#      'SAC',
#      'kings',
#      'Y',
#      '11'],
#     [1628983,
#      'Gilgeous-Alexander, Shai',
#      'Shai Gilgeous-Alexander',
#      1,
#      '2018',
#      '2019',
#      'shai_gilgeous-alexander',
#      1610612746,
#      'LA',
#      'Clippers',
#      'LAC',
#      'clippers',
#      'Y',
#      '00'],
#     [203497,
#      'Gobert, Rudy',
#      'Rudy Gobert',
#      1,
#      '2013',
#      '2019',
#      'rudy_gobert',
#      1610612762,
#      'Utah',
#      'Jazz',
#      'UTA',
#      'jazz',
#      'Y',
#      '01'],
#     [1629164,
#      'Goodwin, Brandon',
#      'Brandon Goodwin',
#      1,
#      '2018',
#      '2019',
#      'brandon_goodwin',
#      1610612743,
#      'Denver',
#      'Nuggets',
#      'DEN',
#      'nuggets',
#      'Y',
#      '11'],
#     [203932,
#      'Gordon, Aaron',
#      'Aaron Gordon',
#      1,
#      '2014',
#      '2019',
#      'aaron_gordon',
#      1610612753,
#      'Orlando',
#      'Magic',
#      'ORL',
#      'magic',
#      'Y',
#      '00'],
#     [201569,
#      'Gordon, Eric',
#      'Eric Gordon',
#      1,
#      '2008',
#      '2019',
#      'eric_gordon',
#      1610612745,
#      'Houston',
#      'Rockets',
#      'HOU',
#      'rockets',
#      'Y',
#      '00'],
#     [101162,
#      'Gortat, Marcin',
#      'Marcin Gortat',
#      0,
#      '2007',
#      '2018',
#      'marcin_gortat',
#      0,
#      '',
#      '',
#      '',
#      '',
#      'Y',
#      '01'],
#     [1628984,
#      "Graham, Devonte'",
#      "Devonte' Graham",
#      1,
#      '2018',
#      '2019',
#      'devonte_graham',
#      1610612766,
#      'Charlotte',
#      'Hornets',
#      'CHA',
#      'hornets',
#      'Y',
#      '11'],
#     [1626203,
#      'Graham, Treveon',
#      'Treveon Graham',
#      1,
#      '2016',
#      '2019',
#      'treveon_graham',
#      1610612751,
#      'Brooklyn',
#      'Nets',
#      'BKN',
#      'nets',
#      'Y',
#      '11'],
#     [203924,
#      'Grant, Jerami',
#      'Jerami Grant',
#      1,
#      '2014',
#      '2019',
#      'jerami_grant',
#      1610612760,
#      'Oklahoma City',
#      'Thunder',
#      'OKC',
#      'thunder',
#      'Y',
#      '00'],
#     [1626170,
#      'Grant, Jerian',
#      'Jerian Grant',
#      1,
#      '2015',
#      '2018',
#      'jerian_grant',
#      1610612753,
#      'Orlando',
#      'Magic',
#      'ORL',
#      'magic',
#      'Y',
#      '01'],
#     [1629055,
#      'Grantham, Donte',
#      'Donte Grantham',
#      1,
#      '2018',
#      '2019',
#      'donte_grantham',
#      1610612760,
#      'Oklahoma City',
#      'Thunder',
#      'OKC',
#      'thunder',
#      'Y',
#      '11'],
#     [201980,
#      'Green, Danny',
#      'Danny Green',
#      1,
#      '2009',
#      '2019',
#      'danny_green',
#      1610612761,
#      'Toronto',
#      'Raptors',
#      'TOR',
#      'raptors',
#      'Y',
#      '01'],
#     [203110,
#      'Green, Draymond',
#      'Draymond Green',
#      1,
#      '2012',
#      '2019',
#      'draymond_green',
#      1610612744,
#      'Golden State',
#      'Warriors',
#      'GSW',
#      'warriors',
#      'Y',
#      '00'],
#     [101123,
#      'Green, Gerald',
#      'Gerald Green',
#      1,
#      '2005',
#      '2019',
#      'gerald_green',
#      1610612745,
#      'Houston',
#      'Rockets',
#      'HOU',
#      'rockets',
#      'Y',
#      '01'],
#     [203210,
#      'Green, JaMychal',
#      'JaMychal Green',
#      1,
#      '2014',
#      '2019',
#      'jamychal_green',
#      1610612746,
#      'LA',
#      'Clippers',
#      'LAC',
#      'clippers',
#      'Y',
#      '01'],
#     [201145,
#      'Green, Jeff',
#      'Jeff Green',
#      1,
#      '2007',
#      '2019',
#      'jeff_green',
#      1610612764,
#      'Washington',
#      'Wizards',
#      'WAS',
#      'wizards',
#      'Y',
#      '00'],
#     [201933,
#      'Griffin, Blake',
#      'Blake Griffin',
#      1,
#      '2009',
#      '2019',
#      'blake_griffin',
#      1610612765,
#      'Detroit',
#      'Pistons',
#      'DET',
#      'pistons',
#      'Y',
#      '00'],
#     [1627772,
#      'Hamilton, Daniel',
#      'Daniel Hamilton',
#      0,
#      '2017',
#      '2019',
#      'daniel_hamilton',
#      0,
#      '',
#      '',
#      '',
#      '',
#      'Y',
#      '11'],
#     [1628605,
#      'Hannahs, Dusty',
#      'Dusty Hannahs',
#      0,
#      '2018',
#      '2018',
#      'dusty_hannahs',
#      0,
#      '',
#      '',
#      '',
#      '',
#      'Y',
#      '11'],
#     [203501,
#      'Hardaway Jr., Tim',
#      'Tim Hardaway Jr.',
#      1,
#      '2013',
#      '2019',
#      'tim_hardaway jr.',
#      1610612742,
#      'Dallas',
#      'Mavericks',
#      'DAL',
#      'mavericks',
#      'Y',
#      '01'],
#     [201935,
#      'Harden, James',
#      'James Harden',
#      1,
#      '2009',
#      '2019',
#      'james_harden',
#      1610612745,
#      'Houston',
#      'Rockets',
#      'HOU',
#      'rockets',
#      'Y',
#      '00'],
#     [203090,
#      'Harkless, Maurice',
#      'Maurice Harkless',
#      1,
#      '2012',
#      '2019',
#      'maurice_harkless',
#      1610612757,
#      'Portland',
#      'Trail Blazers',
#      'POR',
#      'blazers',
#      'Y',
#      '00'],
#     [1626149,
#      'Harrell, Montrezl',
#      'Montrezl Harrell',
#      1,
#      '2015',
#      '2019',
#      'montrezl_harrell',
#      1610612746,
#      'LA',
#      'Clippers',
#      'LAC',
#      'clippers',
#      'Y',
#      '01'],
#     [2734,
#      'Harris, Devin',
#      'Devin Harris',
#      1,
#      '2004',
#      '2018',
#      'devin_harris',
#      1610612742,
#      'Dallas',
#      'Mavericks',
#      'DAL',
#      'mavericks',
#      'Y',
#      '00'],
#     [203914,
#      'Harris, Gary',
#      'Gary Harris',
#      1,
#      '2014',
#      '2019',
#      'gary_harris',
#      1610612743,
#      'Denver',
#      'Nuggets',
#      'DEN',
#      'nuggets',
#      'Y',
#      '00'],
#     [203925,
#      'Harris, Joe',
#      'Joe Harris',
#      1,
#      '2014',
#      '2019',
#      'joe_harris',
#      1610612751,
#      'Brooklyn',
#      'Nets',
#      'BKN',
#      'nets',
#      'Y',
#      '01'],
#     [202699,
#      'Harris, Tobias',
#      'Tobias Harris',
#      1,
#      '2011',
#      '2019',
#      'tobias_harris',
#      1610612755,
#      'Philadelphia',
#      '76ers',
#      'PHI',
#      'sixers',
#      'Y',
#      '00'],
#     [1626150,
#      'Harrison, Andrew',
#      'Andrew Harrison',
#      0,
#      '2016',
#      '2019',
#      'andrew_harrison',
#      0,
#      '',
#      '',
#      '',
#      '',
#      'Y',
#      '01'],
#     [1627885,
#      'Harrison, Shaquille',
#      'Shaquille Harrison',
#      1,
#      '2017',
#      '2019',
#      'shaquille_harrison',
#      1610612741,
#      'Chicago',
#      'Bulls',
#      'CHI',
#      'bulls',
#      'Y',
#      '01'],
#     [1628404,
#      'Hart, Josh',
#      'Josh Hart',
#      1,
#      '2017',
#      '2019',
#      'josh_hart',
#      1610612747,
#      'Los Angeles',
#      'Lakers',
#      'LAL',
#      'lakers',
#      'Y',
#      '01'],
#     [1628392,
#      'Hartenstein, Isaiah',
#      'Isaiah Hartenstein',
#      1,
#      '2018',
#      '2019',
#      'isaiah_hartenstein',
#      1610612745,
#      'Houston',
#      'Rockets',
#      'HOU',
#      'rockets',
#      'Y',
#      '11'],
#     [2617,
#      'Haslem, Udonis',
#      'Udonis Haslem',
#      1,
#      '2003',
#      '2019',
#      'udonis_haslem',
#      1610612748,
#      'Miami',
#      'Heat',
#      'MIA',
#      'heat',
#      'Y',
#      '00'],
#     [202330,
#      'Hayward, Gordon',
#      'Gordon Hayward',
#      1,
#      '2010',
#      '2019',
#      'gordon_hayward',
#      1610612738,
#      'Boston',
#      'Celtics',
#      'BOS',
#      'celtics',
#      'Y',
#      '00'],
#     [203089,
#      'Henson, John',
#      'John Henson',
#      1,
#      '2012',
#      '2019',
#      'john_henson',
#      1610612739,
#      'Cleveland',
#      'Cavaliers',
#      'CLE',
#      'cavaliers',
#      'Y',
#      '00'],
#     [1627823,
#      'Hernangomez, Juancho',
#      'Juancho Hernangomez',
#      1,
#      '2016',
#      '2019',
#      'juan_hernangomez',
#      1610612743,
#      'Denver',
#      'Nuggets',
#      'DEN',
#      'nuggets',
#      'Y',
#      '01'],
#     [1626195,
#      'Hernangomez, Willy',
#      'Willy Hernangomez',
#      1,
#      '2016',
#      '2019',
#      'willy_hernangomez',
#      1610612766,
#      'Charlotte',
#      'Hornets',
#      'CHA',
#      'hornets',
#      'Y',
#      '00'],
#     [1626209,
#      'Hezonja, Mario',
#      'Mario Hezonja',
#      1,
#      '2015',
# ...
#      0,
#      '',
#      '',
#      '',
#      '',
#      'Y',
#      '00'],
#     [1629015,
#      'Smith, Zhaire',
#      'Zhaire Smith',
#      1,
#      '2018',
#      '2019',
#      'zhaire_smith',
#      1610612755,
#      'Philadelphia',
#      '76ers',
#      'PHI',
#      'sixers',
#      'Y',
#      '11'],
#     [1628372,
#      'Smith Jr., Dennis',
#      'Dennis Smith Jr.',
#      1,
#      '2017',
#      '2019',
#      'dennis_smith jr.',
#      1610612752,
#      'New York',
#      'Knicks',
#      'NYK',
#      'knicks',
#      'Y',
#      '00'],
#     [203503,
#      'Snell, Tony',
#      'Tony Snell',
#      1,
#      '2013',
#      '2019',
#      'tony_snell',
#      1610612749,
#      'Milwaukee',
#      'Bucks',
#      'MIL',
#      'bucks',
#      'Y',
#      '00'],
#     [1629034,
#      'Spalding, Ray',
#      'Ray Spalding',
#      1,
#      '2018',
#      '2019',
#      'ray_spalding',
#      1610612756,
#      'Phoenix',
#      'Suns',
#      'PHX',
#      'suns',
#      'Y',
#      '11'],
#     [1629016,
#      'Spellman, Omari',
#      'Omari Spellman',
#      1,
#      '2018',
#      '2019',
#      'omari_spellman',
#      1610612737,
#      'Atlanta',
#      'Hawks',
#      'ATL',
#      'hawks',
#      'Y',
#      '11'],
#     [203917,
#      'Stauskas, Nik',
#      'Nik Stauskas',
#      1,
#      '2014',
#      '2018',
#      'nik_stauskas',
#      1610612739,
#      'Cleveland',
#      'Cavaliers',
#      'CLE',
#      'cavaliers',
#      'Y',
#      '00'],
#     [203474,
#      'Stephens, DJ',
#      'DJ Stephens',
#      0,
#      '2013',
#      '2018',
#      'dj_stephens',
#      0,
#      '',
#      '',
#      '',
#      '',
#      'Y',
#      '11'],
#     [202362,
#      'Stephenson, Lance',
#      'Lance Stephenson',
#      1,
#      '2010',
#      '2018',
#      'lance_stephenson',
#      1610612747,
#      'Los Angeles',
#      'Lakers',
#      'LAL',
#      'lakers',
#      'Y',
#      '00'],
#     [1628410,
#      'Sumner, Edmond',
#      'Edmond Sumner',
#      1,
#      '2017',
#      '2019',
#      'edmond_sumner',
#      1610612754,
#      'Indiana',
#      'Pacers',
#      'IND',
#      'pacers',
#      'Y',
#      '11'],
#     [1628403,
#      'Swanigan, Caleb',
#      'Caleb Swanigan',
#      1,
#      '2017',
#      '2019',
#      'caleb_swanigan',
#      1610612758,
#      'Sacramento',
#      'Kings',
#      'SAC',
#      'kings',
#      'Y',
#      '11'],
#     [1628369,
#      'Tatum, Jayson',
#      'Jayson Tatum',
#      1,
#      '2017',
#      '2019',
#      'jayson_tatum',
#      1610612738,
#      'Boston',
#      'Celtics',
#      'BOS',
#      'celtics',
#      'Y',
#      '00'],
#     [201952,
#      'Teague, Jeff',
#      'Jeff Teague',
#      1,
#      '2009',
#      '2019',
#      'jeff_teague',
#      1610612750,
#      'Minnesota',
#      'Timberwolves',
#      'MIN',
#      'timberwolves',
#      'Y',
#      '00'],
#     [202066,
#      'Temple, Garrett',
#      'Garrett Temple',
#      1,
#      '2009',
#      '2019',
#      'garrett_temple',
#      1610612746,
#      'LA',
#      'Clippers',
#      'LAC',
#      'clippers',
#      'Y',
#      '01'],
#     [1628462,
#      'Teodosic, Milos',
#      'Milos Teodosic',
#      0,
#      '2017',
#      '2018',
#      'milos_teodosic',
#      0,
#      '',
#      '',
#      '',
#      '',
#      'Y',
#      '00'],
#     [1629123,
#      'Terrell, Jared',
#      'Jared Terrell',
#      1,
#      '2018',
#      '2018',
#      'jared_terrell',
#      1610612750,
#      'Minnesota',
#      'Timberwolves',
#      'MIN',
#      'timberwolves',
#      'Y',
#      '11'],
#     [1629150,
#      'Terry, Emanuel',
#      'Emanuel Terry',
#      0,
#      '2018',
#      '2018',
#      'emanuel_terry',
#      0,
#      '',
#      '',
#      '',
#      '',
#      'Y',
#      '11'],
#     [1628464,
#      'Theis, Daniel',
#      'Daniel Theis',
#      1,
#      '2017',
#      '2019',
#      'daniel_theis',
#      1610612738,
#      'Boston',
#      'Celtics',
#      'BOS',
#      'celtics',
#      'Y',
#      '00'],
#     [202738,
#      'Thomas, Isaiah',
#      'Isaiah Thomas',
#      1,
#      '2011',
#      '2019',
#      'isaiah_thomas',
#      1610612743,
#      'Denver',
#      'Nuggets',
#      'DEN',
#      'nuggets',
#      'Y',
#      '00'],
#     [1629017,
#      'Thomas, Khyri',
#      'Khyri Thomas',
#      1,
#      '2018',
#      '2019',
#      'khyri_thomas',
#      1610612765,
#      'Detroit',
#      'Pistons',
#      'DET',
#      'pistons',
#      'Y',
#      '11'],
#     [202498,
#      'Thomas, Lance',
#      'Lance Thomas',
#      1,
#      '2011',
#      '2019',
#      'lance_thomas',
#      1610612752,
#      'New York',
#      'Knicks',
#      'NYK',
#      'knicks',
#      'Y',
#      '01'],
#     [202691,
#      'Thompson, Klay',
#      'Klay Thompson',
#      1,
#      '2011',
#      '2019',
#      'klay_thompson',
#      1610612744,
#      'Golden State',
#      'Warriors',
#      'GSW',
#      'warriors',
#      'Y',
#      '00'],
#     [202684,
#      'Thompson, Tristan',
#      'Tristan Thompson',
#      1,
#      '2011',
#      '2019',
#      'tristan_thompson',
#      1610612739,
#      'Cleveland',
#      'Cavaliers',
#      'CLE',
#      'cavaliers',
#      'Y',
#      '00'],
#     [1628414,
#      'Thornwell, Sindarius',
#      'Sindarius Thornwell',
#      1,
#      '2017',
#      '2019',
#      'sindarius_thornwell',
#      1610612746,
#      'LA',
#      'Clippers',
#      'LAC',
#      'clippers',
#      'Y',
#      '11'],
#     [201229,
#      'Tolliver, Anthony',
#      'Anthony Tolliver',
#      1,
#      '2008',
#      '2019',
#      'anthony_tolliver',
#      1610612750,
#      'Minnesota',
#      'Timberwolves',
#      'MIN',
#      'timberwolves',
#      'Y',
#      '01'],
#     [1626157,
#      'Towns, Karl-Anthony',
#      'Karl-Anthony Towns',
#      1,
#      '2015',
#      '2019',
#      'karl-anthony_towns',
#      1610612750,
#      'Minnesota',
#      'Timberwolves',
#      'MIN',
#      'timberwolves',
#      'Y',
#      '00'],
#     [1629018,
#      'Trent Jr., Gary',
#      'Gary Trent Jr.',
#      1,
#      '2018',
#      '2019',
#      'tmp_gary_trent',
#      1610612757,
#      'Portland',
#      'Trail Blazers',
#      'POR',
#      'blazers',
#      'Y',
#      '11'],
#     [1629019,
#      'Trier, Allonzo',
#      'Allonzo Trier',
#      1,
#      '2018',
#      '2019',
#      'allonzo_trier',
#      1610612752,
#      'New York',
#      'Knicks',
#      'NYK',
#      'knicks',
#      'Y',
#      '00'],
#     [200782,
#      'Tucker, PJ',
#      'PJ Tucker',
#      1,
#      '2006',
#      '2019',
#      'pj_tucker',
#      1610612745,
#      'Houston',
#      'Rockets',
#      'HOU',
#      'rockets',
#      'Y',
#      '01'],
#     [202323,
#      'Turner, Evan',
#      'Evan Turner',
#      1,
#      '2010',
#      '2019',
#      'evan_turner',
#      1610612757,
#      'Portland',
#      'Trail Blazers',
#      'POR',
#      'blazers',
#      'Y',
#      '00'],
#     [1626167,
#      'Turner, Myles',
#      'Myles Turner',
#      1,
#      '2015',
#      '2019',
#      'myles_turner',
#      1610612754,
#      'Indiana',
#      'Pacers',
#      'IND',
#      'pacers',
#      'Y',
#      '00'],
#     [202327,
#      'Udoh, Ekpe',
#      'Ekpe Udoh',
#      1,
#      '2010',
#      '2018',
#      'ekpe_udoh',
#      1610612762,
#      'Utah',
#      'Jazz',
#      'UTA',
#      'jazz',
#      'Y',
#      '00'],
#     [1627755,
#      'Ulis, Tyler',
#      'Tyler Ulis',
#      0,
#      '2016',
#      '2019',
#      'tyler_ulis',
#      0,
#      '',
#      '',
#      '',
#      '',
#      'Y',
#      '11'],
#     [202685,
#      'Valanciunas, Jonas',
#      'Jonas Valanciunas',
#      1,
#      '2012',
#      '2019',
#      'jonas_valanciunas',
#      1610612763,
#      'Memphis',
#      'Grizzlies',
#      'MEM',
#      'grizzlies',
#      'Y',
#      '00'],
#     [1627832,
#      'VanVleet, Fred',
#      'Fred VanVleet',
#      1,
#      '2016',
#      '2019',
#      'fred_vanvleet',
#      1610612761,
#      'Toronto',
#      'Raptors',
#      'TOR',
#      'raptors',
#      'Y',
#      '01'],
#     [1629020,
#      'Vanderbilt, Jarred',
#      'Jarred Vanderbilt',
#      1,
#      '2018',
#      '2019',
#      'jarred_vanderbilt',
#      1610612743,
#      'Denver',
#      'Nuggets',
#      'DEN',
#      'nuggets',
#      'Y',
#      '11'],
#     [203943,
#      'Vonleh, Noah',
#      'Noah Vonleh',
#      1,
#      '2014',
#      '2019',
#      'noah_vonleh',
#      1610612752,
#      'New York',
#      'Knicks',
#      'NYK',
#      'knicks',
#      'Y',
#      '01'],
#     [202696,
#      'Vucevic, Nikola',
#      'Nikola Vucevic',
#      1,
#      '2011',
#      '2019',
#      'nikola_vucevic',
#      1610612753,
#      'Orlando',
#      'Magic',
#      'ORL',
#      'magic',
#      'Y',
#      '00'],
#     [2548,
#      'Wade, Dwyane',
#      'Dwyane Wade',
#      1,
#      '2003',
#      '2018',
#      'dwyane_wade',
#      1610612748,
#      'Miami',
#      'Heat',
#      'MIA',
#      'heat',
#      'Y',
#      '00'],
#     [1629021,
#      'Wagner, Moritz',
#      'Moritz Wagner',
#      1,
#      '2018',
#      '2019',
#      'moritz_wagner',
#      1610612747,
#      'Los Angeles',
#      'Lakers',
#      'LAL',
#      'lakers',
#      'Y',
#      '11'],
#     [203079,
#      'Waiters, Dion',
#      'Dion Waiters',
#      1,
#      '2012',
#      '2019',
#      'dion_waiters',
#      1610612748,
#      'Miami',
#      'Heat',
#      'MIA',
#      'heat',
#      'Y',
#      '00'],
#     [202689,
#      'Walker, Kemba',
#      'Kemba Walker',
#      1,
#      '2011',
#      '2019',
#      'kemba_walker',
#      1610612766,
#      'Charlotte',
#      'Hornets',
#      'CHA',
#      'hornets',
#      'Y',
#      '00'],
#     [1629022,
#      'Walker IV, Lonnie',
#      'Lonnie Walker IV',
#      1,
#      '2018',
#      '2019',
#      'lonnie_walker',
#      1610612759,
#      'San Antonio',
#      'Spurs',
#      'SAS',
#      'spurs',
#      'Y',
#      '11'],
#     [202322,
#      'Wall, John',
#      'John Wall',
#      1,
#      '2010',
#      '2019',
#      'john_wall',
#      1610612764,
#      'Washington',
#      'Wizards',
#      'WAS',
#      'wizards',
#      'Y',
#      '00'],
#     [1627820,
#      'Wallace, Tyrone',
#      'Tyrone Wallace',
#      1,
#      '2017',
#      '2019',
#      'tyrone_wallace',
#      1610612746,
#      'LA',
#      'Clippers',
#      'LAC',
#      'clippers',
#      'Y',
#      '01'],
#     [202954,
#      'Wanamaker, Brad',
#      'Brad Wanamaker',
#      1,
#      '2018',
#      '2019',
#      'brad_wanamaker',
#      1610612738,
#      'Boston',
#      'Celtics',
#      'BOS',
#      'celtics',
#      'Y',
#      '11'],
#     [203933,
#      'Warren, T.J.',
#      'T.J. Warren',
#      1,
#      '2014',
#      '2019',
#      'tj_warren',
#      1610612756,
#      'Phoenix',
#      'Suns',
#      'PHX',
#      'suns',
#      'Y',
#      '01'],
#     [1627395,
#      'Washburn, Julian',
#      'Julian Washburn',
#      1,
#      '2018',
#      '2018',
#      'julian_washburn',
#      1610612763,
#      'Memphis',
#      'Grizzlies',
#      'MEM',
#      'grizzlies',
#      'Y',
#      '11'],
#     [1629139,
#      'Watanabe, Yuta',
#      'Yuta Watanabe',
#      1,
#      '2018',
#      '2019',
#      'yuta_watanabe',
#      1610612763,
#      'Memphis',
#      'Grizzlies',
#      'MEM',
#      'grizzlies',
#      'Y',
#      '11'],
#     [1629118,
#      'Welsh, Thomas',
#      'Thomas Welsh',
#      1,
#      '2018',
#      '2019',
#      'thomas_welsh',
#      1610612743,
#      'Denver',
#      'Nuggets',
#      'DEN',
#      'nuggets',
#      'Y',
#      '11'],
#     [201566,
#      'Westbrook, Russell',
#      'Russell Westbrook',
#      1,
#      '2008',
#      '2019',
#      'russell_westbrook',
#      1610612760,
#      'Oklahoma City',
#      'Thunder',
#      'OKC',
#      'thunder',
#      'Y',
#      '00'],
#     [1628401,
#      'White, Derrick',
#      'Derrick White',
#      1,
#      '2017',
#      '2019',
#      'derrick_white',
#      1610612759,
#      'San Antonio',
#      'Spurs',
#      'SAS',
#      'spurs',
#      'Y',
#      '01'],
#     [1627855,
#      'White, Okaro',
#      'Okaro White',
#      0,
#      '2016',
#      '2018',
#      'okaro_white',
#      0,
#      '',
#      '',
#      '',
#      '',
#      'Y',
#      '11'],
#     [1627785,
#      'Whitehead, Isaiah',
#      'Isaiah Whitehead',
#      1,
#      '2016',
#      '2018',
#      'isaiah_whitehead',
#      1610612765,
#      'Detroit',
#      'Pistons',
#      'DET',
#      'pistons',
#      'Y',
#      '11'],
#     [202355,
#      'Whiteside, Hassan',
#      'Hassan Whiteside',
#      1,
#      '2010',
#      '2019',
#      'hassan_whiteside',
#      1610612748,
#      'Miami',
#      'Heat',
#      'MIA',
#      'heat',
#      'Y',
#      '01'],
#     [203952,
#      'Wiggins, Andrew',
#      'Andrew Wiggins',
#      1,
#      '2014',
#      '2019',
#      'andrew_wiggins',
#      1610612750,
#      'Minnesota',
#      'Timberwolves',
#      'MIN',
#      'timberwolves',
#      'Y',
#      '00'],
#     [1626210,
#      'Williams, Alan',
#      'Alan Williams',
#      1,
#      '2015',
#      '2018',
#      'alan_williams',
#      1610612751,
#      'Brooklyn',
#      'Nets',
#      'BKN',
#      'nets',
#      'Y',
#      '11'],
#     [203710,
#      'Williams, C.J.',
#      'C.J. Williams',
#      1,
#      '2017',
#      '2019',
#      'c.j._williams',
#      1610612750,
#      'Minnesota',
#      'Timberwolves',
#      'MIN',
#      'timberwolves',
#      'Y',
#      '11'],
#     [1629140,
#      'Williams, Johnathan',
#      'Johnathan Williams',
#      1,
#      '2018',
#      '2018',
#      'johnathan_williams',
#      1610612747,
#      'Los Angeles',
#      'Lakers',
#      'LAL',
#      'lakers',
#      'Y',
#      '11'],
#     [1629026,
#      'Williams, Kenrich',
#      'Kenrich Williams',
#      1,
#      '2018',
#      '2019',
#      'kenrich_williams',
#      1610612740,
#      'New Orleans',
#      'Pelicans',
#      'NOP',
#      'pelicans',
#      'Y',
#      '11'],
#     [101150,
#      'Williams, Lou',
#      'Lou Williams',
#      1,
#      '2005',
#      '2019',
#      'lou_williams',
#      1610612746,
#      'LA',
#      'Clippers',
#      'LAC',
#      'clippers',
#      'Y',
#      '01'],
#     [101107,
#      'Williams, Marvin',
#      'Marvin Williams',
#      1,
#      '2005',
#      '2019',
#      'marvin_williams',
#      1610612766,
#      'Charlotte',
#      'Hornets',
#      'CHA',
#      'hornets',
#      'Y',
#      '00'],
#     [1627786,
#      'Williams, Troy',
#      'Troy Williams',
#      1,
#      '2016',
#      '2018',
#      'troy_williams',
#      1610612758,
#      'Sacramento',
#      'Kings',
#      'SAC',
#      'kings',
#      'Y',
#      '11'],
#     [1629057,
#      'Williams III, Robert',
#      'Robert Williams III',
#      1,
#      '2018',
#      '2019',
#      'robert_williams',
#      1610612738,
#      'Boston',
#      'Celtics',
#      'BOS',
#      'celtics',
#      'Y',
#      '11'],
#     [1628391,
#      'Wilson, D.J.',
#      'D.J. Wilson',
#      1,
#      '2017',
#      '2019',
#      'd.j._wilson',
#      1610612749,
#      'Milwaukee',
#      'Bucks',
#      'MIL',
#      'bucks',
#      'Y',
#      '11'],
#     [1626159,
#      'Winslow, Justise',
#      'Justise Winslow',
#      1,
#      '2015',
#      '2019',
#      'justise_winslow',
#      1610612748,
#      'Miami',
#      'Heat',
#      'MIA',
#      'heat',
#      'Y',
#      '00'],
#     [1626174,
#      'Wood, Christian',
#      'Christian Wood',
#      1,
#      '2015',
#      '2019',
#      'christian_wood',
#      1610612740,
#      'New Orleans',
#      'Pelicans',
#      'NOP',
#      'pelicans',
#      'Y',
#      '11'],
#     [1626153,
#      'Wright, Delon',
#      'Delon Wright',
#      1,
#      '2015',
#      '2019',
#      'delon_wright',
#      1610612763,
#      'Memphis',
#      'Grizzlies',
#      'MEM',
#      'grizzlies',
#      'Y',
#      '01'],
#     [1627824,
#      'Yabusele, Guerschon',
#      'Guerschon Yabusele',
#      1,
#      '2017',
#      '2018',
#      'guerschon_yabusele',
#      1610612738,
#      'Boston',
#      'Celtics',
#      'BOS',
#      'celtics',
#      'Y',
#      '11'],
#     [201156,
#      'Young, Nick',
#      'Nick Young',
#      0,
#      '2007',
#      '2018',
#      'nick_young',
#      0,
#      '',
#      '',
#      '',
#      '',
#      'Y',
#      '00'],
#     [201152,
#      'Young, Thaddeus',
#      'Thaddeus Young',
#      1,
#      '2007',
#      '2019',
#      'thaddeus_young',
#      1610612754,
#      'Indiana',
#      'Pacers',
#      'IND',
#      'pacers',
#      'Y',
#      '00'],
#     [1629027,
#      'Young, Trae',
#      'Trae Young',
#      1,
#      '2018',
#      '2019',
#      'trae_young',
#      1610612737,
#      'Atlanta',
#      'Hawks',
#      'ATL',
#      'hawks',
#      'Y',
#      '00'],
#     [203469,
#      'Zeller, Cody',
#      'Cody Zeller',
#      1,
#      '2013',
#      '2019',
#      'cody_zeller',
#      1610612766,
#      'Charlotte',
#      'Hornets',
#      'CHA',
#      'hornets',
#      'Y',
#      '00'],
#     [203092,
#      'Zeller, Tyler',
#      'Tyler Zeller',
#      1,
#      '2012',
#      '2019',
#      'tyler_zeller',
#      1610612763,
#      'Memphis',
#      'Grizzlies',
#      'MEM',
#      'grizzlies',
#      'Y',
#      '00'],
#     [1627790,
#      'Zizic, Ante',
#      'Ante Zizic',
#      1,
#      '2017',
#      '2019',
#      'ante_zizic',
#      1610612739,
#      'Cleveland',
#      'Cavaliers',
#      'CLE',
#      'cavaliers',
#      'Y',
#      '01'],
#     [1627826,
#      'Zubac, Ivica',
#      'Ivica Zubac',
#      1,
#      '2016',
#      '2019',
#      'ivica_zubac',
#      1610612746,
#      'LA',
#      'Clippers',
#      'LAC',
#      'clippers',
#      'Y',
#      '01']]}]}

# %%
playerdata = playerdict['resultSets'][0]['rowSet']
playerdata
# Out:
# [[203518,
#   'Abrines, Alex',
#   'Alex Abrines',
#   0,
#   '2016',
#   '2018',
#   'alex_abrines',
#   0,
#   '',
#   '',
#   '',
#   '',
#   'Y',
#   '00'],
#  [203112,
#   'Acy, Quincy',
#   'Quincy Acy',
#   0,
#   '2012',
#   '2018',
#   'quincy_acy',
#   0,
#   '',
#   '',
#   '',
#   '',
#   'Y',
#   '11'],
#  [1629121,
#   'Adams, Jaylen',
#   'Jaylen Adams',
#   1,
#   '2018',
#   '2019',
#   'jaylen_adams',
#   1610612737,
#   'Atlanta',
#   'Hawks',
#   'ATL',
#   'hawks',
#   'Y',
#   '11'],
#  [203500,
#   'Adams, Steven',
#   'Steven Adams',
#   1,
#   '2013',
#   '2019',
#   'steven_adams',
#   1610612760,
#   'Oklahoma City',
#   'Thunder',
#   'OKC',
#   'thunder',
#   'Y',
#   '00'],
#  [1628389,
#   'Adebayo, Bam',
#   'Bam Adebayo',
#   1,
#   '2017',
#   '2019',
#   'bam_adebayo',
#   1610612748,
#   'Miami',
#   'Heat',
#   'MIA',
#   'heat',
#   'Y',
#   '00'],
#  [1629061,
#   'Adel, Deng',
#   'Deng Adel',
#   1,
#   '2018',
#   '2018',
#   'deng_adel',
#   1610612739,
#   'Cleveland',
#   'Cavaliers',
#   'CLE',
#   'cavaliers',
#   'Y',
#   '11'],
#  [1629152,
#   'Akoon-Purcell, DeVaughn',
#   'DeVaughn Akoon-Purcell',
#   0,
#   '2018',
#   '2018',
#   'devaughn_akoon-purcell',
#   0,
#   '',
#   '',
#   '',
#   '',
#   'Y',
#   '11'],
#  [200746,
#   'Aldridge, LaMarcus',
#   'LaMarcus Aldridge',
#   1,
#   '2006',
#   '2019',
#   'lamarcus_aldridge',
#   1610612759,
#   'San Antonio',
#   'Spurs',
#   'SAS',
#   'spurs',
#   'Y',
#   '00'],
#  [1628959,
#   'Alkins, Rawle',
#   'Rawle Alkins',
#   1,
#   '2018',
#   '2018',
#   'rawle_alkins',
#   1610612741,
#   'Chicago',
#   'Bulls',
#   'CHI',
#   'bulls',
#   'Y',
#   '11'],
#  [1628960,
#   'Allen, Grayson',
#   'Grayson Allen',
#   1,
#   '2018',
#   '2019',
#   'grayson_allen',
#   1610612762,
#   'Utah',
#   'Jazz',
#   'UTA',
#   'jazz',
#   'Y',
#   '11'],
#  [1628386,
#   'Allen, Jarrett',
#   'Jarrett Allen',
#   1,
#   '2017',
#   '2019',
#   'jarrett_allen',
#   1610612751,
#   'Brooklyn',
#   'Nets',
#   'BKN',
#   'nets',
#   'Y',
#   '00'],
#  [1628443,
#   'Allen, Kadeem',
#   'Kadeem Allen',
#   1,
#   '2017',
#   '2019',
#   'kadeem_allen',
#   1610612752,
#   'New York',
#   'Knicks',
#   'NYK',
#   'knicks',
#   'Y',
#   '11'],
#  [202329,
#   'Aminu, Al-Farouq',
#   'Al-Farouq Aminu',
#   1,
#   '2010',
#   '2019',
#   'al-farouq_aminu',
#   1610612757,
#   'Portland',
#   'Trail Blazers',
#   'POR',
#   'blazers',
#   'Y',
#   '00'],
#  [1626147,
#   'Anderson, Justin',
#   'Justin Anderson',
#   1,
#   '2015',
#   '2018',
#   'justin_anderson',
#   1610612737,
#   'Atlanta',
#   'Hawks',
#   'ATL',
#   'hawks',
#   'Y',
#   '01'],
#  [203937,
#   'Anderson, Kyle',
#   'Kyle Anderson',
#   1,
#   '2014',
#   '2019',
#   'kyle_anderson',
#   1610612763,
#   'Memphis',
#   'Grizzlies',
#   'MEM',
#   'grizzlies',
#   'Y',
#   '01'],
#  [201583,
#   'Anderson, Ryan',
#   'Ryan Anderson',
#   1,
#   '2008',
#   '2019',
#   'ryan_anderson',
#   1610612748,
#   'Miami',
#   'Heat',
#   'MIA',
#   'heat',
#   'Y',
#   '00'],
#  [1628387,
#   'Anigbogu, Ike',
#   'Ike Anigbogu',
#   0,
#   '2017',
#   '2018',
#   'ike_anigbogu',
#   0,
#   '',
#   '',
#   '',
#   '',
#   'Y',
#   '11'],
#  [203507,
#   'Antetokounmpo, Giannis',
#   'Giannis Antetokounmpo',
#   1,
#   '2013',
#   '2019',
#   'giannis_antetokounmpo',
#   1610612749,
#   'Milwaukee',
#   'Bucks',
#   'MIL',
#   'bucks',
#   'Y',
#   '00'],
#  [1628961,
#   'Antetokounmpo, Kostas',
#   'Kostas Antetokounmpo',
#   1,
#   '2018',
#   '2019',
#   'kostas_antetokounmpo',
#   1610612742,
#   'Dallas',
#   'Mavericks',
#   'DAL',
#   'mavericks',
#   'Y',
#   '11'],
#  [2546,
#   'Anthony, Carmelo',
#   'Carmelo Anthony',
#   0,
#   '2003',
#   '2018',
#   'carmelo_anthony',
#   0,
#   '',
#   '',
#   '',
#   '',
#   'Y',
#   '00'],
#  [1628384,
#   'Anunoby, OG',
#   'OG Anunoby',
#   1,
#   '2017',
#   '2019',
#   'og_anunoby',
#   1610612761,
#   'Toronto',
#   'Raptors',
#   'TOR',
#   'raptors',
#   'Y',
#   '00'],
#  [1627853,
#   'Arcidiacono, Ryan',
#   'Ryan Arcidiacono',
#   1,
#   '2017',
#   '2019',
#   'ryan_arcidiacono',
#   1610612741,
#   'Chicago',
#   'Bulls',
#   'CHI',
#   'bulls',
#   'Y',
#   '01'],
#  [2772,
#   'Ariza, Trevor',
#   'Trevor Ariza',
#   1,
#   '2004',
#   '2019',
#   'trevor_ariza',
#   1610612764,
#   'Washington',
#   'Wizards',
#   'WAS',
#   'wizards',
#   'Y',
#   '00'],
#  [201571,
#   'Augustin, D.J.',
#   'D.J. Augustin',
#   1,
#   '2008',
#   '2019',
#   'd.j._augustin',
#   1610612753,
#   'Orlando',
#   'Magic',
#   'ORL',
#   'magic',
#   'Y',
#   '00'],
#  [1629028,
#   'Ayton, Deandre',
#   'Deandre Ayton',
#   1,
#   '2018',
#   '2019',
#   'deandre_ayton',
#   1610612756,
#   'Phoenix',
#   'Suns',
#   'PHX',
#   'suns',
#   'Y',
#   '00'],
#  [1628407,
#   'Bacon, Dwayne',
#   'Dwayne Bacon',
#   1,
#   '2017',
#   '2019',
#   'dwayne_bacon',
#   1610612766,
#   'Charlotte',
#   'Hornets',
#   'CHA',
#   'hornets',
#   'Y',
#   '11'],
#  [1628963,
#   'Bagley III, Marvin',
#   'Marvin Bagley III',
#   1,
#   '2018',
#   '2019',
#   'marvin_bagley_iii',
#   1610612758,
#   'Sacramento',
#   'Kings',
#   'SAC',
#   'kings',
#   'Y',
#   '00'],
#  [1627758,
#   'Baker, Ron',
#   'Ron Baker',
#   0,
#   '2016',
#   '2018',
#   'ron_baker',
#   0,
#   '',
#   '',
#   '',
#   '',
#   'Y',
#   '01'],
#  [1627735,
#   'Baldwin IV, Wade',
#   'Wade Baldwin IV',
#   0,
#   '2016',
#   '2018',
#   'wade_baldwin iv',
#   0,
#   '',
#   '',
#   '',
#   '',
#   'Y',
#   '11'],
#  [1628366,
#   'Ball, Lonzo',
#   'Lonzo Ball',
#   1,
#   '2017',
#   '2019',
#   'lonzo_ball',
#   1610612747,
#   'Los Angeles',
#   'Lakers',
#   'LAL',
#   'lakers',
#   'Y',
#   '00'],
#  [1628964,
#   'Bamba, Mo',
#   'Mo Bamba',
#   1,
#   '2018',
#   '2019',
#   'mohamed_bamba',
#   1610612753,
#   'Orlando',
#   'Magic',
#   'ORL',
#   'magic',
#   'Y',
#   '00'],
#  [200826,
#   'Barea, J.J.',
#   'J.J. Barea',
#   1,
#   '2006',
#   '2019',
#   'j.j._barea',
#   1610612742,
#   'Dallas',
#   'Mavericks',
#   'DAL',
#   'mavericks',
#   'Y',
#   '01'],
#  [203084,
#   'Barnes, Harrison',
#   'Harrison Barnes',
#   1,
#   '2012',
#   '2019',
#   'harrison_barnes',
#   1610612758,
#   'Sacramento',
#   'Kings',
#   'SAC',
#   'kings',
#   'Y',
#   '00'],
#  [203115,
#   'Barton, Will',
#   'Will Barton',
#   1,
#   '2012',
#   '2019',
#   'will_barton',
#   1610612743,
#   'Denver',
#   'Nuggets',
#   'DEN',
#   'nuggets',
#   'Y',
#   '01'],
#  [1628966,
#   'Bates-Diop, Keita',
#   'Keita Bates-Diop',
#   1,
#   '2018',
#   '2019',
#   'keita_bates-diop',
#   1610612750,
#   'Minnesota',
#   'Timberwolves',
#   'MIN',
#   'timberwolves',
#   'Y',
#   '11'],
#  [201587,
#   'Batum, Nicolas',
#   'Nicolas Batum',
#   1,
#   '2008',
#   '2019',
#   'nicolas_batum',
#   1610612766,
#   'Charlotte',
#   'Hornets',
#   'CHA',
#   'hornets',
#   'Y',
#   '00'],
#  [201573,
#   'Bayless, Jerryd',
#   'Jerryd Bayless',
#   1,
#   '2008',
#   '2018',
#   'jerryd_bayless',
#   1610612750,
#   'Minnesota',
#   'Timberwolves',
#   'MIN',
#   'timberwolves',
#   'Y',
#   '00'],
#  [203382,
#   'Baynes, Aron',
#   'Aron Baynes',
#   1,
#   '2012',
#   '2019',
#   'aron_baynes',
#   1610612738,
#   'Boston',
#   'Celtics',
#   'BOS',
#   'celtics',
#   'Y',
#   '01'],
#  [203145,
#   'Bazemore, Kent',
#   'Kent Bazemore',
#   1,
#   '2012',
#   '2019',
#   'kent_bazemore',
#   1610612737,
#   'Atlanta',
#   'Hawks',
#   'ATL',
#   'hawks',
#   'Y',
#   '01'],
#  [203078,
#   'Beal, Bradley',
#   'Bradley Beal',
#   1,
#   '2012',
#   '2019',
#   'bradley_beal',
#   1610612764,
#   'Washington',
#   'Wizards',
#   'WAS',
#   'wizards',
#   'Y',
#   '00'],
#  [1627736,
#   'Beasley, Malik',
#   'Malik Beasley',
#   1,
#   '2016',
#   '2019',
#   'malik_beasley',
#   1610612743,
#   'Denver',
#   'Nuggets',
#   'DEN',
#   'nuggets',
#   'Y',
#   '01'],
#  [201563,
#   'Beasley, Michael',
#   'Michael Beasley',
#   0,
#   '2008',
#   '2018',
#   'michael_beasley',
#   0,
#   '',
#   '',
#   '',
#   '',
#   'Y',
#   '00'],
#  [201158,
#   'Belinelli, Marco',
#   'Marco Belinelli',
#   1,
#   '2007',
#   '2019',
#   'marco_belinelli',
#   1610612759,
#   'San Antonio',
#   'Spurs',
#   'SAS',
#   'spurs',
#   'Y',
#   '00'],
#  [1628395,
#   'Bell, Jordan',
#   'Jordan Bell',
#   1,
#   '2017',
#   '2019',
#   'jordan_bell',
#   1610612744,
#   'Golden State',
#   'Warriors',
#   'GSW',
#   'warriors',
#   'Y',
#   '01'],
#  [1627761,
#   "Bembry, DeAndre'",
#   "DeAndre' Bembry",
#   1,
#   '2016',
#   '2019',
#   "deandre'_bembry",
#   1610612737,
#   'Atlanta',
#   'Hawks',
#   'ATL',
#   'hawks',
#   'Y',
#   '01'],
#  [1627733,
#   'Bender, Dragan',
#   'Dragan Bender',
#   1,
#   '2016',
#   '2019',
#   'dragan_bender',
#   1610612756,
#   'Phoenix',
#   'Suns',
#   'PHX',
#   'suns',
#   'Y',
#   '00'],
#  [1629541,
#   'Bertans, Dairis',
#   'Dairis Bertans',
#   1,
#   '2018',
#   '2018',
#   'tmp_dairis_bertans',
#   1610612740,
#   'New Orleans',
#   'Pelicans',
#   'NOP',
#   'pelicans',
#   'Y',
#   '00'],
#  [202722,
#   'Bertans, Davis',
#   'Davis Bertans',
#   1,
#   '2016',
#   '2019',
#   'davis_bertans',
#   1610612759,
#   'San Antonio',
#   'Spurs',
#   'SAS',
#   'spurs',
#   'Y',
#   '01'],
#  [201976,
#   'Beverley, Patrick',
#   'Patrick Beverley',
#   1,
#   '2012',
#   '2019',
#   'patrick_beverley',
#   1610612746,
#   'LA',
#   'Clippers',
#   'LAC',
#   'clippers',
#   'Y',
#   '01'],
#  [203920,
#   'Birch, Khem',
#   'Khem Birch',
#   1,
#   '2017',
#   '2019',
#   'khem_birch',
#   1610612753,
#   'Orlando',
#   'Magic',
#   'ORL',
#   'magic',
#   'Y',
#   '01'],
#  [202687,
#   'Biyombo, Bismack',
#   'Bismack Biyombo',
#   1,
#   '2011',
#   '2019',
#   'bismack_biyombo',
#   1610612766,
#   'Charlotte',
#   'Hornets',
#   'CHA',
#   'hornets',
#   'Y',
#   '00'],
#  [202357,
#   'Bjelica, Nemanja',
#   'Nemanja Bjelica',
#   1,
#   '2015',
#   '2019',
#   'nemanja_bjelica',
#   1610612758,
#   'Sacramento',
#   'Kings',
#   'SAC',
#   'kings',
#   'Y',
#   '00'],
#  [1628469,
#   'Blakeney, Antonio',
#   'Antonio Blakeney',
#   1,
#   '2017',
#   '2018',
#   'antonio_blakeney',
#   1610612741,
#   'Chicago',
#   'Bulls',
#   'CHI',
#   'bulls',
#   'Y',
#   '11'],
#  [202339,
#   'Bledsoe, Eric',
#   'Eric Bledsoe',
#   1,
#   '2010',
#   '2019',
#   'eric_bledsoe',
#   1610612749,
#   'Milwaukee',
#   'Bucks',
#   'MIL',
#   'bucks',
#   'Y',
#   '01'],
#  [1628417,
#   'Blossomgame, Jaron',
#   'Jaron Blossomgame',
#   1,
#   '2018',
#   '2018',
#   'jaron_blossomgame',
#   1610612739,
#   'Cleveland',
#   'Cavaliers',
#   'CLE',
#   'cavaliers',
#   'Y',
#   '11'],
#  [1629129,
#   'Bluiett, Trevon',
#   'Trevon Bluiett',
#   1,
#   '2018',
#   '2018',
#   'trevon_bluiett',
#   1610612740,
#   'New Orleans',
#   'Pelicans',
#   'NOP',
#   'pelicans',
#   'Y',
#   '11'],
#  [203992,
#   'Bogdanovic, Bogdan',
#   'Bogdan Bogdanovic',
#   1,
#   '2017',
#   '2019',
#   'bogdan_bogdanovic',
#   1610612758,
#   'Sacramento',
#   'Kings',
#   'SAC',
#   'kings',
#   'Y',
#   '00'],
#  [202711,
#   'Bogdanovic, Bojan',
#   'Bojan Bogdanovic',
#   1,
#   '2014',
#   '2019',
#   'bojan_bogdanovic',
#   1610612754,
#   'Indiana',
#   'Pacers',
#   'IND',
#   'pacers',
#   'Y',
#   '00'],
#  [101106,
#   'Bogut, Andrew',
#   'Andrew Bogut',
#   1,
#   '2005',
#   '2018',
#   'andrew_bogut',
#   1610612744,
#   'Golden State',
#   'Warriors',
#   'GSW',
#   'warriors',
#   'Y',
#   '00'],
#  [1628413,
#   'Bolden, Jonah',
#   'Jonah Bolden',
#   1,
#   '2018',
#   '2019',
#   'jonah_bolden',
#   1610612755,
#   'Philadelphia',
#   '76ers',
#   'PHI',
#   'sixers',
#   'Y',
#   '11'],
#  [1629067,
#   'Bonga, Isaac',
#   'Isaac Bonga',
#   1,
#   '2018',
#   '2019',
#   'isaac_bonga',
#   1610612747,
#   'Los Angeles',
#   'Lakers',
#   'LAL',
#   'lakers',
#   'Y',
#   '11'],
#  [1626164,
#   'Booker, Devin',
#   'Devin Booker',
#   1,
#   '2015',
#   '2019',
#   'devin_booker',
#   1610612756,
#   'Phoenix',
#   'Suns',
#   'PHX',
#   'suns',
#   'Y',
#   '00'],
#  [1628449,
#   'Boucher, Chris',
#   'Chris Boucher',
#   1,
#   '2017',
#   '2019',
#   'chris_boucher',
#   1610612761,
#   'Toronto',
#   'Raptors',
#   'TOR',
#   'raptors',
#   'Y',
#   '11'],
#  [202340,
#   'Bradley, Avery',
#   'Avery Bradley',
#   1,
#   '2010',
#   '2019',
#   'avery_bradley',
#   1610612763,
#   'Memphis',
#   'Grizzlies',
#   'MEM',
#   'grizzlies',
#   'Y',
#   '01'],
#  [1628396,
#   'Bradley, Tony',
#   'Tony Bradley',
#   1,
#   '2017',
#   '2019',
#   'tony_bradley',
#   1610612762,
#   'Utah',
#   'Jazz',
#   'UTA',
#   'jazz',
#   'Y',
#   '11'],
#  [201147,
#   'Brewer, Corey',
#   'Corey Brewer',
#   1,
#   '2007',
#   '2018',
#   'corey_brewer',
#   1610612758,
#   'Sacramento',
#   'Kings',
#   'SAC',
#   'kings',
#   'Y',
#   '00'],
#  [1628969,
#   'Bridges, Mikal',
#   'Mikal Bridges',
#   1,
#   '2018',
#   '2019',
#   'mikal_bridges',
#   1610612756,
#   'Phoenix',
#   'Suns',
#   'PHX',
#   'suns',
#   'Y',
#   '00'],
#  [1628970,
#   'Bridges, Miles',
#   'Miles Bridges',
#   1,
#   '2018',
#   '2019',
#   'miles_bridges',
#   1610612766,
#   'Charlotte',
#   'Hornets',
#   'CHA',
#   'hornets',
#   'Y',
#   '00'],
#  [1628515,
#   'Briscoe, Isaiah',
#   'Isaiah Briscoe',
#   0,
#   '2018',
#   '2018',
#   'isaiah_briscoe',
#   0,
#   '',
#   '',
#   '',
#   '',
#   'Y',
#   '11'],
#  [1629151,
#   'Broekhoff, Ryan',
#   'Ryan Broekhoff',
#   1,
#   '2018',
#   '2019',
#   'ryan_broekhoff',
#   1610612742,
#   'Dallas',
#   'Mavericks',
#   'DAL',
#   'mavericks',
#   'Y',
#   '00'],
#  [1627763,
#   'Brogdon, Malcolm',
#   'Malcolm Brogdon',
#   1,
#   '2016',
#   '2019',
#   'malcolm_brogdon',
#   1610612749,
#   'Milwaukee',
#   'Bucks',
#   'MIL',
#   'bucks',
#   'Y',
#   '00'],
#  [1628415,
#   'Brooks, Dillon',
#   'Dillon Brooks',
#   1,
#   '2017',
#   '2019',
#   'dillon_brooks',
#   1610612763,
#   'Memphis',
#   'Grizzlies',
#   'MEM',
#   'grizzlies',
#   'Y',
#   '00'],
#  [202705,
#   'Brooks, MarShon',
#   'MarShon Brooks',
#   0,
#   '2011',
#   '2018',
#   'marshon_brooks',
#   0,
#   '',
#   '',
#   '',
#   '',
#   'Y',
#   '01'],
#  [1628971,
#   'Brown, Bruce',
#   'Bruce Brown',
#   1,
#   '2018',
#   '2019',
#   'tmp_bruce_brown',
#   1610612765,
#   'Detroit',
#   'Pistons',
#   'DET',
#   'pistons',
#   'Y',
#   '11'],
#  [1627759,
#   'Brown, Jaylen',
#   'Jaylen Brown',
#   1,
#   '2016',
#   '2019',
#   'jaylen_brown',
#   1610612738,
#   'Boston',
#   'Celtics',
#   'BOS',
#   'celtics',
#   'Y',
#   '00'],
#  [203485,
#   'Brown, Lorenzo',
#   'Lorenzo Brown',
#   0,
#   '2013',
#   '2018',
#   'lorenzo_brown',
#   0,
#   '',
#   '',
#   '',
#   '',
#   'Y',
#   '01'],
#  [1628425,
#   'Brown, Sterling',
#   'Sterling Brown',
#   1,
#   '2017',
#   '2019',
#   'sterling_brown',
#   1610612749,
#   'Milwaukee',
#   'Bucks',
#   'MIL',
#   'bucks',
#   'Y',
#   '11'],
#  [1628972,
#   'Brown Jr., Troy',
#   'Troy Brown Jr.',
#   1,
#   '2018',
#   '2019',
#   'troy_brown_jr',
#   1610612764,
#   'Washington',
#   'Wizards',
#   'WAS',
#   'wizards',
#   'Y',
#   '11'],
#  [1628973,
#   'Brunson, Jalen',
#   'Jalen Brunson',
#   1,
#   '2018',
#   '2019',
#   'jalen_brunson',
#   1610612742,
#   'Dallas',
#   'Mavericks',
#   'DAL',
#   'mavericks',
#   'Y',
#   '00'],
#  [1628418,
#   'Bryant, Thomas',
#   'Thomas Bryant',
#   1,
#   '2017',
#   '2019',
#   'thomas_bryant',
#   1610612764,
#   'Washington',
#   'Wizards',
#   'WAS',
#   'wizards',
#   'Y',
#   '11'],
#  [203493,
#   'Bullock, Reggie',
#   'Reggie Bullock',
#   1,
#   '2013',
#   '2019',
#   'reggie_bullock',
#   1610612747,
#   'Los Angeles',
#   'Lakers',
#   'LAL',
#   'lakers',
#   'Y',
#   '01'],
#  [203504,
#   'Burke, Trey',
#   'Trey Burke',
#   1,
#   '2013',
#   '2019',
#   'trey_burke',
#   1610612742,
#   'Dallas',
#   'Mavericks',
#   'DAL',
#   'mavericks',
#   'Y',
#   '01'],
#  [202692,
#   'Burks, Alec',
#   'Alec Burks',
#   1,
#   '2011',
#   '2019',
#   'alec_burks',
#   1610612758,
#   'Sacramento',
#   'Kings',
#   'SAC',
#   'kings',
#   'Y',
#   '01'],
#  [1629126,
#   'Burton, Deonte',
#   'Deonte Burton',
#   1,
#   '2018',
#   '2019',
#   'deonte_burton',
#   1610612760,
#   'Oklahoma City',
#   'Thunder',
#   'OKC',
#   'thunder',
#   'Y',
#   '11'],
#  [202710,
#   'Butler, Jimmy',
#   'Jimmy Butler',
#   1,
#   '2011',
#   '2019',
#   'jimmy_butler',
#   1610612755,
#   'Philadelphia',
#   '76ers',
#   'PHI',
#   'sixers',
#   'Y',
#   '00'],
#  [203998,
#   'Caboclo, Bruno',
#   'Bruno Caboclo',
#   1,
#   '2014',
#   '2019',
#   'bruno_caboclo',
#   1610612763,
#   'Memphis',
#   'Grizzlies',
#   'MEM',
#   'grizzlies',
#   'Y',
#   '11'],
#  [101181,
#   'Calderon, Jose',
#   'Jose Calderon',
#   1,
#   '2005',
#   '2018',
#   'jose_calderon',
#   1610612765,
#   'Detroit',
#   'Pistons',
#   'DET',
#   'pistons',
#   'Y',
#   '00'],
#  [203484,
#   'Caldwell-Pope, Kentavious',
#   'Kentavious Caldwell-Pope',
#   1,
#   '2013',
#   '2019',
#   'kentavious_caldwell-pope',
#   1610612747,
#   'Los Angeles',
#   'Lakers',
#   'LAL',
#   'lakers',
#   'Y',
#   '00'],
#  [203477,
#   'Canaan, Isaiah',
#   'Isaiah Canaan',
#   0,
#   '2013',
#   '2018',
#   'isaiah_canaan',
#   0,
#   '',
#   '',
#   '',
#   '',
#   'Y',
#   '01'],
#  [203991,
#   'Capela, Clint',
#   'Clint Capela',
#   1,
#   '2014',
#   '2019',
#   'clint_capela',
#   1610612745,
#   'Houston',
#   'Rockets',
#   'HOU',
#   'rockets',
#   'Y',
#   '01'],
#  [201960,
#   'Carroll, DeMarre',
#   'DeMarre Carroll',
#   1,
#   '2009',
#   '2019',
#   'demarre_carroll',
#   1610612751,
#   'Brooklyn',
#   'Nets',
#   'BKN',
#   'nets',
#   'Y',
#   '01'],
#  [1628975,
#   'Carter, Jevon',
#   'Jevon Carter',
#   1,
#   '2018',
#   '2019',
#   'jevon_carter',
#   1610612763,
#   'Memphis',
#   'Grizzlies',
#   'MEM',
#   'grizzlies',
#   'Y',
#   '11'],
#  [1713,
#   'Carter, Vince',
#   'Vince Carter',
#   1,
#   '1998',
#   '2019',
#   'vince_carter',
#   1610612737,
#   'Atlanta',
#   'Hawks',
#   'ATL',
#   'hawks',
#   'Y',
#   '00'],
#  [1628976,
#   'Carter Jr., Wendell',
#   'Wendell Carter Jr.',
#   1,
#   '2018',
#   '2019',
#   'wendell_carter_jr',
#   1610612741,
#   'Chicago',
#   'Bulls',
#   'CHI',
#   'bulls',
#   'Y',
#   '00'],
#  [203487,
#   'Carter-Williams, Michael',
#   'Michael Carter-Williams',
#   1,
#   '2013',
#   '2019',
#   'michael_carter-williams',
#   1610612753,
#   'Orlando',
#   'Magic',
#   'ORL',
#   'magic',
#   'Y',
#   '00'],
#  [1627936,
#   'Caruso, Alex',
#   'Alex Caruso',
#   1,
#   '2017',
#   '2019',
#   'alex_caruso',
#   1610612747,
#   'Los Angeles',
#   'Lakers',
#   'LAL',
#   'lakers',
#   'Y',
#   '11'],
#  [201956,
#   'Casspi, Omri',
#   'Omri Casspi',
#   0,
#   '2009',
#   '2018',
#   'omri_casspi',
#   0,
#   '',
#   '',
#   '',
#   '',
#   'Y',
#   '00'],
#  [1626161,
#   'Cauley-Stein, Willie',
#   'Willie Cauley-Stein',
#   1,
#   '2015',
#   '2019',
#   'willie_cauley-stein',
#   1610612758,
#   'Sacramento',
#   'Kings',
#   'SAC',
#   'kings',
#   'Y',
#   '00'],
#  [1628505,
#   'Caupain, Troy',
#   'Troy Caupain',
#   1,
#   '2018',
#   '2018',
#   'troy_caupain',
#   1610612753,
#   'Orlando',
#   'Magic',
#   'ORL',
#   'magic',
#   'Y',
#   '11'],
#  [1628463,
#   'Cavanaugh, Tyler',
#   'Tyler Cavanaugh',
#   1,
#   '2017',
#   '2018',
#   'tyler_cavanaugh',
#   1610612762,
#   'Utah',
#   'Jazz',
#   'UTA',
#   'jazz',
#   'Y',
#   '11'],
#  [2199,
#   'Chandler, Tyson',
#   'Tyson Chandler',
#   1,
#   '2001',
#   '2019',
#   'tyson_chandler',
#   1610612747,
#   'Los Angeles',
#   'Lakers',
#   'LAL',
#   'lakers',
#   'Y',
#   '00'],
#  [201163,
#   'Chandler, Wilson',
#   'Wilson Chandler',
#   1,
#   '2007',
#   '2019',
#   'wilson_chandler',
#   1610612746,
#   'LA',
#   'Clippers',
#   'LAC',
#   'clippers',
#   'Y',
#   '00'],
#  [1629147,
#   'Chealey, Joe',
#   'Joe Chealey',
#   1,
#   '2018',
#   '2018',
#   'joe_chealey',
#   1610612766,
#   'Charlotte',
#   'Hornets',
#   'CHA',
#   'hornets',
#   'Y',
#   '11'],
#  [1629185,
#   'Chiozza, Chris',
#   'Chris Chiozza',
#   1,
#   '2018',
#   '2019',
#   'chris_chiozza',
#   1610612745,
#   'Houston',
#   'Rockets',
#   'HOU',
#   'rockets',
#   'Y',
#   '11'],
#  [1627737,
#   'Chriss, Marquese',
#   'Marquese Chriss',
#   1,
#   '2016',
#   '2019',
#   'marquese_chriss',
#   1610612739,
#   'Cleveland',
#   'Cavaliers',
#   'CLE',
#   'cavaliers',
#   'Y',
#   '00'],
#  [1629109,
#   'Clark, Gary',
#   'Gary Clark',
#   1,
#   '2018',
#   '2019',
#   'gary_clark',
#   1610612745,
#   'Houston',
#   'Rockets',
#   'HOU',
#   'rockets',
#   'Y',
#   '11'],
#  [203546,
#   'Clark, Ian',
#   'Ian Clark',
#   1,
#   '2013',
#   '2018',
#   'ian_clark',
#   1610612740,
#   'New Orleans',
#   'Pelicans',
#   'NOP',
#   'pelicans',
#   'Y',
#   '01'],
#  [203903,
#   'Clarkson, Jordan',
#   'Jordan Clarkson',
#   1,
#   '2014',
#   '2019',
#   'jordan_clarkson',
#   1610612739,
#   'Cleveland',
#   'Cavaliers',
#   'CLE',
#   'cavaliers',
#   'Y',
#   '01'],
#  [1628381,
#   'Collins, John',
#   'John Collins',
#   1,
#   '2017',
#   '2019',
#   'john_collins',
#   1610612737,
#   'Atlanta',
#   'Hawks',
#   'ATL',
#   'hawks',
#   'Y',
#   '00'],
#  [1628380,
#   'Collins, Zach',
#   'Zach Collins',
#   1,
#   '2017',
#   '2019',
#   'zach_collins',
#   1610612757,
#   'Portland',
#   'Trail Blazers',
#   'POR',
#   'blazers',
#   'Y',
#   '00'],
#  [201954,
#   'Collison, Darren',
#   'Darren Collison',
#   1,
#   '2009',
#   '2018',
#   'darren_collison',
#   1610612754,
#   'Indiana',
#   'Pacers',
#   'IND',
#   'pacers',
#   'Y',
#   '00'],
#  [1629045,
#   'Colson, Bonzie',
#   'Bonzie Colson',
#   1,
#   '2018',
#   '2018',
#   'bonzie_colson',
#   1610612749,
#   'Milwaukee',
#   'Bucks',
#   'MIL',
#   'bucks',
#   'Y',
#   '11'],
#  [201144,
#   'Conley, Mike',
#   'Mike Conley',
#   1,
#   '2007',
#   '2019',
#   'mike_conley',
#   1610612763,
#   'Memphis',
#   'Grizzlies',
#   'MEM',
#   'grizzlies',
#   'Y',
#   '00'],
#  [1626192,
#   'Connaughton, Pat',
#   'Pat Connaughton',
#   1,
#   '2015',
#   '2019',
#   'pat_connaughton',
#   1610612749,
#   'Milwaukee',
#   'Bucks',
#   'MIL',
#   'bucks',
#   'Y',
#   '00'],
#  [1626188,
#   'Cook, Quinn',
#   'Quinn Cook',
#   1,
#   '2016',
#   '2019',
#   'quinn_cook',
#   1610612744,
#   'Golden State',
#   'Warriors',
#   'GSW',
#   'warriors',
#   'Y',
#   '01'],
#  [202326,
#   'Cousins, DeMarcus',
#   'DeMarcus Cousins',
#   1,
#   '2010',
#   '2019',
#   'demarcus_cousins',
#   1610612744,
#   'Golden State',
#   'Warriors',
#   'GSW',
#   'warriors',
#   'Y',
#   '00'],
#  [203496,
#   'Covington, Robert',
#   'Robert Covington',
#   1,
#   '2013',
#   '2019',
#   'robert_covington',
#   1610612750,
#   'Minnesota',
#   'Timberwolves',
#   'MIN',
#   'timberwolves',
#   'Y',
#   '01'],
#  [203459,
#   'Crabbe, Allen',
#   'Allen Crabbe',
#   1,
#   '2013',
#   '2019',
#   'allen_crabbe',
#   1610612751,
#   'Brooklyn',
#   'Nets',
#   'BKN',
#   'nets',
#   'Y',
#   '01'],
#  [1628470,
#   'Craig, Torrey',
#   'Torrey Craig',
#   1,
#   '2017',
#   '2019',
#   'torrey_craig',
#   1610612743,
#   'Denver',
#   'Nuggets',
#   'DEN',
#   'nuggets',
#   'Y',
#   '01'],
#  [2037,
#   'Crawford, Jamal',
#   'Jamal Crawford',
#   1,
#   '2000',
#   '2018',
#   'jamal_crawford',
#   1610612756,
#   'Phoenix',
#   'Suns',
#   'PHX',
#   'suns',
#   'Y',
#   '00'],
#  [1628249,
#   'Creek, Mitchell',
#   'Mitchell Creek',
#   1,
#   '2018',
#   '2018',
#   'mitchell_creek',
#   1610612750,
#   'Minnesota',
#   'Timberwolves',
#   'MIN',
#   'timberwolves',
#   'Y',
#   '11'],
#  [203109,
#   'Crowder, Jae',
#   'Jae Crowder',
#   1,
#   '2012',
#   '2019',
#   'jae_crowder',
#   1610612762,
#   'Utah',
#   'Jazz',
#   'UTA',
#   'jazz',
#   'Y',
#   '01'],
#  [201967,
#   'Cunningham, Dante',
#   'Dante Cunningham',
#   1,
#   '2009',
#   '2018',
#   'dante_cunningham',
#   1610612759,
#   'San Antonio',
#   'Spurs',
#   'SAS',
#   'spurs',
#   'Y',
#   '00'],
#  [203552,
#   'Curry, Seth',
#   'Seth Curry',
#   1,
#   '2013',
#   '2019',
#   'seth_curry',
#   1610612757,
#   'Portland',
#   'Trail Blazers',
#   'POR',
#   'blazers',
#   'Y',
#   '01'],
#  [201939,
#   'Curry, Stephen',
#   'Stephen Curry',
#   1,
#   '2009',
#   '2019',
#   'stephen_curry',
#   1610612744,
#   'Golden State',
#   'Warriors',
#   'GSW',
#   'warriors',
#   'Y',
#   '00'],
#  [203584,
#   'Daniels, Troy',
#   'Troy Daniels',
#   1,
#   '2013',
#   '2019',
#   'troy_daniels',
#   1610612756,
#   'Phoenix',
#   'Suns',
#   'PHX',
#   'suns',
#   'Y',
#   '01'],
#  [203076,
#   'Davis, Anthony',
#   'Anthony Davis',
#   1,
#   '2012',
#   '2019',
#   'anthony_davis',
#   1610612740,
#   'New Orleans',
#   'Pelicans',
#   'NOP',
#   'pelicans',
#   'Y',
#   '00'],
#  [1627738,
#   'Davis, Deyonta',
#   'Deyonta Davis',
#   0,
#   '2016',
#   '2018',
#   'deyonta_davis',
#   0,
#   '',
#   '',
#   '',
#   '',
#   'Y',
#   '11'],
#  [202334,
#   'Davis, Ed',
#   'Ed Davis',
#   1,
#   '2010',
#   '2019',
#   'ed_davis',
#   1610612751,
#   'Brooklyn',
#   'Nets',
#   'BKN',
#   'nets',
#   'Y',
#   '01'],
#  [1629093,
#   'Davis, Tyler',
#   'Tyler Davis',
#   0,
#   '2018',
#   '2018',
#   'tyler_davis',
#   0,
#   '',
#   '',
#   '',
#   '',
#   'Y',
#   '11'],
#  [201942,
#   'DeRozan, DeMar',
#   'DeMar DeRozan',
#   1,
#   '2009',
#   '2019',
#   'demar_derozan',
#   1610612759,
#   'San Antonio',
#   'Spurs',
#   'SAS',
#   'spurs',
#   'Y',
#   '00'],
#  [203473,
#   'Dedmon, Dewayne',
#   'Dewayne Dedmon',
#   1,
#   '2013',
#   '2019',
#   'dewayne_dedmon',
#   1610612737,
#   'Atlanta',
#   'Hawks',
#   'ATL',
#   'hawks',
#   'Y',
#   '01'],
#  [1626155,
#   'Dekker, Sam',
#   'Sam Dekker',
#   1,
#   '2015',
#   '2018',
#   'sam_dekker',
#   1610612764,
#   'Washington',
#   'Wizards',
#   'WAS',
#   'wizards',
#   'Y',
#   '01'],
#  [1629116,
#   'Delgado, Angel',
#   'Angel Delgado',
#   1,
#   '2018',
#   '2018',
#   'angel_delgado',
#   1610612746,
#   'LA',
#   'Clippers',
#   'LAC',
#   'clippers',
#   'Y',
#   '11'],
#  [203521,
#   'Dellavedova, Matthew',
#   'Matthew Dellavedova',
#   1,
#   '2013',
#   '2019',
#   'matthew_dellavedova',
#   1610612739,
#   'Cleveland',
#   'Cavaliers',
#   'CLE',
#   'cavaliers',
#   'Y',
#   '00'],
#  [2736,
#   'Deng, Luol',
#   'Luol Deng',
#   1,
#   '2004',
#   '2018',
#   'luol_deng',
#   1610612750,
#   'Minnesota',
#   'Timberwolves',
#   'MIN',
#   'timberwolves',
#   'Y',
#   '00'],
#  [1629094,
#   'Derrickson, Marcus',
#   'Marcus Derrickson',
#   1,
#   '2018',
#   '2018',
#   'marcus_derrickson',
#   1610612744,
#   'Golden State',
#   'Warriors',
#   'GSW',
#   'warriors',
#   'Y',
#   '11'],
#  [1628978,
#   'DiVincenzo, Donte',
#   'Donte DiVincenzo',
#   1,
#   '2018',
#   '2019',
#   'donte_divincenzo',
#   1610612749,
#   'Milwaukee',
#   'Bucks',
#   'MIL',
#   'bucks',
#   'Y',
#   '11'],
#  [1627767,
#   'Diallo, Cheick',
#   'Cheick Diallo',
#   1,
#   '2016',
#   '2019',
#   'cheick_diallo',
#   1610612740,
#   'New Orleans',
#   'Pelicans',
#   'NOP',
#   'pelicans',
#   'Y',
#   '01'],
#  [1628977,
#   'Diallo, Hamidou',
#   'Hamidou Diallo',
#   1,
#   '2018',
#   '2019',
#   'hamidou_diallo',
#   1610612760,
#   'Oklahoma City',
#   'Thunder',
#   'OKC',
#   'thunder',
#   'Y',
#   '11'],
#  [203476,
#   'Dieng, Gorgui',
#   'Gorgui Dieng',
#   1,
#   '2013',
#   '2019',
#   'gorgui_dieng',
#   1610612750,
#   'Minnesota',
#   'Timberwolves',
#   'MIN',
#   'timberwolves',
#   'Y',
#   '00'],
#  [203915,
#   'Dinwiddie, Spencer',
#   'Spencer Dinwiddie',
#   1,
#   '2014',
#   '2019',
#   'spencer_dinwiddie',
#   1610612751,
#   'Brooklyn',
#   'Nets',
#   'BKN',
#   'nets',
#   'Y',
#   '01'],
#  [1629029,
#   'Doncic, Luka',
#   'Luka Doncic',
#   1,
#   '2018',
#   '2019',
#   'luka_don',
#   1610612742,
#   'Dallas',
#   'Mavericks',
#   'DAL',
#   'mavericks',
#   'Y',
#   '00'],
#  [1628416,
#   'Dorsey, Tyler',
#   'Tyler Dorsey',
#   1,
#   '2017',
#   '2018',
#   'tyler_dorsey',
#   1610612763,
#   'Memphis',
#   'Grizzlies',
#   'MEM',
#   'grizzlies',
#   'Y',
#   '11'],
#  [1628422,
#   'Dotson, Damyean',
#   'Damyean Dotson',
#   1,
#   '2017',
#   '2019',
#   'damyean_dotson',
#   1610612752,
#   'New York',
#   'Knicks',
#   'NYK',
#   'knicks',
#   'Y',
#   '01'],
#  [1628408,
#   'Dozier, PJ',
#   'PJ Dozier',
#   1,
#   '2017',
#   '2019',
#   'pj_dozier',
#   1610612738,
#   'Boston',
#   'Celtics',
#   'BOS',
#   'celtics',
#   'Y',
#   '11'],
#  [201609,
#   'Dragic, Goran',
#   'Goran Dragic',
#   1,
#   '2008',
#   '2019',
#   'goran_dragic',
#   1610612748,
#   'Miami',
#   'Heat',
#   'MIA',
#   'heat',
#   'Y',
#   '00'],
#  [203083,
#   'Drummond, Andre',
#   'Andre Drummond',
#   1,
#   '2012',
#   '2019',
#   'andre_drummond',
#   1610612765,
#   'Detroit',
#   'Pistons',
#   'DET',
#   'pistons',
#   'Y',
#   '00'],
#  [201162,
#   'Dudley, Jared',
#   'Jared Dudley',
#   1,
#   '2007',
#   '2019',
#   'jared_dudley',
#   1610612751,
#   'Brooklyn',
#   'Nets',
#   'BKN',
#   'nets',
#   'Y',
#   '00'],
#  [1627739,
#   'Dunn, Kris',
#   'Kris Dunn',
#   1,
#   '2016',
#   '2019',
#   'kris_dunn',
#   1610612741,
#   'Chicago',
#   'Bulls',
#   'CHI',
#   'bulls',
#   'Y',
#   '00'],
#  [201142,
#   'Durant, Kevin',
#   'Kevin Durant',
#   1,
#   '2007',
#   '2019',
#   'kevin_durant',
#   1610612744,
#   'Golden State',
#   'Warriors',
#   'GSW',
#   'warriors',
#   'Y',
#   '00'],
#  [1628979,
#   'Duval, Trevon',
#   'Trevon Duval',
#   1,
#   '2018',
#   '2018',
#   'trevon_duval',
#   1610612745,
#   'Houston',
#   'Rockets',
#   'HOU',
#   'rockets',
#   'Y',
#   '11'],
#  [1629053,
#   'Edwards, Vincent',
#   'Vincent Edwards',
#   1,
#   '2018',
#   '2018',
#   'vincent_edwards',
#   1610612745,
#   'Houston',
#   'Rockets',
#   'HOU',
#   'rockets',
#   'Y',
#   '11'],
#  [1627740,
#   'Ellenson, Henry',
#   'Henry Ellenson',
#   1,
#   '2016',
#   '2019',
#   'henry_ellenson',
#   1610612752,
#   'New York',
#   'Knicks',
#   'NYK',
#   'knicks',
#   'Y',
#   '11'],
#  [201961,
#   'Ellington, Wayne',
#   'Wayne Ellington',
#   1,
#   '2009',
#   '2019',
#   'wayne_ellington',
#   1610612765,
#   'Detroit',
#   'Pistons',
#   'DET',
#   'pistons',
#   'Y',
#   '00'],
#  [203954,
#   'Embiid, Joel',
#   'Joel Embiid',
#   1,
#   '2014',
#   '2019',
#   'joel_embiid',
#   1610612755,
#   'Philadelphia',
#   '76ers',
#   'PHI',
#   'sixers',
#   'Y',
#   '00'],
#  [203516,
#   'Ennis III, James',
#   'James Ennis III',
#   1,
#   '2014',
#   '2019',
#   'james_ennis iii',
#   1610612755,
#   'Philadelphia',
#   '76ers',
#   'PHI',
#   'sixers',
#   'Y',
#   '01'],
#  [1629234,
#   'Eubanks, Drew',
#   'Drew Eubanks',
#   1,
#   '2018',
#   '2019',
#   'drew_eubanks',
#   1610612759,
#   'San Antonio',
#   'Spurs',
#   'SAS',
#   'spurs',
#   'Y',
#   '11'],
#  [1628980,
#   'Evans, Jacob',
#   'Jacob Evans',
#   1,
#   '2018',
#   '2019',
#   'jacob_evans',
#   1610612744,
#   'Golden State',
#   'Warriors',
#   'GSW',
#   'warriors',
#   'Y',
#   '11'],
#  [1628393,
#   'Evans, Jawun',
#   'Jawun Evans',
#   1,
#   '2017',
#   '2018',
#   'jawun_evans',
#   1610612760,
#   'Oklahoma City',
#   'Thunder',
#   'OKC',
#   'thunder',
#   'Y',
#   '11'],
#  [201936,
#   'Evans, Tyreke',
#   'Tyreke Evans',
#   0,
#   '2009',
#   '2018',
#   'tyreke_evans',
#   0,
#   '',
#   '',
#   '',
#   '',
#   'Y',
#   '00'],
#  [203957,
#   'Exum, Dante',
#   'Dante Exum',
#   1,
#   '2014',
#   '2019',
#   'dante_exum',
#   1610612762,
#   'Utah',
#   'Jazz',
#   'UTA',
#   'jazz',
#   'Y',
#   '00'],
#  [202702,
#   'Faried, Kenneth',
#   'Kenneth Faried',
#   1,
#   '2011',
#   '2018',
#   'kenneth_faried',
#   1610612745,
#   'Houston',
#   'Rockets',
#   'HOU',
#   'rockets',
#   'Y',
#   '00'],
#  [202324,
#   'Favors, Derrick',
#   'Derrick Favors',
#   1,
#   '2010',
#   '2019',
#   'derrick_favors',
#   1610612762,
#   'Utah',
#   'Jazz',
#   'UTA',
#   'jazz',
#   'Y',
#   '00'],
#  [1626245,
#   'Felicio, Cristiano',
#   'Cristiano Felicio',
#   1,
#   '2015',
#   '2019',
#   'cristiano_felicio',
#   1610612741,
#   'Chicago',
#   'Bulls',
#   'CHI',
#   'bulls',
#   'Y',
#   '01'],
#  [101109,
#   'Felton, Raymond',
#   'Raymond Felton',
#   1,
#   '2005',
#   '2018',
#   'raymond_felton',
#   1610612760,
#   'Oklahoma City',
#   'Thunder',
#   'OKC',
#   'thunder',
#   'Y',
#   '00'],
#  [1628390,
#   'Ferguson, Terrance',
#   'Terrance Ferguson',
#   1,
#   '2017',
#   '2019',
#   'terrance_ferguson',
#   1610612760,
#   'Oklahoma City',
#   'Thunder',
#   'OKC',
#   'thunder',
#   'Y',
#   '01'],
#  [1627812,
#   'Ferrell, Yogi',
#   'Yogi Ferrell',
#   1,
#   '2016',
#   '2019',
#   'yogi_ferrell',
#   1610612758,
#   'Sacramento',
#   'Kings',
#   'SAC',
#   'kings',
#   'Y',
#   '01'],
#  [1627827,
#   'Finney-Smith, Dorian',
#   'Dorian Finney-Smith',
#   1,
#   '2016',
#   '2019',
#   'dorian_finney-smith',
#   1610612742,
#   'Dallas',
#   'Mavericks',
#   'DAL',
#   'mavericks',
#   'Y',
#   '00'],
#  [1627854,
#   'Forbes, Bryn',
#   'Bryn Forbes',
#   1,
#   '2016',
#   '2019',
#   'bryn_forbes',
#   1610612759,
#   'San Antonio',
#   'Spurs',
#   'SAS',
#   'spurs',
#   'Y',
#   '01'],
#  [203095,
#   'Fournier, Evan',
#   'Evan Fournier',
#   1,
#   '2012',
#   '2019',
#   'evan_fournier',
#   1610612753,
#   'Orlando',
#   'Magic',
#   'ORL',
#   'magic',
#   'Y',
#   '00'],
#  [1628368,
#   "Fox, De'Aaron",
#   "De'Aaron Fox",
#   1,
#   '2017',
#   '2019',
#   "de'aaron_fox",
#   1610612758,
#   'Sacramento',
#   'Kings',
#   'SAC',
#   'kings',
#   'Y',
#   '00'],
#  [1626187,
#   'Frazier, Michael',
#   'Michael Frazier',
#   1,
#   '2018',
#   '2018',
#   'michael_frazier',
#   1610612745,
#   'Houston',
#   'Rockets',
#   'HOU',
#   'rockets',
#   'Y',
#   '11'],
#  [204025,
#   'Frazier, Tim',
#   'Tim Frazier',
#   1,
#   '2014',
#   '2019',
#   'tim_frazier',
#   1610612749,
#   'Milwaukee',
#   'Bucks',
#   'MIL',
#   'bucks',
#   'Y',
#   '01'],
#  [1628982,
#   'Frazier Jr., Melvin',
#   'Melvin Frazier Jr.',
#   1,
#   '2018',
#   '2019',
#   'melvin_frazier_jr',
#   1610612753,
#   'Orlando',
#   'Magic',
#   'ORL',
#   'magic',
#   'Y',
#   '11'],
#  [202690,
#   'Fredette, Jimmer',
#   'Jimmer Fredette',
#   1,
#   '2011',
#   '2018',
#   'jimmer_fredette',
#   1610612756,
#   'Phoenix',
#   'Suns',
#   'PHX',
#   'suns',
#   'Y',
#   '01'],
#  [101112,
#   'Frye, Channing',
#   'Channing Frye',
#   1,
#   '2005',
#   '2018',
#   'channing_frye',
#   1610612739,
#   'Cleveland',
#   'Cavaliers',
#   'CLE',
#   'cavaliers',
#   'Y',
#   '00'],
#  [1628365,
#   'Fultz, Markelle',
#   'Markelle Fultz',
#   1,
#   '2017',
#   '2019',
#   'markelle_fultz',
#   1610612753,
#   'Orlando',
#   'Magic',
#   'ORL',
#   'magic',
#   'Y',
#   '00'],
#  [201568,
#   'Gallinari, Danilo',
#   'Danilo Gallinari',
#   1,
#   '2008',
#   '2019',
#   'danilo_gallinari',
#   1610612746,
#   'LA',
#   'Clippers',
#   'LAC',
#   'clippers',
#   'Y',
#   '00'],
#  [204038,
#   'Galloway, Langston',
#   'Langston Galloway',
#   1,
#   '2014',
#   '2019',
#   'langston_galloway',
#   1610612765,
#   'Detroit',
#   'Pistons',
#   'DET',
#   'pistons',
#   'Y',
#   '01'],
#  [1628656,
#   'Garrett, Billy',
#   'Billy Garrett',
#   1,
#   '2018',
#   '2018',
#   'billy_garrett',
#   1610612752,
#   'New York',
#   'Knicks',
#   'NYK',
#   'knicks',
#   'Y',
#   '11'],
#  [201188,
#   'Gasol, Marc',
#   'Marc Gasol',
#   1,
#   '2008',
#   '2019',
#   'marc_gasol',
#   1610612761,
#   'Toronto',
#   'Raptors',
#   'TOR',
#   'raptors',
#   'Y',
#   '00'],
#  [2200,
#   'Gasol, Pau',
#   'Pau Gasol',
#   1,
#   '2001',
#   '2019',
#   'pau_gasol',
#   1610612749,
#   'Milwaukee',
#   'Bucks',
#   'MIL',
#   'bucks',
#   'Y',
#   '00'],
#  [200752,
#   'Gay, Rudy',
#   'Rudy Gay',
#   1,
#   '2006',
#   '2019',
#   'rudy_gay',
#   1610612759,
#   'San Antonio',
#   'Spurs',
#   'SAS',
#   'spurs',
#   'Y',
#   '00'],
#  [202331,
#   'George, Paul',
#   'Paul George',
#   1,
#   '2010',
#   '2019',
#   'paul_george',
#   1610612760,
#   'Oklahoma City',
#   'Thunder',
#   'OKC',
#   'thunder',
#   'Y',
#   '00'],
#  [1626780,
#   'Gibson, Jonathan',
#   'Jonathan Gibson',
#   1,
#   '2016',
#   '2018',
#   'jonathan_gibson',
#   1610612738,
#   'Boston',
#   'Celtics',
#   'BOS',
#   'celtics',
#   'Y',
#   '00'],
#  [201959,
#   'Gibson, Taj',
#   'Taj Gibson',
#   1,
#   '2009',
#   '2019',
#   'taj_gibson',
#   1610612750,
#   'Minnesota',
#   'Timberwolves',
#   'MIN',
#   'timberwolves',
#   'Y',
#   '00'],
#  [1628385,
#   'Giles III, Harry',
#   'Harry Giles III',
#   1,
#   '2017',
#   '2019',
#   'harry_giles',
#   1610612758,
#   'Sacramento',
#   'Kings',
#   'SAC',
#   'kings',
#   'Y',
#   '11'],
#  [1628983,
#   'Gilgeous-Alexander, Shai',
#   'Shai Gilgeous-Alexander',
#   1,
#   '2018',
#   '2019',
#   'shai_gilgeous-alexander',
#   1610612746,
#   'LA',
#   'Clippers',
#   'LAC',
#   'clippers',
#   'Y',
#   '00'],
#  [203497,
#   'Gobert, Rudy',
#   'Rudy Gobert',
#   1,
#   '2013',
#   '2019',
#   'rudy_gobert',
#   1610612762,
#   'Utah',
#   'Jazz',
#   'UTA',
#   'jazz',
#   'Y',
#   '01'],
#  [1629164,
#   'Goodwin, Brandon',
#   'Brandon Goodwin',
#   1,
#   '2018',
#   '2019',
#   'brandon_goodwin',
#   1610612743,
#   'Denver',
#   'Nuggets',
#   'DEN',
#   'nuggets',
#   'Y',
#   '11'],
#  [203932,
#   'Gordon, Aaron',
#   'Aaron Gordon',
#   1,
#   '2014',
#   '2019',
#   'aaron_gordon',
#   1610612753,
#   'Orlando',
#   'Magic',
#   'ORL',
#   'magic',
#   'Y',
#   '00'],
#  [201569,
#   'Gordon, Eric',
#   'Eric Gordon',
#   1,
#   '2008',
#   '2019',
#   'eric_gordon',
#   1610612745,
#   'Houston',
#   'Rockets',
#   'HOU',
#   'rockets',
#   'Y',
#   '00'],
#  [101162,
#   'Gortat, Marcin',
#   'Marcin Gortat',
#   0,
#   '2007',
#   '2018',
#   'marcin_gortat',
#   0,
#   '',
#   '',
#   '',
#   '',
#   'Y',
#   '01'],
#  [1628984,
#   "Graham, Devonte'",
#   "Devonte' Graham",
#   1,
#   '2018',
#   '2019',
#   'devonte_graham',
#   1610612766,
#   'Charlotte',
#   'Hornets',
#   'CHA',
#   'hornets',
#   'Y',
#   '11'],
#  [1626203,
#   'Graham, Treveon',
#   'Treveon Graham',
#   1,
#   '2016',
#   '2019',
#   'treveon_graham',
#   1610612751,
#   'Brooklyn',
#   'Nets',
#   'BKN',
#   'nets',
#   'Y',
#   '11'],
#  [203924,
#   'Grant, Jerami',
#   'Jerami Grant',
#   1,
#   '2014',
#   '2019',
#   'jerami_grant',
#   1610612760,
#   'Oklahoma City',
#   'Thunder',
#   'OKC',
#   'thunder',
#   'Y',
#   '00'],
#  [1626170,
#   'Grant, Jerian',
#   'Jerian Grant',
#   1,
#   '2015',
#   '2018',
#   'jerian_grant',
#   1610612753,
#   'Orlando',
#   'Magic',
#   'ORL',
#   'magic',
#   'Y',
#   '01'],
#  [1629055,
#   'Grantham, Donte',
#   'Donte Grantham',
#   1,
#   '2018',
#   '2019',
#   'donte_grantham',
#   1610612760,
#   'Oklahoma City',
#   'Thunder',
#   'OKC',
#   'thunder',
#   'Y',
#   '11'],
#  [201980,
#   'Green, Danny',
#   'Danny Green',
#   1,
#   '2009',
#   '2019',
#   'danny_green',
#   1610612761,
#   'Toronto',
#   'Raptors',
#   'TOR',
#   'raptors',
#   'Y',
#   '01'],
#  [203110,
#   'Green, Draymond',
#   'Draymond Green',
#   1,
#   '2012',
#   '2019',
#   'draymond_green',
#   1610612744,
#   'Golden State',
#   'Warriors',
#   'GSW',
#   'warriors',
#   'Y',
#   '00'],
#  [101123,
#   'Green, Gerald',
#   'Gerald Green',
#   1,
#   '2005',
#   '2019',
#   'gerald_green',
#   1610612745,
#   'Houston',
#   'Rockets',
#   'HOU',
#   'rockets',
#   'Y',
#   '01'],
#  [203210,
#   'Green, JaMychal',
#   'JaMychal Green',
#   1,
#   '2014',
#   '2019',
#   'jamychal_green',
#   1610612746,
#   'LA',
#   'Clippers',
#   'LAC',
#   'clippers',
#   'Y',
#   '01'],
#  [201145,
#   'Green, Jeff',
#   'Jeff Green',
#   1,
#   '2007',
#   '2019',
#   'jeff_green',
#   1610612764,
#   'Washington',
#   'Wizards',
#   'WAS',
#   'wizards',
#   'Y',
#   '00'],
#  [201933,
#   'Griffin, Blake',
#   'Blake Griffin',
#   1,
#   '2009',
#   '2019',
#   'blake_griffin',
#   1610612765,
#   'Detroit',
#   'Pistons',
#   'DET',
#   'pistons',
#   'Y',
#   '00'],
#  [1627772,
#   'Hamilton, Daniel',
#   'Daniel Hamilton',
#   0,
#   '2017',
#   '2019',
#   'daniel_hamilton',
#   0,
#   '',
#   '',
#   '',
#   '',
#   'Y',
#   '11'],
#  [1628605,
#   'Hannahs, Dusty',
#   'Dusty Hannahs',
#   0,
#   '2018',
#   '2018',
#   'dusty_hannahs',
#   0,
#   '',
#   '',
#   '',
#   '',
#   'Y',
#   '11'],
#  [203501,
#   'Hardaway Jr., Tim',
#   'Tim Hardaway Jr.',
#   1,
#   '2013',
#   '2019',
#   'tim_hardaway jr.',
#   1610612742,
#   'Dallas',
#   'Mavericks',
#   'DAL',
#   'mavericks',
#   'Y',
#   '01'],
#  [201935,
#   'Harden, James',
#   'James Harden',
#   1,
#   '2009',
#   '2019',
#   'james_harden',
#   1610612745,
#   'Houston',
#   'Rockets',
#   'HOU',
#   'rockets',
#   'Y',
#   '00'],
#  [203090,
#   'Harkless, Maurice',
#   'Maurice Harkless',
#   1,
#   '2012',
#   '2019',
#   'maurice_harkless',
#   1610612757,
#   'Portland',
#   'Trail Blazers',
#   'POR',
#   'blazers',
#   'Y',
#   '00'],
#  [1626149,
#   'Harrell, Montrezl',
#   'Montrezl Harrell',
#   1,
#   '2015',
#   '2019',
#   'montrezl_harrell',
#   1610612746,
#   'LA',
#   'Clippers',
#   'LAC',
#   'clippers',
#   'Y',
#   '01'],
#  [2734,
#   'Harris, Devin',
#   'Devin Harris',
#   1,
#   '2004',
#   '2018',
#   'devin_harris',
#   1610612742,
#   'Dallas',
#   'Mavericks',
#   'DAL',
#   'mavericks',
#   'Y',
#   '00'],
#  [203914,
#   'Harris, Gary',
#   'Gary Harris',
#   1,
#   '2014',
#   '2019',
#   'gary_harris',
#   1610612743,
#   'Denver',
#   'Nuggets',
#   'DEN',
#   'nuggets',
#   'Y',
#   '00'],
#  [203925,
#   'Harris, Joe',
#   'Joe Harris',
#   1,
#   '2014',
#   '2019',
#   'joe_harris',
#   1610612751,
#   'Brooklyn',
#   'Nets',
#   'BKN',
#   'nets',
#   'Y',
#   '01'],
#  [202699,
#   'Harris, Tobias',
#   'Tobias Harris',
#   1,
#   '2011',
#   '2019',
#   'tobias_harris',
#   1610612755,
#   'Philadelphia',
#   '76ers',
#   'PHI',
#   'sixers',
#   'Y',
#   '00'],
#  [1626150,
#   'Harrison, Andrew',
#   'Andrew Harrison',
#   0,
#   '2016',
#   '2019',
#   'andrew_harrison',
#   0,
#   '',
#   '',
#   '',
#   '',
#   'Y',
#   '01'],
#  [1627885,
#   'Harrison, Shaquille',
#   'Shaquille Harrison',
#   1,
#   '2017',
#   '2019',
#   'shaquille_harrison',
#   1610612741,
#   'Chicago',
#   'Bulls',
#   'CHI',
#   'bulls',
#   'Y',
#   '01'],
#  [1628404,
#   'Hart, Josh',
#   'Josh Hart',
#   1,
#   '2017',
#   '2019',
#   'josh_hart',
#   1610612747,
#   'Los Angeles',
#   'Lakers',
#   'LAL',
#   'lakers',
#   'Y',
#   '01'],
#  [1628392,
#   'Hartenstein, Isaiah',
#   'Isaiah Hartenstein',
#   1,
#   '2018',
#   '2019',
#   'isaiah_hartenstein',
#   1610612745,
#   'Houston',
#   'Rockets',
#   'HOU',
#   'rockets',
#   'Y',
#   '11'],
#  [2617,
#   'Haslem, Udonis',
#   'Udonis Haslem',
#   1,
#   '2003',
#   '2019',
#   'udonis_haslem',
#   1610612748,
#   'Miami',
#   'Heat',
#   'MIA',
#   'heat',
#   'Y',
#   '00'],
#  [202330,
#   'Hayward, Gordon',
#   'Gordon Hayward',
#   1,
#   '2010',
#   '2019',
#   'gordon_hayward',
#   1610612738,
#   'Boston',
#   'Celtics',
#   'BOS',
#   'celtics',
#   'Y',
#   '00'],
#  [203089,
#   'Henson, John',
#   'John Henson',
#   1,
#   '2012',
#   '2019',
#   'john_henson',
#   1610612739,
#   'Cleveland',
#   'Cavaliers',
#   'CLE',
#   'cavaliers',
#   'Y',
#   '00'],
#  [1627823,
#   'Hernangomez, Juancho',
#   'Juancho Hernangomez',
#   1,
#   '2016',
#   '2019',
#   'juan_hernangomez',
#   1610612743,
#   'Denver',
#   'Nuggets',
#   'DEN',
#   'nuggets',
#   'Y',
#   '01'],
#  [1626195,
#   'Hernangomez, Willy',
#   'Willy Hernangomez',
#   1,
#   '2016',
#   '2019',
#   'willy_hernangomez',
#   1610612766,
#   'Charlotte',
#   'Hornets',
#   'CHA',
#   'hornets',
#   'Y',
#   '00'],
#  [1626209,
#   'Hezonja, Mario',
#   'Mario Hezonja',
#   1,
#   '2015',
#   '2019',
#   'mario_hezonja',
#   1610612752,
#   'New York',
#   'Knicks',
#   'NYK',
#   'knicks',
#   'Y',
#   '00'],
#  [1628439,
#   'Hicks, Isaiah',
#   'Isaiah Hicks',
#   1,
#   '2017',
#   '2018',
#   'isaiah_hicks',
#   1610612752,
#   'New York',
#   'Knicks',
#   'NYK',
#   'knicks',
#   'Y',
#   '11'],
#  [1627741,
#   'Hield, Buddy',
#   'Buddy Hield',
#   1,
#   '2016',
#   '2019',
#   'buddy_hield',
#   1610612758,
#   'Sacramento',
#   'Kings',
#   'SAC',
#   'kings',
#   'Y',
#   '00'],
#  [1629312,
#   'Highsmith, Haywood',
#   'Haywood Highsmith',
#   1,
#   '2018',
#   '2019',
#   'haywood_highsmith',
#   1610612755,
#   'Philadelphia',
#   '76ers',
#   'PHI',
#   'sixers',
#   'Y',
#   '11'],
#  [2403,
#   'Nene',
#   'Nene',
#   1,
#   '2002',
#   '2019',
#   'nene_hilario',
#   1610612745,
#   'Houston',
#   'Rockets',
#   'HOU',
#   'rockets',
#   'Y',
#   '00'],
#  [201588,
#   'Hill, George',
#   'George Hill',
#   1,
#   '2008',
#   '2019',
#   'george_hill',
#   1610612749,
#   'Milwaukee',
#   'Bucks',
#   'MIL',
#   'bucks',
#   'Y',
#   '00'],
#  [203524,
#   'Hill, Solomon',
#   'Solomon Hill',
#   1,
#   '2013',
#   '2019',
#   'solomon_hill',
#   1610612740,
#   'New Orleans',
#   'Pelicans',
#   'NOP',
#   'pelicans',
#   'Y',
#   '01'],
#  [1628988,
#   'Holiday, Aaron',
#   'Aaron Holiday',
#   1,
#   '2018',
#   '2019',
#   'aaron_holiday',
#   1610612754,
#   'Indiana',
#   'Pacers',
#   'IND',
#   'pacers',
#   'Y',
#   '00'],
#  [201950,
#   'Holiday, Jrue',
#   'Jrue Holiday',
#   1,
#   '2009',
#   '2019',
#   'jrue_holiday',
#   1610612740,
#   'New Orleans',
#   'Pelicans',
#   'NOP',
#   'pelicans',
#   'Y',
#   '00'],
#  [203200,
#   'Holiday, Justin',
#   'Justin Holiday',
#   1,
#   '2012',
#   '2019',
#   'justin_holiday',
#   1610612763,
#   'Memphis',
#   'Grizzlies',
#   'MEM',
#   'grizzlies',
#   'Y',
#   '01'],
#  [204066,
#   'Holland, John',
#   'John Holland',
#   0,
#   '2015',
#   '2018',
#   'john_holland',
#   0,
#   '',
#   '',
#   '',
#   '',
#   'Y',
#   '11'],
#  [1626178,
#   'Hollis-Jefferson, Rondae',
#   'Rondae Hollis-Jefferson',
#   1,
#   '2015',
#   '2019',
#   'rondae_hollis-jefferson',
#   1610612751,
#   'Brooklyn',
#   'Nets',
#   'BKN',
#   'nets',
#   'Y',
#   '00'],
#  [1626158,
#   'Holmes, Richaun',
#   'Richaun Holmes',
#   1,
#   '2015',
#   '2019',
#   'richaun_holmes',
#   1610612756,
#   'Phoenix',
#   'Suns',
#   'PHX',
#   'suns',
#   'Y',
#   '01'],
#  [203918,
#   'Hood, Rodney',
#   'Rodney Hood',
#   1,
#   '2014',
#   '2019',
#   'rodney_hood',
#   1610612757,
#   'Portland',
#   'Trail Blazers',
#   'POR',
#   'blazers',
#   'Y',
#   '00'],
#  [201143,
#   'Horford, Al',
#   'Al Horford',
#   1,
#   '2007',
#   '2019',
#   'al_horford',
#   1610612738,
#   'Boston',
#   'Celtics',
#   'BOS',
#   'celtics',
#   'Y',
#   '00'],
#  [1627863,
#   'House Jr., Danuel',
#   'Danuel House Jr.',
#   1,
#   '2016',
#   '2019',
#   'danuel_house',
#   1610612745,
#   'Houston',
#   'Rockets',
#   'HOU',
#   'rockets',
#   'Y',
#   '11'],
#  [2730,
#   'Howard, Dwight',
#   'Dwight Howard',
#   1,
#   '2004',
#   '2019',
#   'dwight_howard',
#   1610612764,
#   'Washington',
#   'Wizards',
#   'WAS',
#   'wizards',
#   'Y',
#   '00'],
#  [1628989,
#   'Huerter, Kevin',
#   'Kevin Huerter',
#   1,
#   '2018',
#   '2019',
#   'kevin_huerter',
#   1610612737,
#   'Atlanta',
#   'Hawks',
#   'ATL',
#   'hawks',
#   'Y',
#   '00'],
#  [1629353,
#   'Humphries, Isaac',
#   'Isaac Humphries',
#   1,
#   '2018',
#   '2019',
#   'isaac_humphries',
#   1610612737,
#   'Atlanta',
#   'Hawks',
#   'ATL',
#   'hawks',
#   'Y',
#   '11'],
#  [1626154,
#   'Hunter, RJ',
#   'RJ Hunter',
#   1,
#   '2015',
#   '2018',
#   'rj_hunter',
#   1610612738,
#   'Boston',
#   'Celtics',
#   'BOS',
#   'celtics',
#   'Y',
#   '11'],
#  [1628990,
#   'Hutchison, Chandler',
#   'Chandler Hutchison',
#   1,
#   '2018',
#   '2019',
#   'chandler_hutchison',
#   1610612741,
#   'Chicago',
#   'Bulls',
#   'CHI',
#   'bulls',
#   'Y',
#   '00'],
#  [201586,
#   'Ibaka, Serge',
#   'Serge Ibaka',
#   1,
#   '2009',
#   '2019',
#   'serge_ibaka',
#   1610612761,
#   'Toronto',
#   'Raptors',
#   'TOR',
#   'raptors',
#   'Y',
#   '00'],
#  [2738,
#   'Iguodala, Andre',
#   'Andre Iguodala',
#   1,
#   '2004',
#   '2019',
#   'andre_iguodala',
#   1610612744,
#   'Golden State',
#   'Warriors',
#   'GSW',
#   'warriors',
#   'Y',
#   '00'],
#  [101141,
#   'Ilyasova, Ersan',
#   'Ersan Ilyasova',
#   1,
#   '2006',
#   '2019',
#   'ersan_ilyasova',
#   1610612749,
#   'Milwaukee',
#   'Bucks',
#   'MIL',
#   'bucks',
#   'Y',
#   '01'],
#  [204060,
#   'Ingles, Joe',
#   'Joe Ingles',
#   1,
#   '2014',
#   '2019',
#   'joe_ingles',
#   1610612762,
#   'Utah',
#   'Jazz',
#   'UTA',
#   'jazz',
#   'Y',
#   '00'],
#  [201281,
#   'Ingram, Andre',
#   'Andre Ingram',
#   0,
#   '2017',
#   '2018',
#   'andre_ingram',
#   0,
#   '',
#   '',
#   '',
#   '',
#   'Y',
#   '11'],
#  [1627742,
#   'Ingram, Brandon',
#   'Brandon Ingram',
#   1,
#   '2016',
#   '2019',
#   'brandon_ingram',
#   1610612747,
#   'Los Angeles',
#   'Lakers',
#   'LAL',
#   'lakers',
#   'Y',
#   '00'],
#  [202681,
#   'Irving, Kyrie',
#   'Kyrie Irving',
#   1,
#   '2011',
#   '2019',
#   'kyrie_irving',
#   1610612738,
#   'Boston',
#   'Celtics',
#   'BOS',
#   'celtics',
#   'Y',
#   '00'],
#  [1628371,
#   'Isaac, Jonathan',
#   'Jonathan Isaac',
#   1,
#   '2017',
#   '2019',
#   'jonathan_isaac',
#   1610612753,
#   'Orlando',
#   'Magic',
#   'ORL',
#   'magic',
#   'Y',
#   '01'],
#  [1628411,
#   'Iwundu, Wes',
#   'Wes Iwundu',
#   1,
#   '2017',
#   '2019',
#   'wes_iwundu',
#   1610612753,
#   'Orlando',
#   'Magic',
#   'ORL',
#   'magic',
#   'Y',
#   '01'],
#  [1627743,
#   'Jackson, Demetrius',
#   'Demetrius Jackson',
#   0,
#   '2016',
#   '2019',
#   'demetrius_jackson',
#   0,
#   '',
#   '',
#   '',
#   '',
#   'Y',
#   '11'],
#  [1628402,
#   'Jackson, Frank',
#   'Frank Jackson',
#   1,
#   '2017',
#   '2019',
#   'frank_jackson',
#   1610612740,
#   'New Orleans',
#   'Pelicans',
#   'NOP',
#   'pelicans',
#   'Y',
#   '11'],
#  [1628367,
#   'Jackson, Josh',
#   'Josh Jackson',
#   1,
#   '2017',
#   '2019',
#   'josh_jackson',
#   1610612756,
#   'Phoenix',
#   'Suns',
#   'PHX',
#   'suns',
#   'Y',
#   '00'],
#  [1628382,
#   'Jackson, Justin',
#   'Justin Jackson',
#   1,
#   '2017',
#   '2019',
#   'justin_jackson',
#   1610612742,
#   'Dallas',
#   'Mavericks',
#   'DAL',
#   'mavericks',
#   'Y',
#   '01'],
#  [202704,
#   'Jackson, Reggie',
#   'Reggie Jackson',
#   1,
#   '2011',
#   '2019',
#   'reggie_jackson',
#   1610612765,
#   'Detroit',
#   'Pistons',
#   'DET',
#   'pistons',
#   'Y',
#   '01'],
#  [1628991,
#   'Jackson Jr., Jaren',
#   'Jaren Jackson Jr.',
#   1,
#   '2018',
#   '2019',
#   'jaren_jackson_jr',
#   1610612763,
#   'Memphis',
#   'Grizzlies',
#   'MEM',
#   'grizzlies',
#   'Y',
#   '00'],
#  [2544,
#   'James, LeBron',
#   'LeBron James',
#   1,
#   '2003',
#   '2019',
#   'lebron_james',
#   1610612747,
#   'Los Angeles',
#   'Lakers',
#   'LAL',
#   'lakers',
#   'Y',
#   '00'],
#  [1628518,
#   'Jefferson, Amile',
#   'Amile Jefferson',
#   1,
#   '2017',
#   '2019',
#   'amile_jefferson',
#   1610612753,
#   'Orlando',
#   'Magic',
#   'ORL',
#   'magic',
#   'Y',
#   '11'],
#  [203098,
#   'Jenkins, John',
#   'John Jenkins',
#   1,
#   '2012',
#   '2018',
#   'john_jenkins',
#   1610612752,
#   'New York',
#   'Knicks',
#   'NYK',
#   'knicks',
#   'Y',
#   '11'],
#  [201973,
#   'Jerebko, Jonas',
#   'Jonas Jerebko',
#   1,
#   '2009',
#   '2018',
#   'jonas_jerebko',
#   1610612744,
#   'Golden State',
#   'Warriors',
#   'GSW',
#   'warriors',
#   'Y',
#   '00'],
#  [1628993,
#   'Johnson, Alize',
#   'Alize Johnson',
#   1,
#   '2018',
#   '2019',
#   'alize_johnson',
#   1610612754,
#   'Indiana',
#   'Pacers',
#   'IND',
#   'pacers',
#   'Y',
#   '11'],
#  [101161,
#   'Johnson, Amir',
#   'Amir Johnson',
#   1,
#   '2005',
#   '2018',
#   'amir_johnson',
#   1610612755,
#   'Philadelphia',
#   '76ers',
#   'PHI',
#   'sixers',
#   'Y',
#   '11'],
#  [1629168,
#   'Johnson, BJ',
#   'BJ Johnson',
#   1,
#   '2018',
#   '2019',
#   'bj_johnson',
#   1610612758,
#   'Sacramento',
#   'Kings',
#   'SAC',
#   'kings',
#   'Y',
#   '11'],
#  [201949,
#   'Johnson, James',
#   'James Johnson',
#   1,
#   '2009',
#   '2019',
#   'james_johnson',
#   1610612748,
#   'Miami',
#   'Heat',
#   'MIA',
#   'heat',
#   'Y',
#   '01'],
#  [1626169,
#   'Johnson, Stanley',
#   'Stanley Johnson',
#   1,
#   '2015',
#   '2019',
#   'stanley_johnson',
#   1610612740,
#   'New Orleans',
#   'Pelicans',
#   'NOP',
#   'pelicans',
#   'Y',
#   '01'],
#  [204020,
#   'Johnson, Tyler',
#   'Tyler Johnson',
#   1,
#   '2014',
#   '2019',
#   'tyler_johnson',
#   1610612756,
#   'Phoenix',
#   'Suns',
#   'PHX',
#   'suns',
#   'Y',
#   '01'],
#  [202325,
#   'Johnson, Wesley',
#   'Wesley Johnson',
#   1,
#   '2010',
#   '2018',
#   'wesley_johnson',
#   1610612764,
#   'Washington',
#   'Wizards',
#   'WAS',
#   'wizards',
#   'Y',
#   '00'],
#  [203999,
#   'Jokic, Nikola',
#   'Nikola Jokic',
#   1,
#   '2015',
#   '2019',
#   'nikola_jokic',
#   1610612743,
#   'Denver',
#   'Nuggets',
#   'DEN',
#   'nuggets',
#   'Y',
#   '00'],
#  [1627745,
#   'Jones, Damian',
#   'Damian Jones',
#   1,
#   '2016',
#   '2019',
#   'damian_jones',
#   1610612744,
#   'Golden State',
#   'Warriors',
#   'GSW',
#   'warriors',
#   'Y',
#   '01'],
#  [1627883,
#   'Jones, Jalen',
#   'Jalen Jones',
#   0,
#   '2017',
#   '2019',
#   'jalen_jones',
#   0,
#   '',
#   '',
#   '',
#   '',
#   'Y',
#   '11'],
#  [1629203,
#   'Jones, Jemerrio',
#   'Jemerrio Jones',
#   1,
#   '2018',
#   '2018',
#   'jemerrio_jones',
#   1610612747,
#   'Los Angeles',
#   'Lakers',
#   'LAL',
#   'lakers',
#   'Y',
#   '11'],
#  [203093,
#   'Jones, Terrence',
#   'Terrence Jones',
#   0,
#   '2012',
#   '2018',
#   'terrence_jones',
#   0,
#   '',
#   '',
#   '',
#   '',
#   'Y',
#   '11'],
#  [1626145,
#   'Jones, Tyus',
#   'Tyus Jones',
#   1,
#   '2015',
#   '2019',
#   'tyus_jones',
#   1610612750,
#   'Minnesota',
#   'Timberwolves',
#   'MIN',
#   'timberwolves',
#   'Y',
#   '01'],
#  [1627884,
#   'Jones Jr., Derrick',
#   'Derrick Jones Jr.',
#   1,
#   '2016',
#   '2019',
#   'derrick_jones jr.',
#   1610612748,
#   'Miami',
#   'Heat',
#   'MIA',
#   'heat',
#   'Y',
#   '01'],
#  [201599,
#   'Jordan, DeAndre',
#   'DeAndre Jordan',
#   1,
#   '2008',
#   '2019',
#   'deandre_jordan',
#   1610612752,
#   'New York',
#   'Knicks',
#   'NYK',
#   'knicks',
#   'Y',
#   '00'],
#  [202709,
#   'Joseph, Cory',
#   'Cory Joseph',
#   1,
#   '2011',
#   '2019',
#   'cory_joseph',
#   1610612754,
#   'Indiana',
#   'Pacers',
#   'IND',
#   'pacers',
#   'Y',
#   '01'],
#  [1626163,
#   'Kaminsky, Frank',
#   'Frank Kaminsky',
#   1,
#   '2015',
#   '2019',
#   'frank_kaminsky',
#   1610612766,
#   'Charlotte',
#   'Hornets',
#   'CHA',
#   'hornets',
#   'Y',
#   '00'],
#  [202683,
#   'Kanter, Enes',
#   'Enes Kanter',
#   1,
#   '2011',
#   '2019',
#   'enes_kanter',
#   1610612757,
#   'Portland',
#   'Trail Blazers',
#   'POR',
#   'blazers',
#   'Y',
#   '00'],
#  [1628379,
#   'Kennard, Luke',
#   'Luke Kennard',
#   1,
#   '2017',
#   '2019',
#   'luke_kennard',
#   1610612765,
#   'Detroit',
#   'Pistons',
#   'DET',
#   'pistons',
#   'Y',
#   '11'],
#  [203077,
# ...
#   'jakarr_sampson',
#   0,
#   '',
#   '',
#   '',
#   '',
#   'Y',
#   '11'],
#  [203967,
#   'Saric, Dario',
#   'Dario Saric',
#   1,
#   '2016',
#   '2019',
#   'dario_saric',
#   1610612750,
#   'Minnesota',
#   'Timberwolves',
#   'MIN',
#   'timberwolves',
#   'Y',
#   '00'],
#  [203107,
#   'Satoransky, Tomas',
#   'Tomas Satoransky',
#   1,
#   '2016',
#   '2019',
#   'tomas_satoransky',
#   1610612764,
#   'Washington',
#   'Wizards',
#   'WAS',
#   'wizards',
#   'Y',
#   '00'],
#  [203471,
#   'Schroder, Dennis',
#   'Dennis Schroder',
#   1,
#   '2013',
#   '2019',
#   'dennis_schroder',
#   1610612760,
#   'Oklahoma City',
#   'Thunder',
#   'OKC',
#   'thunder',
#   'Y',
#   '01'],
#  [203118,
#   'Scott, Mike',
#   'Mike Scott',
#   1,
#   '2012',
#   '2019',
#   'mike_scott',
#   1610612755,
#   'Philadelphia',
#   '76ers',
#   'PHI',
#   'sixers',
#   'Y',
#   '01'],
#  [200757,
#   'Sefolosha, Thabo',
#   'Thabo Sefolosha',
#   1,
#   '2006',
#   '2019',
#   'thabo_sefolosha',
#   1610612762,
#   'Utah',
#   'Jazz',
#   'UTA',
#   'jazz',
#   'Y',
#   '00'],
#  [1627782,
#   'Selden, Wayne',
#   'Wayne Selden',
#   1,
#   '2016',
#   '2018',
#   'wayne_selden',
#   1610612741,
#   'Chicago',
#   'Bulls',
#   'CHI',
#   'bulls',
#   'Y',
#   '01'],
#  [1629012,
#   'Sexton, Collin',
#   'Collin Sexton',
#   1,
#   '2018',
#   '2019',
#   'collin_sexton',
#   1610612739,
#   'Cleveland',
#   'Cavaliers',
#   'CLE',
#   'cavaliers',
#   'Y',
#   '00'],
#  [1629013,
#   'Shamet, Landry',
#   'Landry Shamet',
#   1,
#   '2018',
#   '2019',
#   'landry_shamet',
#   1610612746,
#   'LA',
#   'Clippers',
#   'LAC',
#   'clippers',
#   'Y',
#   '00'],
#  [202697,
#   'Shumpert, Iman',
#   'Iman Shumpert',
#   1,
#   '2011',
#   '2018',
#   'iman_shumpert',
#   1610612745,
#   'Houston',
#   'Rockets',
#   'HOU',
#   'rockets',
#   'Y',
#   '00'],
#  [1627783,
#   'Siakam, Pascal',
#   'Pascal Siakam',
#   1,
#   '2016',
#   '2019',
#   'pascal_siakam',
#   1610612761,
#   'Toronto',
#   'Raptors',
#   'TOR',
#   'raptors',
#   'Y',
#   '01'],
#  [1626296,
#   'Sibert, Jordan',
#   'Jordan Sibert',
#   0,
#   '2018',
#   '2018',
#   'jordan_sibert',
#   0,
#   '',
#   '',
#   '',
#   '',
#   'Y',
#   '11'],
#  [1627732,
#   'Simmons, Ben',
#   'Ben Simmons',
#   1,
#   '2016',
#   '2019',
#   'ben_simmons',
#   1610612755,
#   'Philadelphia',
#   '76ers',
#   'PHI',
#   'sixers',
#   'Y',
#   '00'],
#  [203613,
#   'Simmons, Jonathon',
#   'Jonathon Simmons',
#   1,
#   '2015',
#   '2018',
#   'jonathon_simmons',
#   1610612755,
#   'Philadelphia',
#   '76ers',
#   'PHI',
#   'sixers',
#   'Y',
#   '01'],
#  [1628424,
#   'Simmons, Kobi',
#   'Kobi Simmons',
#   0,
#   '2017',
#   '2019',
#   'kobi_simmons',
#   0,
#   '',
#   '',
#   '',
#   '',
#   'Y',
#   '11'],
#  [1629014,
#   'Simons, Anfernee',
#   'Anfernee Simons',
#   1,
#   '2018',
#   '2019',
#   'anfernee_simons',
#   1610612757,
#   'Portland',
#   'Trail Blazers',
#   'POR',
#   'blazers',
#   'Y',
#   '11'],
#  [203935,
#   'Smart, Marcus',
#   'Marcus Smart',
#   1,
#   '2014',
#   '2019',
#   'marcus_smart',
#   1610612738,
#   'Boston',
#   'Celtics',
#   'BOS',
#   'celtics',
#   'Y',
#   '01'],
#  [202397,
#   'Smith, Ish',
#   'Ish Smith',
#   1,
#   '2010',
#   '2019',
#   'ish_smith',
#   1610612765,
#   'Detroit',
#   'Pistons',
#   'DET',
#   'pistons',
#   'Y',
#   '01'],
#  [2747,
#   'Smith, JR',
#   'JR Smith',
#   1,
#   '2004',
#   '2018',
#   'jr_smith',
#   1610612739,
#   'Cleveland',
#   'Cavaliers',
#   'CLE',
#   'cavaliers',
#   'Y',
#   '00'],
#  [201160,
#   'Smith, Jason',
#   'Jason Smith',
#   0,
#   '2007',
#   '2018',
#   'jason_smith',
#   0,
#   '',
#   '',
#   '',
#   '',
#   'Y',
#   '00'],
#  [1629015,
#   'Smith, Zhaire',
#   'Zhaire Smith',
#   1,
#   '2018',
#   '2019',
#   'zhaire_smith',
#   1610612755,
#   'Philadelphia',
#   '76ers',
#   'PHI',
#   'sixers',
#   'Y',
#   '11'],
#  [1628372,
#   'Smith Jr., Dennis',
#   'Dennis Smith Jr.',
#   1,
#   '2017',
#   '2019',
#   'dennis_smith jr.',
#   1610612752,
#   'New York',
#   'Knicks',
#   'NYK',
#   'knicks',
#   'Y',
#   '00'],
#  [203503,
#   'Snell, Tony',
#   'Tony Snell',
#   1,
#   '2013',
#   '2019',
#   'tony_snell',
#   1610612749,
#   'Milwaukee',
#   'Bucks',
#   'MIL',
#   'bucks',
#   'Y',
#   '00'],
#  [1629034,
#   'Spalding, Ray',
#   'Ray Spalding',
#   1,
#   '2018',
#   '2019',
#   'ray_spalding',
#   1610612756,
#   'Phoenix',
#   'Suns',
#   'PHX',
#   'suns',
#   'Y',
#   '11'],
#  [1629016,
#   'Spellman, Omari',
#   'Omari Spellman',
#   1,
#   '2018',
#   '2019',
#   'omari_spellman',
#   1610612737,
#   'Atlanta',
#   'Hawks',
#   'ATL',
#   'hawks',
#   'Y',
#   '11'],
#  [203917,
#   'Stauskas, Nik',
#   'Nik Stauskas',
#   1,
#   '2014',
#   '2018',
#   'nik_stauskas',
#   1610612739,
#   'Cleveland',
#   'Cavaliers',
#   'CLE',
#   'cavaliers',
#   'Y',
#   '00'],
#  [203474,
#   'Stephens, DJ',
#   'DJ Stephens',
#   0,
#   '2013',
#   '2018',
#   'dj_stephens',
#   0,
#   '',
#   '',
#   '',
#   '',
#   'Y',
#   '11'],
#  [202362,
#   'Stephenson, Lance',
#   'Lance Stephenson',
#   1,
#   '2010',
#   '2018',
#   'lance_stephenson',
#   1610612747,
#   'Los Angeles',
#   'Lakers',
#   'LAL',
#   'lakers',
#   'Y',
#   '00'],
#  [1628410,
#   'Sumner, Edmond',
#   'Edmond Sumner',
#   1,
#   '2017',
#   '2019',
#   'edmond_sumner',
#   1610612754,
#   'Indiana',
#   'Pacers',
#   'IND',
#   'pacers',
#   'Y',
#   '11'],
#  [1628403,
#   'Swanigan, Caleb',
#   'Caleb Swanigan',
#   1,
#   '2017',
#   '2019',
#   'caleb_swanigan',
#   1610612758,
#   'Sacramento',
#   'Kings',
#   'SAC',
#   'kings',
#   'Y',
#   '11'],
#  [1628369,
#   'Tatum, Jayson',
#   'Jayson Tatum',
#   1,
#   '2017',
#   '2019',
#   'jayson_tatum',
#   1610612738,
#   'Boston',
#   'Celtics',
#   'BOS',
#   'celtics',
#   'Y',
#   '00'],
#  [201952,
#   'Teague, Jeff',
#   'Jeff Teague',
#   1,
#   '2009',
#   '2019',
#   'jeff_teague',
#   1610612750,
#   'Minnesota',
#   'Timberwolves',
#   'MIN',
#   'timberwolves',
#   'Y',
#   '00'],
#  [202066,
#   'Temple, Garrett',
#   'Garrett Temple',
#   1,
#   '2009',
#   '2019',
#   'garrett_temple',
#   1610612746,
#   'LA',
#   'Clippers',
#   'LAC',
#   'clippers',
#   'Y',
#   '01'],
#  [1628462,
#   'Teodosic, Milos',
#   'Milos Teodosic',
#   0,
#   '2017',
#   '2018',
#   'milos_teodosic',
#   0,
#   '',
#   '',
#   '',
#   '',
#   'Y',
#   '00'],
#  [1629123,
#   'Terrell, Jared',
#   'Jared Terrell',
#   1,
#   '2018',
#   '2018',
#   'jared_terrell',
#   1610612750,
#   'Minnesota',
#   'Timberwolves',
#   'MIN',
#   'timberwolves',
#   'Y',
#   '11'],
#  [1629150,
#   'Terry, Emanuel',
#   'Emanuel Terry',
#   0,
#   '2018',
#   '2018',
#   'emanuel_terry',
#   0,
#   '',
#   '',
#   '',
#   '',
#   'Y',
#   '11'],
#  [1628464,
#   'Theis, Daniel',
#   'Daniel Theis',
#   1,
#   '2017',
#   '2019',
#   'daniel_theis',
#   1610612738,
#   'Boston',
#   'Celtics',
#   'BOS',
#   'celtics',
#   'Y',
#   '00'],
#  [202738,
#   'Thomas, Isaiah',
#   'Isaiah Thomas',
#   1,
#   '2011',
#   '2019',
#   'isaiah_thomas',
#   1610612743,
#   'Denver',
#   'Nuggets',
#   'DEN',
#   'nuggets',
#   'Y',
#   '00'],
#  [1629017,
#   'Thomas, Khyri',
#   'Khyri Thomas',
#   1,
#   '2018',
#   '2019',
#   'khyri_thomas',
#   1610612765,
#   'Detroit',
#   'Pistons',
#   'DET',
#   'pistons',
#   'Y',
#   '11'],
#  [202498,
#   'Thomas, Lance',
#   'Lance Thomas',
#   1,
#   '2011',
#   '2019',
#   'lance_thomas',
#   1610612752,
#   'New York',
#   'Knicks',
#   'NYK',
#   'knicks',
#   'Y',
#   '01'],
#  [202691,
#   'Thompson, Klay',
#   'Klay Thompson',
#   1,
#   '2011',
#   '2019',
#   'klay_thompson',
#   1610612744,
#   'Golden State',
#   'Warriors',
#   'GSW',
#   'warriors',
#   'Y',
#   '00'],
#  [202684,
#   'Thompson, Tristan',
#   'Tristan Thompson',
#   1,
#   '2011',
#   '2019',
#   'tristan_thompson',
#   1610612739,
#   'Cleveland',
#   'Cavaliers',
#   'CLE',
#   'cavaliers',
#   'Y',
#   '00'],
#  [1628414,
#   'Thornwell, Sindarius',
#   'Sindarius Thornwell',
#   1,
#   '2017',
#   '2019',
#   'sindarius_thornwell',
#   1610612746,
#   'LA',
#   'Clippers',
#   'LAC',
#   'clippers',
#   'Y',
#   '11'],
#  [201229,
#   'Tolliver, Anthony',
#   'Anthony Tolliver',
#   1,
#   '2008',
#   '2019',
#   'anthony_tolliver',
#   1610612750,
#   'Minnesota',
#   'Timberwolves',
#   'MIN',
#   'timberwolves',
#   'Y',
#   '01'],
#  [1626157,
#   'Towns, Karl-Anthony',
#   'Karl-Anthony Towns',
#   1,
#   '2015',
#   '2019',
#   'karl-anthony_towns',
#   1610612750,
#   'Minnesota',
#   'Timberwolves',
#   'MIN',
#   'timberwolves',
#   'Y',
#   '00'],
#  [1629018,
#   'Trent Jr., Gary',
#   'Gary Trent Jr.',
#   1,
#   '2018',
#   '2019',
#   'tmp_gary_trent',
#   1610612757,
#   'Portland',
#   'Trail Blazers',
#   'POR',
#   'blazers',
#   'Y',
#   '11'],
#  [1629019,
#   'Trier, Allonzo',
#   'Allonzo Trier',
#   1,
#   '2018',
#   '2019',
#   'allonzo_trier',
#   1610612752,
#   'New York',
#   'Knicks',
#   'NYK',
#   'knicks',
#   'Y',
#   '00'],
#  [200782,
#   'Tucker, PJ',
#   'PJ Tucker',
#   1,
#   '2006',
#   '2019',
#   'pj_tucker',
#   1610612745,
#   'Houston',
#   'Rockets',
#   'HOU',
#   'rockets',
#   'Y',
#   '01'],
#  [202323,
#   'Turner, Evan',
#   'Evan Turner',
#   1,
#   '2010',
#   '2019',
#   'evan_turner',
#   1610612757,
#   'Portland',
#   'Trail Blazers',
#   'POR',
#   'blazers',
#   'Y',
#   '00'],
#  [1626167,
#   'Turner, Myles',
#   'Myles Turner',
#   1,
#   '2015',
#   '2019',
#   'myles_turner',
#   1610612754,
#   'Indiana',
#   'Pacers',
#   'IND',
#   'pacers',
#   'Y',
#   '00'],
#  [202327,
#   'Udoh, Ekpe',
#   'Ekpe Udoh',
#   1,
#   '2010',
#   '2018',
#   'ekpe_udoh',
#   1610612762,
#   'Utah',
#   'Jazz',
#   'UTA',
#   'jazz',
#   'Y',
#   '00'],
#  [1627755,
#   'Ulis, Tyler',
#   'Tyler Ulis',
#   0,
#   '2016',
#   '2019',
#   'tyler_ulis',
#   0,
#   '',
#   '',
#   '',
#   '',
#   'Y',
#   '11'],
#  [202685,
#   'Valanciunas, Jonas',
#   'Jonas Valanciunas',
#   1,
#   '2012',
#   '2019',
#   'jonas_valanciunas',
#   1610612763,
#   'Memphis',
#   'Grizzlies',
#   'MEM',
#   'grizzlies',
#   'Y',
#   '00'],
#  [1627832,
#   'VanVleet, Fred',
#   'Fred VanVleet',
#   1,
#   '2016',
#   '2019',
#   'fred_vanvleet',
#   1610612761,
#   'Toronto',
#   'Raptors',
#   'TOR',
#   'raptors',
#   'Y',
#   '01'],
#  [1629020,
#   'Vanderbilt, Jarred',
#   'Jarred Vanderbilt',
#   1,
#   '2018',
#   '2019',
#   'jarred_vanderbilt',
#   1610612743,
#   'Denver',
#   'Nuggets',
#   'DEN',
#   'nuggets',
#   'Y',
#   '11'],
#  [203943,
#   'Vonleh, Noah',
#   'Noah Vonleh',
#   1,
#   '2014',
#   '2019',
#   'noah_vonleh',
#   1610612752,
#   'New York',
#   'Knicks',
#   'NYK',
#   'knicks',
#   'Y',
#   '01'],
#  [202696,
#   'Vucevic, Nikola',
#   'Nikola Vucevic',
#   1,
#   '2011',
#   '2019',
#   'nikola_vucevic',
#   1610612753,
#   'Orlando',
#   'Magic',
#   'ORL',
#   'magic',
#   'Y',
#   '00'],
#  [2548,
#   'Wade, Dwyane',
#   'Dwyane Wade',
#   1,
#   '2003',
#   '2018',
#   'dwyane_wade',
#   1610612748,
#   'Miami',
#   'Heat',
#   'MIA',
#   'heat',
#   'Y',
#   '00'],
#  [1629021,
#   'Wagner, Moritz',
#   'Moritz Wagner',
#   1,
#   '2018',
#   '2019',
#   'moritz_wagner',
#   1610612747,
#   'Los Angeles',
#   'Lakers',
#   'LAL',
#   'lakers',
#   'Y',
#   '11'],
#  [203079,
#   'Waiters, Dion',
#   'Dion Waiters',
#   1,
#   '2012',
#   '2019',
#   'dion_waiters',
#   1610612748,
#   'Miami',
#   'Heat',
#   'MIA',
#   'heat',
#   'Y',
#   '00'],
#  [202689,
#   'Walker, Kemba',
#   'Kemba Walker',
#   1,
#   '2011',
#   '2019',
#   'kemba_walker',
#   1610612766,
#   'Charlotte',
#   'Hornets',
#   'CHA',
#   'hornets',
#   'Y',
#   '00'],
#  [1629022,
#   'Walker IV, Lonnie',
#   'Lonnie Walker IV',
#   1,
#   '2018',
#   '2019',
#   'lonnie_walker',
#   1610612759,
#   'San Antonio',
#   'Spurs',
#   'SAS',
#   'spurs',
#   'Y',
#   '11'],
#  [202322,
#   'Wall, John',
#   'John Wall',
#   1,
#   '2010',
#   '2019',
#   'john_wall',
#   1610612764,
#   'Washington',
#   'Wizards',
#   'WAS',
#   'wizards',
#   'Y',
#   '00'],
#  [1627820,
#   'Wallace, Tyrone',
#   'Tyrone Wallace',
#   1,
#   '2017',
#   '2019',
#   'tyrone_wallace',
#   1610612746,
#   'LA',
#   'Clippers',
#   'LAC',
#   'clippers',
#   'Y',
#   '01'],
#  [202954,
#   'Wanamaker, Brad',
#   'Brad Wanamaker',
#   1,
#   '2018',
#   '2019',
#   'brad_wanamaker',
#   1610612738,
#   'Boston',
#   'Celtics',
#   'BOS',
#   'celtics',
#   'Y',
#   '11'],
#  [203933,
#   'Warren, T.J.',
#   'T.J. Warren',
#   1,
#   '2014',
#   '2019',
#   'tj_warren',
#   1610612756,
#   'Phoenix',
#   'Suns',
#   'PHX',
#   'suns',
#   'Y',
#   '01'],
#  [1627395,
#   'Washburn, Julian',
#   'Julian Washburn',
#   1,
#   '2018',
#   '2018',
#   'julian_washburn',
#   1610612763,
#   'Memphis',
#   'Grizzlies',
#   'MEM',
#   'grizzlies',
#   'Y',
#   '11'],
#  [1629139,
#   'Watanabe, Yuta',
#   'Yuta Watanabe',
#   1,
#   '2018',
#   '2019',
#   'yuta_watanabe',
#   1610612763,
#   'Memphis',
#   'Grizzlies',
#   'MEM',
#   'grizzlies',
#   'Y',
#   '11'],
#  [1629118,
#   'Welsh, Thomas',
#   'Thomas Welsh',
#   1,
#   '2018',
#   '2019',
#   'thomas_welsh',
#   1610612743,
#   'Denver',
#   'Nuggets',
#   'DEN',
#   'nuggets',
#   'Y',
#   '11'],
#  [201566,
#   'Westbrook, Russell',
#   'Russell Westbrook',
#   1,
#   '2008',
#   '2019',
#   'russell_westbrook',
#   1610612760,
#   'Oklahoma City',
#   'Thunder',
#   'OKC',
#   'thunder',
#   'Y',
#   '00'],
#  [1628401,
#   'White, Derrick',
#   'Derrick White',
#   1,
#   '2017',
#   '2019',
#   'derrick_white',
#   1610612759,
#   'San Antonio',
#   'Spurs',
#   'SAS',
#   'spurs',
#   'Y',
#   '01'],
#  [1627855,
#   'White, Okaro',
#   'Okaro White',
#   0,
#   '2016',
#   '2018',
#   'okaro_white',
#   0,
#   '',
#   '',
#   '',
#   '',
#   'Y',
#   '11'],
#  [1627785,
#   'Whitehead, Isaiah',
#   'Isaiah Whitehead',
#   1,
#   '2016',
#   '2018',
#   'isaiah_whitehead',
#   1610612765,
#   'Detroit',
#   'Pistons',
#   'DET',
#   'pistons',
#   'Y',
#   '11'],
#  [202355,
#   'Whiteside, Hassan',
#   'Hassan Whiteside',
#   1,
#   '2010',
#   '2019',
#   'hassan_whiteside',
#   1610612748,
#   'Miami',
#   'Heat',
#   'MIA',
#   'heat',
#   'Y',
#   '01'],
#  [203952,
#   'Wiggins, Andrew',
#   'Andrew Wiggins',
#   1,
#   '2014',
#   '2019',
#   'andrew_wiggins',
#   1610612750,
#   'Minnesota',
#   'Timberwolves',
#   'MIN',
#   'timberwolves',
#   'Y',
#   '00'],
#  [1626210,
#   'Williams, Alan',
#   'Alan Williams',
#   1,
#   '2015',
#   '2018',
#   'alan_williams',
#   1610612751,
#   'Brooklyn',
#   'Nets',
#   'BKN',
#   'nets',
#   'Y',
#   '11'],
#  [203710,
#   'Williams, C.J.',
#   'C.J. Williams',
#   1,
#   '2017',
#   '2019',
#   'c.j._williams',
#   1610612750,
#   'Minnesota',
#   'Timberwolves',
#   'MIN',
#   'timberwolves',
#   'Y',
#   '11'],
#  [1629140,
#   'Williams, Johnathan',
#   'Johnathan Williams',
#   1,
#   '2018',
#   '2018',
#   'johnathan_williams',
#   1610612747,
#   'Los Angeles',
#   'Lakers',
#   'LAL',
#   'lakers',
#   'Y',
#   '11'],
#  [1629026,
#   'Williams, Kenrich',
#   'Kenrich Williams',
#   1,
#   '2018',
#   '2019',
#   'kenrich_williams',
#   1610612740,
#   'New Orleans',
#   'Pelicans',
#   'NOP',
#   'pelicans',
#   'Y',
#   '11'],
#  [101150,
#   'Williams, Lou',
#   'Lou Williams',
#   1,
#   '2005',
#   '2019',
#   'lou_williams',
#   1610612746,
#   'LA',
#   'Clippers',
#   'LAC',
#   'clippers',
#   'Y',
#   '01'],
#  [101107,
#   'Williams, Marvin',
#   'Marvin Williams',
#   1,
#   '2005',
#   '2019',
#   'marvin_williams',
#   1610612766,
#   'Charlotte',
#   'Hornets',
#   'CHA',
#   'hornets',
#   'Y',
#   '00'],
#  [1627786,
#   'Williams, Troy',
#   'Troy Williams',
#   1,
#   '2016',
#   '2018',
#   'troy_williams',
#   1610612758,
#   'Sacramento',
#   'Kings',
#   'SAC',
#   'kings',
#   'Y',
#   '11'],
#  [1629057,
#   'Williams III, Robert',
#   'Robert Williams III',
#   1,
#   '2018',
#   '2019',
#   'robert_williams',
#   1610612738,
#   'Boston',
#   'Celtics',
#   'BOS',
#   'celtics',
#   'Y',
#   '11'],
#  [1628391,
#   'Wilson, D.J.',
#   'D.J. Wilson',
#   1,
#   '2017',
#   '2019',
#   'd.j._wilson',
#   1610612749,
#   'Milwaukee',
#   'Bucks',
#   'MIL',
#   'bucks',
#   'Y',
#   '11'],
#  [1626159,
#   'Winslow, Justise',
#   'Justise Winslow',
#   1,
#   '2015',
#   '2019',
#   'justise_winslow',
#   1610612748,
#   'Miami',
#   'Heat',
#   'MIA',
#   'heat',
#   'Y',
#   '00'],
#  [1626174,
#   'Wood, Christian',
#   'Christian Wood',
#   1,
#   '2015',
#   '2019',
#   'christian_wood',
#   1610612740,
#   'New Orleans',
#   'Pelicans',
#   'NOP',
#   'pelicans',
#   'Y',
#   '11'],
#  [1626153,
#   'Wright, Delon',
#   'Delon Wright',
#   1,
#   '2015',
#   '2019',
#   'delon_wright',
#   1610612763,
#   'Memphis',
#   'Grizzlies',
#   'MEM',
#   'grizzlies',
#   'Y',
#   '01'],
#  [1627824,
#   'Yabusele, Guerschon',
#   'Guerschon Yabusele',
#   1,
#   '2017',
#   '2018',
#   'guerschon_yabusele',
#   1610612738,
#   'Boston',
#   'Celtics',
#   'BOS',
#   'celtics',
#   'Y',
#   '11'],
#  [201156,
#   'Young, Nick',
#   'Nick Young',
#   0,
#   '2007',
#   '2018',
#   'nick_young',
#   0,
#   '',
#   '',
#   '',
#   '',
#   'Y',
#   '00'],
#  [201152,
#   'Young, Thaddeus',
#   'Thaddeus Young',
#   1,
#   '2007',
#   '2019',
#   'thaddeus_young',
#   1610612754,
#   'Indiana',
#   'Pacers',
#   'IND',
#   'pacers',
#   'Y',
#   '00'],
#  [1629027,
#   'Young, Trae',
#   'Trae Young',
#   1,
#   '2018',
#   '2019',
#   'trae_young',
#   1610612737,
#   'Atlanta',
#   'Hawks',
#   'ATL',
#   'hawks',
#   'Y',
#   '00'],
#  [203469,
#   'Zeller, Cody',
#   'Cody Zeller',
#   1,
#   '2013',
#   '2019',
#   'cody_zeller',
#   1610612766,
#   'Charlotte',
#   'Hornets',
#   'CHA',
#   'hornets',
#   'Y',
#   '00'],
#  [203092,
#   'Zeller, Tyler',
#   'Tyler Zeller',
#   1,
#   '2012',
#   '2019',
#   'tyler_zeller',
#   1610612763,
#   'Memphis',
#   'Grizzlies',
#   'MEM',
#   'grizzlies',
#   'Y',
#   '00'],
#  [1627790,
#   'Zizic, Ante',
#   'Ante Zizic',
#   1,
#   '2017',
#   '2019',
#   'ante_zizic',
#   1610612739,
#   'Cleveland',
#   'Cavaliers',
#   'CLE',
#   'cavaliers',
#   'Y',
#   '01'],
#  [1627826,
#   'Zubac, Ivica',
#   'Ivica Zubac',
#   1,
#   '2016',
#   '2019',
#   'ivica_zubac',
#   1610612746,
#   'LA',
#   'Clippers',
#   'LAC',
#   'clippers',
#   'Y',
#   '01']]

# %%
for player in playerdata:
    document = {
        'id' : player[0],
        'name_last_first' : player[1],
        'full_name' : player[2],
        'roster_status' : player[3],
        'from_year' : player[4],
        'to_year' : player[5],
        'player_code' : player[6],
        'team_id' : player[7],
        'team_city' : player[8],
        'team_name' : player[9],
        'team_abbreviation' : player[10],
        'team_code' : player[11],
        'games_played_bool' : player[12],
        'other_league_exp' : player[13]
    }
    
    db.active_players_copy.update({'id':document['id']}, document, True)
# Out:
# /Users/andrew/anaconda3/envs/bootcamp/lib/python3.7/site-packages/ipykernel_launcher.py:19: DeprecationWarning: update is deprecated. Use replace_one, update_one or update_many instead.

# %%
db.active_players_copy.delete_many({"team_id": 0})

# %%
db.active_players_copy.count_documents({"team_id": 0})
# Out:
# 0

# %%
for player in db.active_players_copy.find():
    print(player)
# Out:
# {'_id': ObjectId('5da78671c40d54eedfe4a33c'), 'id': 1629121, 'name_last_first': 'Adams, Jaylen', 'full_name': 'Jaylen Adams', 'roster_status': 1, 'from_year': '2018', 'to_year': '2019', 'player_code': 'jaylen_adams', 'team_id': 1610612737, 'team_city': 'Atlanta', 'team_name': 'Hawks', 'team_abbreviation': 'ATL', 'team_code': 'hawks', 'games_played_bool': 'Y', 'other_league_exp': '11'}
# {'_id': ObjectId('5da78671c40d54eedfe4a348'), 'id': 203500, 'name_last_first': 'Adams, Steven', 'full_name': 'Steven Adams', 'roster_status': 1, 'from_year': '2013', 'to_year': '2019', 'player_code': 'steven_adams', 'team_id': 1610612760, 'team_city': 'Oklahoma City', 'team_name': 'Thunder', 'team_abbreviation': 'OKC', 'team_code': 'thunder', 'games_played_bool': 'Y', 'other_league_exp': '00'}
# {'_id': ObjectId('5da78671c40d54eedfe4a353'), 'id': 1628389, 'name_last_first': 'Adebayo, Bam', 'full_name': 'Bam Adebayo', 'roster_status': 1, 'from_year': '2017', 'to_year': '2019', 'player_code': 'bam_adebayo', 'team_id': 1610612748, 'team_city': 'Miami', 'team_name': 'Heat', 'team_abbreviation': 'MIA', 'team_code': 'heat', 'games_played_bool': 'Y', 'other_league_exp': '00'}
# {'_id': ObjectId('5da78671c40d54eedfe4a361'), 'id': 1629061, 'name_last_first': 'Adel, Deng', 'full_name': 'Deng Adel', 'roster_status': 1, 'from_year': '2018', 'to_year': '2018', 'player_code': 'deng_adel', 'team_id': 1610612739, 'team_city': 'Cleveland', 'team_name': 'Cavaliers', 'team_abbreviation': 'CLE', 'team_code': 'cavaliers', 'games_played_bool': 'Y', 'other_league_exp': '11'}
# {'_id': ObjectId('5da78671c40d54eedfe4a377'), 'id': 200746, 'name_last_first': 'Aldridge, LaMarcus', 'full_name': 'LaMarcus Aldridge', 'roster_status': 1, 'from_year': '2006', 'to_year': '2019', 'player_code': 'lamarcus_aldridge', 'team_id': 1610612759, 'team_city': 'San Antonio', 'team_name': 'Spurs', 'team_abbreviation': 'SAS', 'team_code': 'spurs', 'games_played_bool': 'Y', 'other_league_exp': '00'}
# {'_id': ObjectId('5da78671c40d54eedfe4a382'), 'id': 1628959, 'name_last_first': 'Alkins, Rawle', 'full_name': 'Rawle Alkins', 'roster_status': 1, 'from_year': '2018', 'to_year': '2018', 'player_code': 'rawle_alkins', 'team_id': 1610612741, 'team_city': 'Chicago', 'team_name': 'Bulls', 'team_abbreviation': 'CHI', 'team_code': 'bulls', 'games_played_bool': 'Y', 'other_league_exp': '11'}
# {'_id': ObjectId('5da78671c40d54eedfe4a38e'), 'id': 1628960, 'name_last_first': 'Allen, Grayson', 'full_name': 'Grayson Allen', 'roster_status': 1, 'from_year': '2018', 'to_year': '2019', 'player_code': 'grayson_allen', 'team_id': 1610612762, 'team_city': 'Utah', 'team_name': 'Jazz', 'team_abbreviation': 'UTA', 'team_code': 'jazz', 'games_played_bool': 'Y', 'other_league_exp': '11'}
# {'_id': ObjectId('5da78671c40d54eedfe4a39b'), 'id': 1628386, 'name_last_first': 'Allen, Jarrett', 'full_name': 'Jarrett Allen', 'roster_status': 1, 'from_year': '2017', 'to_year': '2019', 'player_code': 'jarrett_allen', 'team_id': 1610612751, 'team_city': 'Brooklyn', 'team_name': 'Nets', 'team_abbreviation': 'BKN', 'team_code': 'nets', 'games_played_bool': 'Y', 'other_league_exp': '00'}
# {'_id': ObjectId('5da78671c40d54eedfe4a3a6'), 'id': 1628443, 'name_last_first': 'Allen, Kadeem', 'full_name': 'Kadeem Allen', 'roster_status': 1, 'from_year': '2017', 'to_year': '2019', 'player_code': 'kadeem_allen', 'team_id': 1610612752, 'team_city': 'New York', 'team_name': 'Knicks', 'team_abbreviation': 'NYK', 'team_code': 'knicks', 'games_played_bool': 'Y', 'other_league_exp': '11'}
# {'_id': ObjectId('5da78672c40d54eedfe4a3b3'), 'id': 202329, 'name_last_first': 'Aminu, Al-Farouq', 'full_name': 'Al-Farouq Aminu', 'roster_status': 1, 'from_year': '2010', 'to_year': '2019', 'player_code': 'al-farouq_aminu', 'team_id': 1610612757, 'team_city': 'Portland', 'team_name': 'Trail Blazers', 'team_abbreviation': 'POR', 'team_code': 'blazers', 'games_played_bool': 'Y', 'other_league_exp': '00'}
# {'_id': ObjectId('5da78672c40d54eedfe4a3be'), 'id': 1626147, 'name_last_first': 'Anderson, Justin', 'full_name': 'Justin Anderson', 'roster_status': 1, 'from_year': '2015', 'to_year': '2018', 'player_code': 'justin_anderson', 'team_id': 1610612737, 'team_city': 'Atlanta', 'team_name': 'Hawks', 'team_abbreviation': 'ATL', 'team_code': 'hawks', 'games_played_bool': 'Y', 'other_league_exp': '01'}
# {'_id': ObjectId('5da78672c40d54eedfe4a3ca'), 'id': 203937, 'name_last_first': 'Anderson, Kyle', 'full_name': 'Kyle Anderson', 'roster_status': 1, 'from_year': '2014', 'to_year': '2019', 'player_code': 'kyle_anderson', 'team_id': 1610612763, 'team_city': 'Memphis', 'team_name': 'Grizzlies', 'team_abbreviation': 'MEM', 'team_code': 'grizzlies', 'games_played_bool': 'Y', 'other_league_exp': '01'}
# {'_id': ObjectId('5da78672c40d54eedfe4a3d5'), 'id': 201583, 'name_last_first': 'Anderson, Ryan', 'full_name': 'Ryan Anderson', 'roster_status': 1, 'from_year': '2008', 'to_year': '2019', 'player_code': 'ryan_anderson', 'team_id': 1610612748, 'team_city': 'Miami', 'team_name': 'Heat', 'team_abbreviation': 'MIA', 'team_code': 'heat', 'games_played_bool': 'Y', 'other_league_exp': '00'}
# {'_id': ObjectId('5da78672c40d54eedfe4a3ec'), 'id': 203507, 'name_last_first': 'Antetokounmpo, Giannis', 'full_name': 'Giannis Antetokounmpo', 'roster_status': 1, 'from_year': '2013', 'to_year': '2019', 'player_code': 'giannis_antetokounmpo', 'team_id': 1610612749, 'team_city': 'Milwaukee', 'team_name': 'Bucks', 'team_abbreviation': 'MIL', 'team_code': 'bucks', 'games_played_bool': 'Y', 'other_league_exp': '00'}
# {'_id': ObjectId('5da78672c40d54eedfe4a403'), 'id': 1628961, 'name_last_first': 'Antetokounmpo, Kostas', 'full_name': 'Kostas Antetokounmpo', 'roster_status': 1, 'from_year': '2018', 'to_year': '2019', 'player_code': 'kostas_antetokounmpo', 'team_id': 1610612742, 'team_city': 'Dallas', 'team_name': 'Mavericks', 'team_abbreviation': 'DAL', 'team_code': 'mavericks', 'games_played_bool': 'Y', 'other_league_exp': '11'}
# {'_id': ObjectId('5da78672c40d54eedfe4a419'), 'id': 1628384, 'name_last_first': 'Anunoby, OG', 'full_name': 'OG Anunoby', 'roster_status': 1, 'from_year': '2017', 'to_year': '2019', 'player_code': 'og_anunoby', 'team_id': 1610612761, 'team_city': 'Toronto', 'team_name': 'Raptors', 'team_abbreviation': 'TOR', 'team_code': 'raptors', 'games_played_bool': 'Y', 'other_league_exp': '00'}
# {'_id': ObjectId('5da78672c40d54eedfe4a424'), 'id': 1627853, 'name_last_first': 'Arcidiacono, Ryan', 'full_name': 'Ryan Arcidiacono', 'roster_status': 1, 'from_year': '2017', 'to_year': '2019', 'player_code': 'ryan_arcidiacono', 'team_id': 1610612741, 'team_city': 'Chicago', 'team_name': 'Bulls', 'team_abbreviation': 'CHI', 'team_code': 'bulls', 'games_played_bool': 'Y', 'other_league_exp': '01'}
# {'_id': ObjectId('5da78672c40d54eedfe4a431'), 'id': 2772, 'name_last_first': 'Ariza, Trevor', 'full_name': 'Trevor Ariza', 'roster_status': 1, 'from_year': '2004', 'to_year': '2019', 'player_code': 'trevor_ariza', 'team_id': 1610612764, 'team_city': 'Washington', 'team_name': 'Wizards', 'team_abbreviation': 'WAS', 'team_code': 'wizards', 'games_played_bool': 'Y', 'other_league_exp': '00'}
# {'_id': ObjectId('5da78672c40d54eedfe4a447'), 'id': 201571, 'name_last_first': 'Augustin, D.J.', 'full_name': 'D.J. Augustin', 'roster_status': 1, 'from_year': '2008', 'to_year': '2019', 'player_code': 'd.j._augustin', 'team_id': 1610612753, 'team_city': 'Orlando', 'team_name': 'Magic', 'team_abbreviation': 'ORL', 'team_code': 'magic', 'games_played_bool': 'Y', 'other_league_exp': '00'}
# {'_id': ObjectId('5da78672c40d54eedfe4a453'), 'id': 1629028, 'name_last_first': 'Ayton, Deandre', 'full_name': 'Deandre Ayton', 'roster_status': 1, 'from_year': '2018', 'to_year': '2019', 'player_code': 'deandre_ayton', 'team_id': 1610612756, 'team_city': 'Phoenix', 'team_name': 'Suns', 'team_abbreviation': 'PHX', 'team_code': 'suns', 'games_played_bool': 'Y', 'other_league_exp': '00'}
# {'_id': ObjectId('5da78672c40d54eedfe4a45e'), 'id': 1628407, 'name_last_first': 'Bacon, Dwayne', 'full_name': 'Dwayne Bacon', 'roster_status': 1, 'from_year': '2017', 'to_year': '2019', 'player_code': 'dwayne_bacon', 'team_id': 1610612766, 'team_city': 'Charlotte', 'team_name': 'Hornets', 'team_abbreviation': 'CHA', 'team_code': 'hornets', 'games_played_bool': 'Y', 'other_league_exp': '11'}
# {'_id': ObjectId('5da78672c40d54eedfe4a46a'), 'id': 1628963, 'name_last_first': 'Bagley III, Marvin', 'full_name': 'Marvin Bagley III', 'roster_status': 1, 'from_year': '2018', 'to_year': '2019', 'player_code': 'marvin_bagley_iii', 'team_id': 1610612758, 'team_city': 'Sacramento', 'team_name': 'Kings', 'team_abbreviation': 'SAC', 'team_code': 'kings', 'games_played_bool': 'Y', 'other_league_exp': '00'}
# {'_id': ObjectId('5da78672c40d54eedfe4a48c'), 'id': 1628366, 'name_last_first': 'Ball, Lonzo', 'full_name': 'Lonzo Ball', 'roster_status': 1, 'from_year': '2017', 'to_year': '2019', 'player_code': 'lonzo_ball', 'team_id': 1610612747, 'team_city': 'Los Angeles', 'team_name': 'Lakers', 'team_abbreviation': 'LAL', 'team_code': 'lakers', 'games_played_bool': 'Y', 'other_league_exp': '00'}
# {'_id': ObjectId('5da78672c40d54eedfe4a497'), 'id': 1628964, 'name_last_first': 'Bamba, Mo', 'full_name': 'Mo Bamba', 'roster_status': 1, 'from_year': '2018', 'to_year': '2019', 'player_code': 'mohamed_bamba', 'team_id': 1610612753, 'team_city': 'Orlando', 'team_name': 'Magic', 'team_abbreviation': 'ORL', 'team_code': 'magic', 'games_played_bool': 'Y', 'other_league_exp': '00'}
# {'_id': ObjectId('5da78672c40d54eedfe4a4a4'), 'id': 200826, 'name_last_first': 'Barea, J.J.', 'full_name': 'J.J. Barea', 'roster_status': 1, 'from_year': '2006', 'to_year': '2019', 'player_code': 'j.j._barea', 'team_id': 1610612742, 'team_city': 'Dallas', 'team_name': 'Mavericks', 'team_abbreviation': 'DAL', 'team_code': 'mavericks', 'games_played_bool': 'Y', 'other_league_exp': '01'}
# {'_id': ObjectId('5da78672c40d54eedfe4a4b1'), 'id': 203084, 'name_last_first': 'Barnes, Harrison', 'full_name': 'Harrison Barnes', 'roster_status': 1, 'from_year': '2012', 'to_year': '2019', 'player_code': 'harrison_barnes', 'team_id': 1610612758, 'team_city': 'Sacramento', 'team_name': 'Kings', 'team_abbreviation': 'SAC', 'team_code': 'kings', 'games_played_bool': 'Y', 'other_league_exp': '00'}
# {'_id': ObjectId('5da78672c40d54eedfe4a4bc'), 'id': 203115, 'name_last_first': 'Barton, Will', 'full_name': 'Will Barton', 'roster_status': 1, 'from_year': '2012', 'to_year': '2019', 'player_code': 'will_barton', 'team_id': 1610612743, 'team_city': 'Denver', 'team_name': 'Nuggets', 'team_abbreviation': 'DEN', 'team_code': 'nuggets', 'games_played_bool': 'Y', 'other_league_exp': '01'}
# {'_id': ObjectId('5da78672c40d54eedfe4a4c8'), 'id': 1628966, 'name_last_first': 'Bates-Diop, Keita', 'full_name': 'Keita Bates-Diop', 'roster_status': 1, 'from_year': '2018', 'to_year': '2019', 'player_code': 'keita_bates-diop', 'team_id': 1610612750, 'team_city': 'Minnesota', 'team_name': 'Timberwolves', 'team_abbreviation': 'MIN', 'team_code': 'timberwolves', 'games_played_bool': 'Y', 'other_league_exp': '11'}
# {'_id': ObjectId('5da78672c40d54eedfe4a4d3'), 'id': 201587, 'name_last_first': 'Batum, Nicolas', 'full_name': 'Nicolas Batum', 'roster_status': 1, 'from_year': '2008', 'to_year': '2019', 'player_code': 'nicolas_batum', 'team_id': 1610612766, 'team_city': 'Charlotte', 'team_name': 'Hornets', 'team_abbreviation': 'CHA', 'team_code': 'hornets', 'games_played_bool': 'Y', 'other_league_exp': '00'}
# {'_id': ObjectId('5da78672c40d54eedfe4a4de'), 'id': 201573, 'name_last_first': 'Bayless, Jerryd', 'full_name': 'Jerryd Bayless', 'roster_status': 1, 'from_year': '2008', 'to_year': '2018', 'player_code': 'jerryd_bayless', 'team_id': 1610612750, 'team_city': 'Minnesota', 'team_name': 'Timberwolves', 'team_abbreviation': 'MIN', 'team_code': 'timberwolves', 'games_played_bool': 'Y', 'other_league_exp': '00'}
# {'_id': ObjectId('5da78673c40d54eedfe4a4e9'), 'id': 203382, 'name_last_first': 'Baynes, Aron', 'full_name': 'Aron Baynes', 'roster_status': 1, 'from_year': '2012', 'to_year': '2019', 'player_code': 'aron_baynes', 'team_id': 1610612738, 'team_city': 'Boston', 'team_name': 'Celtics', 'team_abbreviation': 'BOS', 'team_code': 'celtics', 'games_played_bool': 'Y', 'other_league_exp': '01'}
# {'_id': ObjectId('5da78673c40d54eedfe4a4f4'), 'id': 203145, 'name_last_first': 'Bazemore, Kent', 'full_name': 'Kent Bazemore', 'roster_status': 1, 'from_year': '2012', 'to_year': '2019', 'player_code': 'kent_bazemore', 'team_id': 1610612737, 'team_city': 'Atlanta', 'team_name': 'Hawks', 'team_abbreviation': 'ATL', 'team_code': 'hawks', 'games_played_bool': 'Y', 'other_league_exp': '01'}
# {'_id': ObjectId('5da78673c40d54eedfe4a4ff'), 'id': 203078, 'name_last_first': 'Beal, Bradley', 'full_name': 'Bradley Beal', 'roster_status': 1, 'from_year': '2012', 'to_year': '2019', 'player_code': 'bradley_beal', 'team_id': 1610612764, 'team_city': 'Washington', 'team_name': 'Wizards', 'team_abbreviation': 'WAS', 'team_code': 'wizards', 'games_played_bool': 'Y', 'other_league_exp': '00'}
# {'_id': ObjectId('5da78673c40d54eedfe4a50a'), 'id': 1627736, 'name_last_first': 'Beasley, Malik', 'full_name': 'Malik Beasley', 'roster_status': 1, 'from_year': '2016', 'to_year': '2019', 'player_code': 'malik_beasley', 'team_id': 1610612743, 'team_city': 'Denver', 'team_name': 'Nuggets', 'team_abbreviation': 'DEN', 'team_code': 'nuggets', 'games_played_bool': 'Y', 'other_league_exp': '01'}
# {'_id': ObjectId('5da78673c40d54eedfe4a521'), 'id': 201158, 'name_last_first': 'Belinelli, Marco', 'full_name': 'Marco Belinelli', 'roster_status': 1, 'from_year': '2007', 'to_year': '2019', 'player_code': 'marco_belinelli', 'team_id': 1610612759, 'team_city': 'San Antonio', 'team_name': 'Spurs', 'team_abbreviation': 'SAS', 'team_code': 'spurs', 'games_played_bool': 'Y', 'other_league_exp': '00'}
# {'_id': ObjectId('5da78673c40d54eedfe4a52c'), 'id': 1628395, 'name_last_first': 'Bell, Jordan', 'full_name': 'Jordan Bell', 'roster_status': 1, 'from_year': '2017', 'to_year': '2019', 'player_code': 'jordan_bell', 'team_id': 1610612744, 'team_city': 'Golden State', 'team_name': 'Warriors', 'team_abbreviation': 'GSW', 'team_code': 'warriors', 'games_played_bool': 'Y', 'other_league_exp': '01'}
# {'_id': ObjectId('5da78673c40d54eedfe4a537'), 'id': 1627761, 'name_last_first': "Bembry, DeAndre'", 'full_name': "DeAndre' Bembry", 'roster_status': 1, 'from_year': '2016', 'to_year': '2019', 'player_code': "deandre'_bembry", 'team_id': 1610612737, 'team_city': 'Atlanta', 'team_name': 'Hawks', 'team_abbreviation': 'ATL', 'team_code': 'hawks', 'games_played_bool': 'Y', 'other_league_exp': '01'}
# {'_id': ObjectId('5da78673c40d54eedfe4a542'), 'id': 1627733, 'name_last_first': 'Bender, Dragan', 'full_name': 'Dragan Bender', 'roster_status': 1, 'from_year': '2016', 'to_year': '2019', 'player_code': 'dragan_bender', 'team_id': 1610612756, 'team_city': 'Phoenix', 'team_name': 'Suns', 'team_abbreviation': 'PHX', 'team_code': 'suns', 'games_played_bool': 'Y', 'other_league_exp': '00'}
# {'_id': ObjectId('5da78673c40d54eedfe4a54e'), 'id': 1629541, 'name_last_first': 'Bertans, Dairis', 'full_name': 'Dairis Bertans', 'roster_status': 1, 'from_year': '2018', 'to_year': '2018', 'player_code': 'tmp_dairis_bertans', 'team_id': 1610612740, 'team_city': 'New Orleans', 'team_name': 'Pelicans', 'team_abbreviation': 'NOP', 'team_code': 'pelicans', 'games_played_bool': 'Y', 'other_league_exp': '00'}
# {'_id': ObjectId('5da78673c40d54eedfe4a55a'), 'id': 202722, 'name_last_first': 'Bertans, Davis', 'full_name': 'Davis Bertans', 'roster_status': 1, 'from_year': '2016', 'to_year': '2019', 'player_code': 'davis_bertans', 'team_id': 1610612759, 'team_city': 'San Antonio', 'team_name': 'Spurs', 'team_abbreviation': 'SAS', 'team_code': 'spurs', 'games_played_bool': 'Y', 'other_league_exp': '01'}
# {'_id': ObjectId('5da78673c40d54eedfe4a56a'), 'id': 201976, 'name_last_first': 'Beverley, Patrick', 'full_name': 'Patrick Beverley', 'roster_status': 1, 'from_year': '2012', 'to_year': '2019', 'player_code': 'patrick_beverley', 'team_id': 1610612746, 'team_city': 'LA', 'team_name': 'Clippers', 'team_abbreviation': 'LAC', 'team_code': 'clippers', 'games_played_bool': 'Y', 'other_league_exp': '01'}
# {'_id': ObjectId('5da78673c40d54eedfe4a575'), 'id': 1629167, 'full_name': 'Justin Bibbs', 'first_name': 'Justin', 'last_name': 'Bibbs', 'is_active': True}
# {'_id': ObjectId('5da78673c40d54eedfe4a582'), 'id': 203920, 'name_last_first': 'Birch, Khem', 'full_name': 'Khem Birch', 'roster_status': 1, 'from_year': '2017', 'to_year': '2019', 'player_code': 'khem_birch', 'team_id': 1610612753, 'team_city': 'Orlando', 'team_name': 'Magic', 'team_abbreviation': 'ORL', 'team_code': 'magic', 'games_played_bool': 'Y', 'other_league_exp': '01'}
# {'_id': ObjectId('5da78673c40d54eedfe4a58e'), 'id': 202687, 'name_last_first': 'Biyombo, Bismack', 'full_name': 'Bismack Biyombo', 'roster_status': 1, 'from_year': '2011', 'to_year': '2019', 'player_code': 'bismack_biyombo', 'team_id': 1610612766, 'team_city': 'Charlotte', 'team_name': 'Hornets', 'team_abbreviation': 'CHA', 'team_code': 'hornets', 'games_played_bool': 'Y', 'other_league_exp': '00'}
# {'_id': ObjectId('5da78673c40d54eedfe4a599'), 'id': 202357, 'name_last_first': 'Bjelica, Nemanja', 'full_name': 'Nemanja Bjelica', 'roster_status': 1, 'from_year': '2015', 'to_year': '2019', 'player_code': 'nemanja_bjelica', 'team_id': 1610612758, 'team_city': 'Sacramento', 'team_name': 'Kings', 'team_abbreviation': 'SAC', 'team_code': 'kings', 'games_played_bool': 'Y', 'other_league_exp': '00'}
# {'_id': ObjectId('5da78673c40d54eedfe4a5af'), 'id': 1628469, 'name_last_first': 'Blakeney, Antonio', 'full_name': 'Antonio Blakeney', 'roster_status': 1, 'from_year': '2017', 'to_year': '2018', 'player_code': 'antonio_blakeney', 'team_id': 1610612741, 'team_city': 'Chicago', 'team_name': 'Bulls', 'team_abbreviation': 'CHI', 'team_code': 'bulls', 'games_played_bool': 'Y', 'other_league_exp': '11'}
# {'_id': ObjectId('5da78673c40d54eedfe4a5bc'), 'id': 202339, 'name_last_first': 'Bledsoe, Eric', 'full_name': 'Eric Bledsoe', 'roster_status': 1, 'from_year': '2010', 'to_year': '2019', 'player_code': 'eric_bledsoe', 'team_id': 1610612749, 'team_city': 'Milwaukee', 'team_name': 'Bucks', 'team_abbreviation': 'MIL', 'team_code': 'bucks', 'games_played_bool': 'Y', 'other_league_exp': '01'}
# {'_id': ObjectId('5da78673c40d54eedfe4a5c7'), 'id': 1628417, 'name_last_first': 'Blossomgame, Jaron', 'full_name': 'Jaron Blossomgame', 'roster_status': 1, 'from_year': '2018', 'to_year': '2018', 'player_code': 'jaron_blossomgame', 'team_id': 1610612739, 'team_city': 'Cleveland', 'team_name': 'Cavaliers', 'team_abbreviation': 'CLE', 'team_code': 'cavaliers', 'games_played_bool': 'Y', 'other_league_exp': '11'}
# {'_id': ObjectId('5da78673c40d54eedfe4a5d3'), 'id': 1629129, 'name_last_first': 'Bluiett, Trevon', 'full_name': 'Trevon Bluiett', 'roster_status': 1, 'from_year': '2018', 'to_year': '2018', 'player_code': 'trevon_bluiett', 'team_id': 1610612740, 'team_city': 'New Orleans', 'team_name': 'Pelicans', 'team_abbreviation': 'NOP', 'team_code': 'pelicans', 'games_played_bool': 'Y', 'other_league_exp': '11'}
# {'_id': ObjectId('5da78673c40d54eedfe4a5de'), 'id': 203992, 'name_last_first': 'Bogdanovic, Bogdan', 'full_name': 'Bogdan Bogdanovic', 'roster_status': 1, 'from_year': '2017', 'to_year': '2019', 'player_code': 'bogdan_bogdanovic', 'team_id': 1610612758, 'team_city': 'Sacramento', 'team_name': 'Kings', 'team_abbreviation': 'SAC', 'team_code': 'kings', 'games_played_bool': 'Y', 'other_league_exp': '00'}
# {'_id': ObjectId('5da78673c40d54eedfe4a5e9'), 'id': 202711, 'name_last_first': 'Bogdanovic, Bojan', 'full_name': 'Bojan Bogdanovic', 'roster_status': 1, 'from_year': '2014', 'to_year': '2019', 'player_code': 'bojan_bogdanovic', 'team_id': 1610612754, 'team_city': 'Indiana', 'team_name': 'Pacers', 'team_abbreviation': 'IND', 'team_code': 'pacers', 'games_played_bool': 'Y', 'other_league_exp': '00'}
# {'_id': ObjectId('5da78673c40d54eedfe4a600'), 'id': 101106, 'name_last_first': 'Bogut, Andrew', 'full_name': 'Andrew Bogut', 'roster_status': 1, 'from_year': '2005', 'to_year': '2018', 'player_code': 'andrew_bogut', 'team_id': 1610612744, 'team_city': 'Golden State', 'team_name': 'Warriors', 'team_abbreviation': 'GSW', 'team_code': 'warriors', 'games_played_bool': 'Y', 'other_league_exp': '00'}
# {'_id': ObjectId('5da78673c40d54eedfe4a60c'), 'id': 1628413, 'name_last_first': 'Bolden, Jonah', 'full_name': 'Jonah Bolden', 'roster_status': 1, 'from_year': '2018', 'to_year': '2019', 'player_code': 'jonah_bolden', 'team_id': 1610612755, 'team_city': 'Philadelphia', 'team_name': '76ers', 'team_abbreviation': 'PHI', 'team_code': 'sixers', 'games_played_bool': 'Y', 'other_league_exp': '11'}
# {'_id': ObjectId('5da78673c40d54eedfe4a619'), 'id': 1629067, 'name_last_first': 'Bonga, Isaac', 'full_name': 'Isaac Bonga', 'roster_status': 1, 'from_year': '2018', 'to_year': '2019', 'player_code': 'isaac_bonga', 'team_id': 1610612747, 'team_city': 'Los Angeles', 'team_name': 'Lakers', 'team_abbreviation': 'LAL', 'team_code': 'lakers', 'games_played_bool': 'Y', 'other_league_exp': '11'}
# {'_id': ObjectId('5da78674c40d54eedfe4a625'), 'id': 1626164, 'name_last_first': 'Booker, Devin', 'full_name': 'Devin Booker', 'roster_status': 1, 'from_year': '2015', 'to_year': '2019', 'player_code': 'devin_booker', 'team_id': 1610612756, 'team_city': 'Phoenix', 'team_name': 'Suns', 'team_abbreviation': 'PHX', 'team_code': 'suns', 'games_played_bool': 'Y', 'other_league_exp': '00'}
# {'_id': ObjectId('5da78674c40d54eedfe4a630'), 'id': 1628449, 'name_last_first': 'Boucher, Chris', 'full_name': 'Chris Boucher', 'roster_status': 1, 'from_year': '2017', 'to_year': '2019', 'player_code': 'chris_boucher', 'team_id': 1610612761, 'team_city': 'Toronto', 'team_name': 'Raptors', 'team_abbreviation': 'TOR', 'team_code': 'raptors', 'games_played_bool': 'Y', 'other_league_exp': '11'}
# {'_id': ObjectId('5da78674c40d54eedfe4a63c'), 'id': 202340, 'name_last_first': 'Bradley, Avery', 'full_name': 'Avery Bradley', 'roster_status': 1, 'from_year': '2010', 'to_year': '2019', 'player_code': 'avery_bradley', 'team_id': 1610612763, 'team_city': 'Memphis', 'team_name': 'Grizzlies', 'team_abbreviation': 'MEM', 'team_code': 'grizzlies', 'games_played_bool': 'Y', 'other_league_exp': '01'}
# {'_id': ObjectId('5da78674c40d54eedfe4a647'), 'id': 1628396, 'name_last_first': 'Bradley, Tony', 'full_name': 'Tony Bradley', 'roster_status': 1, 'from_year': '2017', 'to_year': '2019', 'player_code': 'tony_bradley', 'team_id': 1610612762, 'team_city': 'Utah', 'team_name': 'Jazz', 'team_abbreviation': 'UTA', 'team_code': 'jazz', 'games_played_bool': 'Y', 'other_league_exp': '11'}
# {'_id': ObjectId('5da78674c40d54eedfe4a652'), 'id': 201147, 'name_last_first': 'Brewer, Corey', 'full_name': 'Corey Brewer', 'roster_status': 1, 'from_year': '2007', 'to_year': '2018', 'player_code': 'corey_brewer', 'team_id': 1610612758, 'team_city': 'Sacramento', 'team_name': 'Kings', 'team_abbreviation': 'SAC', 'team_code': 'kings', 'games_played_bool': 'Y', 'other_league_exp': '00'}
# {'_id': ObjectId('5da78674c40d54eedfe4a65d'), 'id': 1628969, 'name_last_first': 'Bridges, Mikal', 'full_name': 'Mikal Bridges', 'roster_status': 1, 'from_year': '2018', 'to_year': '2019', 'player_code': 'mikal_bridges', 'team_id': 1610612756, 'team_city': 'Phoenix', 'team_name': 'Suns', 'team_abbreviation': 'PHX', 'team_code': 'suns', 'games_played_bool': 'Y', 'other_league_exp': '00'}
# {'_id': ObjectId('5da78674c40d54eedfe4a66b'), 'id': 1628970, 'name_last_first': 'Bridges, Miles', 'full_name': 'Miles Bridges', 'roster_status': 1, 'from_year': '2018', 'to_year': '2019', 'player_code': 'miles_bridges', 'team_id': 1610612766, 'team_city': 'Charlotte', 'team_name': 'Hornets', 'team_abbreviation': 'CHA', 'team_code': 'hornets', 'games_played_bool': 'Y', 'other_league_exp': '00'}
# {'_id': ObjectId('5da78674c40d54eedfe4a682'), 'id': 1629151, 'name_last_first': 'Broekhoff, Ryan', 'full_name': 'Ryan Broekhoff', 'roster_status': 1, 'from_year': '2018', 'to_year': '2019', 'player_code': 'ryan_broekhoff', 'team_id': 1610612742, 'team_city': 'Dallas', 'team_name': 'Mavericks', 'team_abbreviation': 'DAL', 'team_code': 'mavericks', 'games_played_bool': 'Y', 'other_league_exp': '00'}
# {'_id': ObjectId('5da78674c40d54eedfe4a68d'), 'id': 1627763, 'name_last_first': 'Brogdon, Malcolm', 'full_name': 'Malcolm Brogdon', 'roster_status': 1, 'from_year': '2016', 'to_year': '2019', 'player_code': 'malcolm_brogdon', 'team_id': 1610612749, 'team_city': 'Milwaukee', 'team_name': 'Bucks', 'team_abbreviation': 'MIL', 'team_code': 'bucks', 'games_played_bool': 'Y', 'other_league_exp': '00'}
# {'_id': ObjectId('5da78674c40d54eedfe4a699'), 'id': 1628415, 'name_last_first': 'Brooks, Dillon', 'full_name': 'Dillon Brooks', 'roster_status': 1, 'from_year': '2017', 'to_year': '2019', 'player_code': 'dillon_brooks', 'team_id': 1610612763, 'team_city': 'Memphis', 'team_name': 'Grizzlies', 'team_abbreviation': 'MEM', 'team_code': 'grizzlies', 'games_played_bool': 'Y', 'other_league_exp': '00'}
# {'_id': ObjectId('5da78674c40d54eedfe4a6b1'), 'id': 1628971, 'name_last_first': 'Brown, Bruce', 'full_name': 'Bruce Brown', 'roster_status': 1, 'from_year': '2018', 'to_year': '2019', 'player_code': 'tmp_bruce_brown', 'team_id': 1610612765, 'team_city': 'Detroit', 'team_name': 'Pistons', 'team_abbreviation': 'DET', 'team_code': 'pistons', 'games_played_bool': 'Y', 'other_league_exp': '11'}
# {'_id': ObjectId('5da78674c40d54eedfe4a6bd'), 'id': 1627759, 'name_last_first': 'Brown, Jaylen', 'full_name': 'Jaylen Brown', 'roster_status': 1, 'from_year': '2016', 'to_year': '2019', 'player_code': 'jaylen_brown', 'team_id': 1610612738, 'team_city': 'Boston', 'team_name': 'Celtics', 'team_abbreviation': 'BOS', 'team_code': 'celtics', 'games_played_bool': 'Y', 'other_league_exp': '00'}
# {'_id': ObjectId('5da78674c40d54eedfe4a6d3'), 'id': 1628425, 'name_last_first': 'Brown, Sterling', 'full_name': 'Sterling Brown', 'roster_status': 1, 'from_year': '2017', 'to_year': '2019', 'player_code': 'sterling_brown', 'team_id': 1610612749, 'team_city': 'Milwaukee', 'team_name': 'Bucks', 'team_abbreviation': 'MIL', 'team_code': 'bucks', 'games_played_bool': 'Y', 'other_league_exp': '11'}
# {'_id': ObjectId('5da78674c40d54eedfe4a6de'), 'id': 1628972, 'name_last_first': 'Brown Jr., Troy', 'full_name': 'Troy Brown Jr.', 'roster_status': 1, 'from_year': '2018', 'to_year': '2019', 'player_code': 'troy_brown_jr', 'team_id': 1610612764, 'team_city': 'Washington', 'team_name': 'Wizards', 'team_abbreviation': 'WAS', 'team_code': 'wizards', 'games_played_bool': 'Y', 'other_league_exp': '11'}
# {'_id': ObjectId('5da78674c40d54eedfe4a6e9'), 'id': 1628973, 'name_last_first': 'Brunson, Jalen', 'full_name': 'Jalen Brunson', 'roster_status': 1, 'from_year': '2018', 'to_year': '2019', 'player_code': 'jalen_brunson', 'team_id': 1610612742, 'team_city': 'Dallas', 'team_name': 'Mavericks', 'team_abbreviation': 'DAL', 'team_code': 'mavericks', 'games_played_bool': 'Y', 'other_league_exp': '00'}
# {'_id': ObjectId('5da78674c40d54eedfe4a6f6'), 'id': 1628418, 'name_last_first': 'Bryant, Thomas', 'full_name': 'Thomas Bryant', 'roster_status': 1, 'from_year': '2017', 'to_year': '2019', 'player_code': 'thomas_bryant', 'team_id': 1610612764, 'team_city': 'Washington', 'team_name': 'Wizards', 'team_abbreviation': 'WAS', 'team_code': 'wizards', 'games_played_bool': 'Y', 'other_league_exp': '11'}
# {'_id': ObjectId('5da78674c40d54eedfe4a701'), 'id': 203493, 'name_last_first': 'Bullock, Reggie', 'full_name': 'Reggie Bullock', 'roster_status': 1, 'from_year': '2013', 'to_year': '2019', 'player_code': 'reggie_bullock', 'team_id': 1610612747, 'team_city': 'Los Angeles', 'team_name': 'Lakers', 'team_abbreviation': 'LAL', 'team_code': 'lakers', 'games_played_bool': 'Y', 'other_league_exp': '01'}
# {'_id': ObjectId('5da78674c40d54eedfe4a70c'), 'id': 203504, 'name_last_first': 'Burke, Trey', 'full_name': 'Trey Burke', 'roster_status': 1, 'from_year': '2013', 'to_year': '2019', 'player_code': 'trey_burke', 'team_id': 1610612742, 'team_city': 'Dallas', 'team_name': 'Mavericks', 'team_abbreviation': 'DAL', 'team_code': 'mavericks', 'games_played_bool': 'Y', 'other_league_exp': '01'}
# {'_id': ObjectId('5da78674c40d54eedfe4a717'), 'id': 202692, 'name_last_first': 'Burks, Alec', 'full_name': 'Alec Burks', 'roster_status': 1, 'from_year': '2011', 'to_year': '2019', 'player_code': 'alec_burks', 'team_id': 1610612758, 'team_city': 'Sacramento', 'team_name': 'Kings', 'team_abbreviation': 'SAC', 'team_code': 'kings', 'games_played_bool': 'Y', 'other_league_exp': '01'}
# {'_id': ObjectId('5da78674c40d54eedfe4a724'), 'id': 1629126, 'name_last_first': 'Burton, Deonte', 'full_name': 'Deonte Burton', 'roster_status': 1, 'from_year': '2018', 'to_year': '2019', 'player_code': 'deonte_burton', 'team_id': 1610612760, 'team_city': 'Oklahoma City', 'team_name': 'Thunder', 'team_abbreviation': 'OKC', 'team_code': 'thunder', 'games_played_bool': 'Y', 'other_league_exp': '11'}
# {'_id': ObjectId('5da78674c40d54eedfe4a731'), 'id': 202710, 'name_last_first': 'Butler, Jimmy', 'full_name': 'Jimmy Butler', 'roster_status': 1, 'from_year': '2011', 'to_year': '2019', 'player_code': 'jimmy_butler', 'team_id': 1610612755, 'team_city': 'Philadelphia', 'team_name': '76ers', 'team_abbreviation': 'PHI', 'team_code': 'sixers', 'games_played_bool': 'Y', 'other_league_exp': '00'}
# {'_id': ObjectId('5da78674c40d54eedfe4a73c'), 'id': 203998, 'name_last_first': 'Caboclo, Bruno', 'full_name': 'Bruno Caboclo', 'roster_status': 1, 'from_year': '2014', 'to_year': '2019', 'player_code': 'bruno_caboclo', 'team_id': 1610612763, 'team_city': 'Memphis', 'team_name': 'Grizzlies', 'team_abbreviation': 'MEM', 'team_code': 'grizzlies', 'games_played_bool': 'Y', 'other_league_exp': '11'}
# {'_id': ObjectId('5da78675c40d54eedfe4a747'), 'id': 101181, 'name_last_first': 'Calderon, Jose', 'full_name': 'Jose Calderon', 'roster_status': 1, 'from_year': '2005', 'to_year': '2018', 'player_code': 'jose_calderon', 'team_id': 1610612765, 'team_city': 'Detroit', 'team_name': 'Pistons', 'team_abbreviation': 'DET', 'team_code': 'pistons', 'games_played_bool': 'Y', 'other_league_exp': '00'}
# {'_id': ObjectId('5da78675c40d54eedfe4a752'), 'id': 203484, 'name_last_first': 'Caldwell-Pope, Kentavious', 'full_name': 'Kentavious Caldwell-Pope', 'roster_status': 1, 'from_year': '2013', 'to_year': '2019', 'player_code': 'kentavious_caldwell-pope', 'team_id': 1610612747, 'team_city': 'Los Angeles', 'team_name': 'Lakers', 'team_abbreviation': 'LAL', 'team_code': 'lakers', 'games_played_bool': 'Y', 'other_league_exp': '00'}
# {'_id': ObjectId('5da78675c40d54eedfe4a769'), 'id': 203991, 'name_last_first': 'Capela, Clint', 'full_name': 'Clint Capela', 'roster_status': 1, 'from_year': '2014', 'to_year': '2019', 'player_code': 'clint_capela', 'team_id': 1610612745, 'team_city': 'Houston', 'team_name': 'Rockets', 'team_abbreviation': 'HOU', 'team_code': 'rockets', 'games_played_bool': 'Y', 'other_league_exp': '01'}
# {'_id': ObjectId('5da78675c40d54eedfe4a774'), 'id': 201960, 'name_last_first': 'Carroll, DeMarre', 'full_name': 'DeMarre Carroll', 'roster_status': 1, 'from_year': '2009', 'to_year': '2019', 'player_code': 'demarre_carroll', 'team_id': 1610612751, 'team_city': 'Brooklyn', 'team_name': 'Nets', 'team_abbreviation': 'BKN', 'team_code': 'nets', 'games_played_bool': 'Y', 'other_league_exp': '01'}
# {'_id': ObjectId('5da78675c40d54eedfe4a784'), 'id': 1628975, 'name_last_first': 'Carter, Jevon', 'full_name': 'Jevon Carter', 'roster_status': 1, 'from_year': '2018', 'to_year': '2019', 'player_code': 'jevon_carter', 'team_id': 1610612763, 'team_city': 'Memphis', 'team_name': 'Grizzlies', 'team_abbreviation': 'MEM', 'team_code': 'grizzlies', 'games_played_bool': 'Y', 'other_league_exp': '11'}
# {'_id': ObjectId('5da78675c40d54eedfe4a798'), 'id': 1713, 'name_last_first': 'Carter, Vince', 'full_name': 'Vince Carter', 'roster_status': 1, 'from_year': '1998', 'to_year': '2019', 'player_code': 'vince_carter', 'team_id': 1610612737, 'team_city': 'Atlanta', 'team_name': 'Hawks', 'team_abbreviation': 'ATL', 'team_code': 'hawks', 'games_played_bool': 'Y', 'other_league_exp': '00'}
# {'_id': ObjectId('5da78675c40d54eedfe4a7a4'), 'id': 1628976, 'name_last_first': 'Carter Jr., Wendell', 'full_name': 'Wendell Carter Jr.', 'roster_status': 1, 'from_year': '2018', 'to_year': '2019', 'player_code': 'wendell_carter_jr', 'team_id': 1610612741, 'team_city': 'Chicago', 'team_name': 'Bulls', 'team_abbreviation': 'CHI', 'team_code': 'bulls', 'games_played_bool': 'Y', 'other_league_exp': '00'}
# {'_id': ObjectId('5da78675c40d54eedfe4a7af'), 'id': 203487, 'name_last_first': 'Carter-Williams, Michael', 'full_name': 'Michael Carter-Williams', 'roster_status': 1, 'from_year': '2013', 'to_year': '2019', 'player_code': 'michael_carter-williams', 'team_id': 1610612753, 'team_city': 'Orlando', 'team_name': 'Magic', 'team_abbreviation': 'ORL', 'team_code': 'magic', 'games_played_bool': 'Y', 'other_league_exp': '00'}
# {'_id': ObjectId('5da78675c40d54eedfe4a7ba'), 'id': 1627936, 'name_last_first': 'Caruso, Alex', 'full_name': 'Alex Caruso', 'roster_status': 1, 'from_year': '2017', 'to_year': '2019', 'player_code': 'alex_caruso', 'team_id': 1610612747, 'team_city': 'Los Angeles', 'team_name': 'Lakers', 'team_abbreviation': 'LAL', 'team_code': 'lakers', 'games_played_bool': 'Y', 'other_league_exp': '11'}
# {'_id': ObjectId('5da78675c40d54eedfe4a7d0'), 'id': 1626161, 'name_last_first': 'Cauley-Stein, Willie', 'full_name': 'Willie Cauley-Stein', 'roster_status': 1, 'from_year': '2015', 'to_year': '2019', 'player_code': 'willie_cauley-stein', 'team_id': 1610612758, 'team_city': 'Sacramento', 'team_name': 'Kings', 'team_abbreviation': 'SAC', 'team_code': 'kings', 'games_played_bool': 'Y', 'other_league_exp': '00'}
# {'_id': ObjectId('5da78675c40d54eedfe4a7db'), 'id': 1628505, 'name_last_first': 'Caupain, Troy', 'full_name': 'Troy Caupain', 'roster_status': 1, 'from_year': '2018', 'to_year': '2018', 'player_code': 'troy_caupain', 'team_id': 1610612753, 'team_city': 'Orlando', 'team_name': 'Magic', 'team_abbreviation': 'ORL', 'team_code': 'magic', 'games_played_bool': 'Y', 'other_league_exp': '11'}
# {'_id': ObjectId('5da78675c40d54eedfe4a7e7'), 'id': 1628463, 'name_last_first': 'Cavanaugh, Tyler', 'full_name': 'Tyler Cavanaugh', 'roster_status': 1, 'from_year': '2017', 'to_year': '2018', 'player_code': 'tyler_cavanaugh', 'team_id': 1610612762, 'team_city': 'Utah', 'team_name': 'Jazz', 'team_abbreviation': 'UTA', 'team_code': 'jazz', 'games_played_bool': 'Y', 'other_league_exp': '11'}
# {'_id': ObjectId('5da78675c40d54eedfe4a7fa'), 'id': 2199, 'name_last_first': 'Chandler, Tyson', 'full_name': 'Tyson Chandler', 'roster_status': 1, 'from_year': '2001', 'to_year': '2019', 'player_code': 'tyson_chandler', 'team_id': 1610612747, 'team_city': 'Los Angeles', 'team_name': 'Lakers', 'team_abbreviation': 'LAL', 'team_code': 'lakers', 'games_played_bool': 'Y', 'other_league_exp': '00'}
# {'_id': ObjectId('5da78675c40d54eedfe4a806'), 'id': 201163, 'name_last_first': 'Chandler, Wilson', 'full_name': 'Wilson Chandler', 'roster_status': 1, 'from_year': '2007', 'to_year': '2019', 'player_code': 'wilson_chandler', 'team_id': 1610612746, 'team_city': 'LA', 'team_name': 'Clippers', 'team_abbreviation': 'LAC', 'team_code': 'clippers', 'games_played_bool': 'Y', 'other_league_exp': '00'}
# {'_id': ObjectId('5da78675c40d54eedfe4a811'), 'id': 1629147, 'name_last_first': 'Chealey, Joe', 'full_name': 'Joe Chealey', 'roster_status': 1, 'from_year': '2018', 'to_year': '2018', 'player_code': 'joe_chealey', 'team_id': 1610612766, 'team_city': 'Charlotte', 'team_name': 'Hornets', 'team_abbreviation': 'CHA', 'team_code': 'hornets', 'games_played_bool': 'Y', 'other_league_exp': '11'}
# {'_id': ObjectId('5da78675c40d54eedfe4a81c'), 'id': 1629185, 'name_last_first': 'Chiozza, Chris', 'full_name': 'Chris Chiozza', 'roster_status': 1, 'from_year': '2018', 'to_year': '2019', 'player_code': 'chris_chiozza', 'team_id': 1610612745, 'team_city': 'Houston', 'team_name': 'Rockets', 'team_abbreviation': 'HOU', 'team_code': 'rockets', 'games_played_bool': 'Y', 'other_league_exp': '11'}
# {'_id': ObjectId('5da78675c40d54eedfe4a829'), 'id': 1627737, 'name_last_first': 'Chriss, Marquese', 'full_name': 'Marquese Chriss', 'roster_status': 1, 'from_year': '2016', 'to_year': '2019', 'player_code': 'marquese_chriss', 'team_id': 1610612739, 'team_city': 'Cleveland', 'team_name': 'Cavaliers', 'team_abbreviation': 'CLE', 'team_code': 'cavaliers', 'games_played_bool': 'Y', 'other_league_exp': '00'}
# {'_id': ObjectId('5da78675c40d54eedfe4a835'), 'id': 1629109, 'name_last_first': 'Clark, Gary', 'full_name': 'Gary Clark', 'roster_status': 1, 'from_year': '2018', 'to_year': '2019', 'player_code': 'gary_clark', 'team_id': 1610612745, 'team_city': 'Houston', 'team_name': 'Rockets', 'team_abbreviation': 'HOU', 'team_code': 'rockets', 'games_played_bool': 'Y', 'other_league_exp': '11'}
# {'_id': ObjectId('5da78675c40d54eedfe4a840'), 'id': 203546, 'name_last_first': 'Clark, Ian', 'full_name': 'Ian Clark', 'roster_status': 1, 'from_year': '2013', 'to_year': '2018', 'player_code': 'ian_clark', 'team_id': 1610612740, 'team_city': 'New Orleans', 'team_name': 'Pelicans', 'team_abbreviation': 'NOP', 'team_code': 'pelicans', 'games_played_bool': 'Y', 'other_league_exp': '01'}
# {'_id': ObjectId('5da78675c40d54eedfe4a84c'), 'id': 203903, 'name_last_first': 'Clarkson, Jordan', 'full_name': 'Jordan Clarkson', 'roster_status': 1, 'from_year': '2014', 'to_year': '2019', 'player_code': 'jordan_clarkson', 'team_id': 1610612739, 'team_city': 'Cleveland', 'team_name': 'Cavaliers', 'team_abbreviation': 'CLE', 'team_code': 'cavaliers', 'games_played_bool': 'Y', 'other_league_exp': '01'}
# {'_id': ObjectId('5da78675c40d54eedfe4a857'), 'id': 1628381, 'name_last_first': 'Collins, John', 'full_name': 'John Collins', 'roster_status': 1, 'from_year': '2017', 'to_year': '2019', 'player_code': 'john_collins', 'team_id': 1610612737, 'team_city': 'Atlanta', 'team_name': 'Hawks', 'team_abbreviation': 'ATL', 'team_code': 'hawks', 'games_played_bool': 'Y', 'other_league_exp': '00'}
# {'_id': ObjectId('5da78675c40d54eedfe4a862'), 'id': 1628380, 'name_last_first': 'Collins, Zach', 'full_name': 'Zach Collins', 'roster_status': 1, 'from_year': '2017', 'to_year': '2019', 'player_code': 'zach_collins', 'team_id': 1610612757, 'team_city': 'Portland', 'team_name': 'Trail Blazers', 'team_abbreviation': 'POR', 'team_code': 'blazers', 'games_played_bool': 'Y', 'other_league_exp': '00'}
# {'_id': ObjectId('5da78675c40d54eedfe4a86e'), 'id': 201954, 'name_last_first': 'Collison, Darren', 'full_name': 'Darren Collison', 'roster_status': 1, 'from_year': '2009', 'to_year': '2018', 'player_code': 'darren_collison', 'team_id': 1610612754, 'team_city': 'Indiana', 'team_name': 'Pacers', 'team_abbreviation': 'IND', 'team_code': 'pacers', 'games_played_bool': 'Y', 'other_league_exp': '00'}
# {'_id': ObjectId('5da78676c40d54eedfe4a879'), 'id': 1629045, 'name_last_first': 'Colson, Bonzie', 'full_name': 'Bonzie Colson', 'roster_status': 1, 'from_year': '2018', 'to_year': '2018', 'player_code': 'bonzie_colson', 'team_id': 1610612749, 'team_city': 'Milwaukee', 'team_name': 'Bucks', 'team_abbreviation': 'MIL', 'team_code': 'bucks', 'games_played_bool': 'Y', 'other_league_exp': '11'}
# {'_id': ObjectId('5da78676c40d54eedfe4a884'), 'id': 201144, 'name_last_first': 'Conley, Mike', 'full_name': 'Mike Conley', 'roster_status': 1, 'from_year': '2007', 'to_year': '2019', 'player_code': 'mike_conley', 'team_id': 1610612763, 'team_city': 'Memphis', 'team_name': 'Grizzlies', 'team_abbreviation': 'MEM', 'team_code': 'grizzlies', 'games_played_bool': 'Y', 'other_league_exp': '00'}
# {'_id': ObjectId('5da78676c40d54eedfe4a890'), 'id': 1626192, 'name_last_first': 'Connaughton, Pat', 'full_name': 'Pat Connaughton', 'roster_status': 1, 'from_year': '2015', 'to_year': '2019', 'player_code': 'pat_connaughton', 'team_id': 1610612749, 'team_city': 'Milwaukee', 'team_name': 'Bucks', 'team_abbreviation': 'MIL', 'team_code': 'bucks', 'games_played_bool': 'Y', 'other_league_exp': '00'}
# {'_id': ObjectId('5da78676c40d54eedfe4a89b'), 'id': 1626188, 'name_last_first': 'Cook, Quinn', 'full_name': 'Quinn Cook', 'roster_status': 1, 'from_year': '2016', 'to_year': '2019', 'player_code': 'quinn_cook', 'team_id': 1610612744, 'team_city': 'Golden State', 'team_name': 'Warriors', 'team_abbreviation': 'GSW', 'team_code': 'warriors', 'games_played_bool': 'Y', 'other_league_exp': '01'}
# {'_id': ObjectId('5da78676c40d54eedfe4a8a7'), 'id': 202326, 'name_last_first': 'Cousins, DeMarcus', 'full_name': 'DeMarcus Cousins', 'roster_status': 1, 'from_year': '2010', 'to_year': '2019', 'player_code': 'demarcus_cousins', 'team_id': 1610612744, 'team_city': 'Golden State', 'team_name': 'Warriors', 'team_abbreviation': 'GSW', 'team_code': 'warriors', 'games_played_bool': 'Y', 'other_league_exp': '00'}
# {'_id': ObjectId('5da78676c40d54eedfe4a8b4'), 'id': 203496, 'name_last_first': 'Covington, Robert', 'full_name': 'Robert Covington', 'roster_status': 1, 'from_year': '2013', 'to_year': '2019', 'player_code': 'robert_covington', 'team_id': 1610612750, 'team_city': 'Minnesota', 'team_name': 'Timberwolves', 'team_abbreviation': 'MIN', 'team_code': 'timberwolves', 'games_played_bool': 'Y', 'other_league_exp': '01'}
# {'_id': ObjectId('5da78676c40d54eedfe4a8bf'), 'id': 203459, 'name_last_first': 'Crabbe, Allen', 'full_name': 'Allen Crabbe', 'roster_status': 1, 'from_year': '2013', 'to_year': '2019', 'player_code': 'allen_crabbe', 'team_id': 1610612751, 'team_city': 'Brooklyn', 'team_name': 'Nets', 'team_abbreviation': 'BKN', 'team_code': 'nets', 'games_played_bool': 'Y', 'other_league_exp': '01'}
# {'_id': ObjectId('5da78676c40d54eedfe4a8cb'), 'id': 1628470, 'name_last_first': 'Craig, Torrey', 'full_name': 'Torrey Craig', 'roster_status': 1, 'from_year': '2017', 'to_year': '2019', 'player_code': 'torrey_craig', 'team_id': 1610612743, 'team_city': 'Denver', 'team_name': 'Nuggets', 'team_abbreviation': 'DEN', 'team_code': 'nuggets', 'games_played_bool': 'Y', 'other_league_exp': '01'}
# {'_id': ObjectId('5da78676c40d54eedfe4a8d6'), 'id': 2037, 'name_last_first': 'Crawford, Jamal', 'full_name': 'Jamal Crawford', 'roster_status': 1, 'from_year': '2000', 'to_year': '2018', 'player_code': 'jamal_crawford', 'team_id': 1610612756, 'team_city': 'Phoenix', 'team_name': 'Suns', 'team_abbreviation': 'PHX', 'team_code': 'suns', 'games_played_bool': 'Y', 'other_league_exp': '00'}
# {'_id': ObjectId('5da78676c40d54eedfe4a8e2'), 'id': 1628249, 'name_last_first': 'Creek, Mitchell', 'full_name': 'Mitchell Creek', 'roster_status': 1, 'from_year': '2018', 'to_year': '2018', 'player_code': 'mitchell_creek', 'team_id': 1610612750, 'team_city': 'Minnesota', 'team_name': 'Timberwolves', 'team_abbreviation': 'MIN', 'team_code': 'timberwolves', 'games_played_bool': 'Y', 'other_league_exp': '11'}
# {'_id': ObjectId('5da78676c40d54eedfe4a8ef'), 'id': 203109, 'name_last_first': 'Crowder, Jae', 'full_name': 'Jae Crowder', 'roster_status': 1, 'from_year': '2012', 'to_year': '2019', 'player_code': 'jae_crowder', 'team_id': 1610612762, 'team_city': 'Utah', 'team_name': 'Jazz', 'team_abbreviation': 'UTA', 'team_code': 'jazz', 'games_played_bool': 'Y', 'other_league_exp': '01'}
# {'_id': ObjectId('5da78676c40d54eedfe4a8fc'), 'id': 201967, 'name_last_first': 'Cunningham, Dante', 'full_name': 'Dante Cunningham', 'roster_status': 1, 'from_year': '2009', 'to_year': '2018', 'player_code': 'dante_cunningham', 'team_id': 1610612759, 'team_city': 'San Antonio', 'team_name': 'Spurs', 'team_abbreviation': 'SAS', 'team_code': 'spurs', 'games_played_bool': 'Y', 'other_league_exp': '00'}
# {'_id': ObjectId('5da78676c40d54eedfe4a907'), 'id': 203552, 'name_last_first': 'Curry, Seth', 'full_name': 'Seth Curry', 'roster_status': 1, 'from_year': '2013', 'to_year': '2019', 'player_code': 'seth_curry', 'team_id': 1610612757, 'team_city': 'Portland', 'team_name': 'Trail Blazers', 'team_abbreviation': 'POR', 'team_code': 'blazers', 'games_played_bool': 'Y', 'other_league_exp': '01'}
# {'_id': ObjectId('5da78676c40d54eedfe4a912'), 'id': 201939, 'name_last_first': 'Curry, Stephen', 'full_name': 'Stephen Curry', 'roster_status': 1, 'from_year': '2009', 'to_year': '2019', 'player_code': 'stephen_curry', 'team_id': 1610612744, 'team_city': 'Golden State', 'team_name': 'Warriors', 'team_abbreviation': 'GSW', 'team_code': 'warriors', 'games_played_bool': 'Y', 'other_league_exp': '00'}
# {'_id': ObjectId('5da78676c40d54eedfe4a91d'), 'id': 203584, 'name_last_first': 'Daniels, Troy', 'full_name': 'Troy Daniels', 'roster_status': 1, 'from_year': '2013', 'to_year': '2019', 'player_code': 'troy_daniels', 'team_id': 1610612756, 'team_city': 'Phoenix', 'team_name': 'Suns', 'team_abbreviation': 'PHX', 'team_code': 'suns', 'games_played_bool': 'Y', 'other_league_exp': '01'}
# {'_id': ObjectId('5da78676c40d54eedfe4a929'), 'id': 203076, 'name_last_first': 'Davis, Anthony', 'full_name': 'Anthony Davis', 'roster_status': 1, 'from_year': '2012', 'to_year': '2019', 'player_code': 'anthony_davis', 'team_id': 1610612740, 'team_city': 'New Orleans', 'team_name': 'Pelicans', 'team_abbreviation': 'NOP', 'team_code': 'pelicans', 'games_played_bool': 'Y', 'other_league_exp': '00'}
# {'_id': ObjectId('5da78676c40d54eedfe4a93f'), 'id': 202334, 'name_last_first': 'Davis, Ed', 'full_name': 'Ed Davis', 'roster_status': 1, 'from_year': '2010', 'to_year': '2019', 'player_code': 'ed_davis', 'team_id': 1610612751, 'team_city': 'Brooklyn', 'team_name': 'Nets', 'team_abbreviation': 'BKN', 'team_code': 'nets', 'games_played_bool': 'Y', 'other_league_exp': '01'}
# {'_id': ObjectId('5da78676c40d54eedfe4a962'), 'id': 201942, 'name_last_first': 'DeRozan, DeMar', 'full_name': 'DeMar DeRozan', 'roster_status': 1, 'from_year': '2009', 'to_year': '2019', 'player_code': 'demar_derozan', 'team_id': 1610612759, 'team_city': 'San Antonio', 'team_name': 'Spurs', 'team_abbreviation': 'SAS', 'team_code': 'spurs', 'games_played_bool': 'Y', 'other_league_exp': '00'}
# {'_id': ObjectId('5da78676c40d54eedfe4a96d'), 'id': 203473, 'name_last_first': 'Dedmon, Dewayne', 'full_name': 'Dewayne Dedmon', 'roster_status': 1, 'from_year': '2013', 'to_year': '2019', 'player_code': 'dewayne_dedmon', 'team_id': 1610612737, 'team_city': 'Atlanta', 'team_name': 'Hawks', 'team_abbreviation': 'ATL', 'team_code': 'hawks', 'games_played_bool': 'Y', 'other_league_exp': '01'}
# {'_id': ObjectId('5da78676c40d54eedfe4a979'), 'id': 1626155, 'name_last_first': 'Dekker, Sam', 'full_name': 'Sam Dekker', 'roster_status': 1, 'from_year': '2015', 'to_year': '2018', 'player_code': 'sam_dekker', 'team_id': 1610612764, 'team_city': 'Washington', 'team_name': 'Wizards', 'team_abbreviation': 'WAS', 'team_code': 'wizards', 'games_played_bool': 'Y', 'other_league_exp': '01'}
# {'_id': ObjectId('5da78676c40d54eedfe4a984'), 'id': 1629116, 'name_last_first': 'Delgado, Angel', 'full_name': 'Angel Delgado', 'roster_status': 1, 'from_year': '2018', 'to_year': '2018', 'player_code': 'angel_delgado', 'team_id': 1610612746, 'team_city': 'LA', 'team_name': 'Clippers', 'team_abbreviation': 'LAC', 'team_code': 'clippers', 'games_played_bool': 'Y', 'other_league_exp': '11'}
# {'_id': ObjectId('5da78676c40d54eedfe4a98f'), 'id': 203521, 'name_last_first': 'Dellavedova, Matthew', 'full_name': 'Matthew Dellavedova', 'roster_status': 1, 'from_year': '2013', 'to_year': '2019', 'player_code': 'matthew_dellavedova', 'team_id': 1610612739, 'team_city': 'Cleveland', 'team_name': 'Cavaliers', 'team_abbreviation': 'CLE', 'team_code': 'cavaliers', 'games_played_bool': 'Y', 'other_league_exp': '00'}
# {'_id': ObjectId('5da78676c40d54eedfe4a99b'), 'id': 1628610, 'full_name': 'Cody Demps', 'first_name': 'Cody', 'last_name': 'Demps', 'is_active': True}
# ...
# {'_id': ObjectId('5da78685c40d54eedfe4bba4'), 'id': 1627832, 'name_last_first': 'VanVleet, Fred', 'full_name': 'Fred VanVleet', 'roster_status': 1, 'from_year': '2016', 'to_year': '2019', 'player_code': 'fred_vanvleet', 'team_id': 1610612761, 'team_city': 'Toronto', 'team_name': 'Raptors', 'team_abbreviation': 'TOR', 'team_code': 'raptors', 'games_played_bool': 'Y', 'other_league_exp': '01'}
# {'_id': ObjectId('5da78685c40d54eedfe4bbaf'), 'id': 1629020, 'name_last_first': 'Vanderbilt, Jarred', 'full_name': 'Jarred Vanderbilt', 'roster_status': 1, 'from_year': '2018', 'to_year': '2019', 'player_code': 'jarred_vanderbilt', 'team_id': 1610612743, 'team_city': 'Denver', 'team_name': 'Nuggets', 'team_abbreviation': 'DEN', 'team_code': 'nuggets', 'games_played_bool': 'Y', 'other_league_exp': '11'}
# {'_id': ObjectId('5da78685c40d54eedfe4bbbb'), 'id': 203943, 'name_last_first': 'Vonleh, Noah', 'full_name': 'Noah Vonleh', 'roster_status': 1, 'from_year': '2014', 'to_year': '2019', 'player_code': 'noah_vonleh', 'team_id': 1610612752, 'team_city': 'New York', 'team_name': 'Knicks', 'team_abbreviation': 'NYK', 'team_code': 'knicks', 'games_played_bool': 'Y', 'other_league_exp': '01'}
# {'_id': ObjectId('5da78685c40d54eedfe4bbc6'), 'id': 202696, 'name_last_first': 'Vucevic, Nikola', 'full_name': 'Nikola Vucevic', 'roster_status': 1, 'from_year': '2011', 'to_year': '2019', 'player_code': 'nikola_vucevic', 'team_id': 1610612753, 'team_city': 'Orlando', 'team_name': 'Magic', 'team_abbreviation': 'ORL', 'team_code': 'magic', 'games_played_bool': 'Y', 'other_league_exp': '00'}
# {'_id': ObjectId('5da78685c40d54eedfe4bbd1'), 'id': 2548, 'name_last_first': 'Wade, Dwyane', 'full_name': 'Dwyane Wade', 'roster_status': 1, 'from_year': '2003', 'to_year': '2018', 'player_code': 'dwyane_wade', 'team_id': 1610612748, 'team_city': 'Miami', 'team_name': 'Heat', 'team_abbreviation': 'MIA', 'team_code': 'heat', 'games_played_bool': 'Y', 'other_league_exp': '00'}
# {'_id': ObjectId('5da78685c40d54eedfe4bbe3'), 'id': 1629021, 'name_last_first': 'Wagner, Moritz', 'full_name': 'Moritz Wagner', 'roster_status': 1, 'from_year': '2018', 'to_year': '2019', 'player_code': 'moritz_wagner', 'team_id': 1610612747, 'team_city': 'Los Angeles', 'team_name': 'Lakers', 'team_abbreviation': 'LAL', 'team_code': 'lakers', 'games_played_bool': 'Y', 'other_league_exp': '11'}
# {'_id': ObjectId('5da78685c40d54eedfe4bbef'), 'id': 203079, 'name_last_first': 'Waiters, Dion', 'full_name': 'Dion Waiters', 'roster_status': 1, 'from_year': '2012', 'to_year': '2019', 'player_code': 'dion_waiters', 'team_id': 1610612748, 'team_city': 'Miami', 'team_name': 'Heat', 'team_abbreviation': 'MIA', 'team_code': 'heat', 'games_played_bool': 'Y', 'other_league_exp': '00'}
# {'_id': ObjectId('5da78685c40d54eedfe4bbfa'), 'id': 202689, 'name_last_first': 'Walker, Kemba', 'full_name': 'Kemba Walker', 'roster_status': 1, 'from_year': '2011', 'to_year': '2019', 'player_code': 'kemba_walker', 'team_id': 1610612766, 'team_city': 'Charlotte', 'team_name': 'Hornets', 'team_abbreviation': 'CHA', 'team_code': 'hornets', 'games_played_bool': 'Y', 'other_league_exp': '00'}
# {'_id': ObjectId('5da78685c40d54eedfe4bc05'), 'id': 1629022, 'name_last_first': 'Walker IV, Lonnie', 'full_name': 'Lonnie Walker IV', 'roster_status': 1, 'from_year': '2018', 'to_year': '2019', 'player_code': 'lonnie_walker', 'team_id': 1610612759, 'team_city': 'San Antonio', 'team_name': 'Spurs', 'team_abbreviation': 'SAS', 'team_code': 'spurs', 'games_played_bool': 'Y', 'other_league_exp': '11'}
# {'_id': ObjectId('5da78685c40d54eedfe4bc10'), 'id': 202322, 'name_last_first': 'Wall, John', 'full_name': 'John Wall', 'roster_status': 1, 'from_year': '2010', 'to_year': '2019', 'player_code': 'john_wall', 'team_id': 1610612764, 'team_city': 'Washington', 'team_name': 'Wizards', 'team_abbreviation': 'WAS', 'team_code': 'wizards', 'games_played_bool': 'Y', 'other_league_exp': '00'}
# {'_id': ObjectId('5da78686c40d54eedfe4bc1b'), 'id': 1627820, 'name_last_first': 'Wallace, Tyrone', 'full_name': 'Tyrone Wallace', 'roster_status': 1, 'from_year': '2017', 'to_year': '2019', 'player_code': 'tyrone_wallace', 'team_id': 1610612746, 'team_city': 'LA', 'team_name': 'Clippers', 'team_abbreviation': 'LAC', 'team_code': 'clippers', 'games_played_bool': 'Y', 'other_league_exp': '01'}
# {'_id': ObjectId('5da78686c40d54eedfe4bc32'), 'id': 202954, 'name_last_first': 'Wanamaker, Brad', 'full_name': 'Brad Wanamaker', 'roster_status': 1, 'from_year': '2018', 'to_year': '2019', 'player_code': 'brad_wanamaker', 'team_id': 1610612738, 'team_city': 'Boston', 'team_name': 'Celtics', 'team_abbreviation': 'BOS', 'team_code': 'celtics', 'games_played_bool': 'Y', 'other_league_exp': '11'}
# {'_id': ObjectId('5da78686c40d54eedfe4bc42'), 'id': 203933, 'name_last_first': 'Warren, T.J.', 'full_name': 'T.J. Warren', 'roster_status': 1, 'from_year': '2014', 'to_year': '2019', 'player_code': 'tj_warren', 'team_id': 1610612756, 'team_city': 'Phoenix', 'team_name': 'Suns', 'team_abbreviation': 'PHX', 'team_code': 'suns', 'games_played_bool': 'Y', 'other_league_exp': '01'}
# {'_id': ObjectId('5da78686c40d54eedfe4bc4e'), 'id': 1627395, 'name_last_first': 'Washburn, Julian', 'full_name': 'Julian Washburn', 'roster_status': 1, 'from_year': '2018', 'to_year': '2018', 'player_code': 'julian_washburn', 'team_id': 1610612763, 'team_city': 'Memphis', 'team_name': 'Grizzlies', 'team_abbreviation': 'MEM', 'team_code': 'grizzlies', 'games_played_bool': 'Y', 'other_league_exp': '11'}
# {'_id': ObjectId('5da78686c40d54eedfe4bc5b'), 'id': 1629139, 'name_last_first': 'Watanabe, Yuta', 'full_name': 'Yuta Watanabe', 'roster_status': 1, 'from_year': '2018', 'to_year': '2019', 'player_code': 'yuta_watanabe', 'team_id': 1610612763, 'team_city': 'Memphis', 'team_name': 'Grizzlies', 'team_abbreviation': 'MEM', 'team_code': 'grizzlies', 'games_played_bool': 'Y', 'other_league_exp': '11'}
# {'_id': ObjectId('5da78686c40d54eedfe4bc68'), 'id': 1629118, 'name_last_first': 'Welsh, Thomas', 'full_name': 'Thomas Welsh', 'roster_status': 1, 'from_year': '2018', 'to_year': '2019', 'player_code': 'thomas_welsh', 'team_id': 1610612743, 'team_city': 'Denver', 'team_name': 'Nuggets', 'team_abbreviation': 'DEN', 'team_code': 'nuggets', 'games_played_bool': 'Y', 'other_league_exp': '11'}
# {'_id': ObjectId('5da78686c40d54eedfe4bc73'), 'id': 201566, 'name_last_first': 'Westbrook, Russell', 'full_name': 'Russell Westbrook', 'roster_status': 1, 'from_year': '2008', 'to_year': '2019', 'player_code': 'russell_westbrook', 'team_id': 1610612760, 'team_city': 'Oklahoma City', 'team_name': 'Thunder', 'team_abbreviation': 'OKC', 'team_code': 'thunder', 'games_played_bool': 'Y', 'other_league_exp': '00'}
# {'_id': ObjectId('5da78686c40d54eedfe4bc7f'), 'id': 1628401, 'name_last_first': 'White, Derrick', 'full_name': 'Derrick White', 'roster_status': 1, 'from_year': '2017', 'to_year': '2019', 'player_code': 'derrick_white', 'team_id': 1610612759, 'team_city': 'San Antonio', 'team_name': 'Spurs', 'team_abbreviation': 'SAS', 'team_code': 'spurs', 'games_played_bool': 'Y', 'other_league_exp': '01'}
# {'_id': ObjectId('5da78686c40d54eedfe4bc96'), 'id': 1627785, 'name_last_first': 'Whitehead, Isaiah', 'full_name': 'Isaiah Whitehead', 'roster_status': 1, 'from_year': '2016', 'to_year': '2018', 'player_code': 'isaiah_whitehead', 'team_id': 1610612765, 'team_city': 'Detroit', 'team_name': 'Pistons', 'team_abbreviation': 'DET', 'team_code': 'pistons', 'games_played_bool': 'Y', 'other_league_exp': '11'}
# {'_id': ObjectId('5da78686c40d54eedfe4bca2'), 'id': 202355, 'name_last_first': 'Whiteside, Hassan', 'full_name': 'Hassan Whiteside', 'roster_status': 1, 'from_year': '2010', 'to_year': '2019', 'player_code': 'hassan_whiteside', 'team_id': 1610612748, 'team_city': 'Miami', 'team_name': 'Heat', 'team_abbreviation': 'MIA', 'team_code': 'heat', 'games_played_bool': 'Y', 'other_league_exp': '01'}
# {'_id': ObjectId('5da78686c40d54eedfe4bcae'), 'id': 203952, 'name_last_first': 'Wiggins, Andrew', 'full_name': 'Andrew Wiggins', 'roster_status': 1, 'from_year': '2014', 'to_year': '2019', 'player_code': 'andrew_wiggins', 'team_id': 1610612750, 'team_city': 'Minnesota', 'team_name': 'Timberwolves', 'team_abbreviation': 'MIN', 'team_code': 'timberwolves', 'games_played_bool': 'Y', 'other_league_exp': '00'}
# {'_id': ObjectId('5da78686c40d54eedfe4bcb9'), 'id': 1626210, 'name_last_first': 'Williams, Alan', 'full_name': 'Alan Williams', 'roster_status': 1, 'from_year': '2015', 'to_year': '2018', 'player_code': 'alan_williams', 'team_id': 1610612751, 'team_city': 'Brooklyn', 'team_name': 'Nets', 'team_abbreviation': 'BKN', 'team_code': 'nets', 'games_played_bool': 'Y', 'other_league_exp': '11'}
# {'_id': ObjectId('5da78686c40d54eedfe4bcc4'), 'id': 203710, 'name_last_first': 'Williams, C.J.', 'full_name': 'C.J. Williams', 'roster_status': 1, 'from_year': '2017', 'to_year': '2019', 'player_code': 'c.j._williams', 'team_id': 1610612750, 'team_city': 'Minnesota', 'team_name': 'Timberwolves', 'team_abbreviation': 'MIN', 'team_code': 'timberwolves', 'games_played_bool': 'Y', 'other_league_exp': '11'}
# {'_id': ObjectId('5da78686c40d54eedfe4bccf'), 'id': 1629140, 'name_last_first': 'Williams, Johnathan', 'full_name': 'Johnathan Williams', 'roster_status': 1, 'from_year': '2018', 'to_year': '2018', 'player_code': 'johnathan_williams', 'team_id': 1610612747, 'team_city': 'Los Angeles', 'team_name': 'Lakers', 'team_abbreviation': 'LAL', 'team_code': 'lakers', 'games_played_bool': 'Y', 'other_league_exp': '11'}
# {'_id': ObjectId('5da78686c40d54eedfe4bcda'), 'id': 1629026, 'name_last_first': 'Williams, Kenrich', 'full_name': 'Kenrich Williams', 'roster_status': 1, 'from_year': '2018', 'to_year': '2019', 'player_code': 'kenrich_williams', 'team_id': 1610612740, 'team_city': 'New Orleans', 'team_name': 'Pelicans', 'team_abbreviation': 'NOP', 'team_code': 'pelicans', 'games_played_bool': 'Y', 'other_league_exp': '11'}
# {'_id': ObjectId('5da78686c40d54eedfe4bce6'), 'id': 101150, 'name_last_first': 'Williams, Lou', 'full_name': 'Lou Williams', 'roster_status': 1, 'from_year': '2005', 'to_year': '2019', 'player_code': 'lou_williams', 'team_id': 1610612746, 'team_city': 'LA', 'team_name': 'Clippers', 'team_abbreviation': 'LAC', 'team_code': 'clippers', 'games_played_bool': 'Y', 'other_league_exp': '01'}
# {'_id': ObjectId('5da78686c40d54eedfe4bcf1'), 'id': 101107, 'name_last_first': 'Williams, Marvin', 'full_name': 'Marvin Williams', 'roster_status': 1, 'from_year': '2005', 'to_year': '2019', 'player_code': 'marvin_williams', 'team_id': 1610612766, 'team_city': 'Charlotte', 'team_name': 'Hornets', 'team_abbreviation': 'CHA', 'team_code': 'hornets', 'games_played_bool': 'Y', 'other_league_exp': '00'}
# {'_id': ObjectId('5da78686c40d54eedfe4bcfc'), 'id': 1627786, 'name_last_first': 'Williams, Troy', 'full_name': 'Troy Williams', 'roster_status': 1, 'from_year': '2016', 'to_year': '2018', 'player_code': 'troy_williams', 'team_id': 1610612758, 'team_city': 'Sacramento', 'team_name': 'Kings', 'team_abbreviation': 'SAC', 'team_code': 'kings', 'games_played_bool': 'Y', 'other_league_exp': '11'}
# {'_id': ObjectId('5da78686c40d54eedfe4bd08'), 'id': 1629057, 'name_last_first': 'Williams III, Robert', 'full_name': 'Robert Williams III', 'roster_status': 1, 'from_year': '2018', 'to_year': '2019', 'player_code': 'robert_williams', 'team_id': 1610612738, 'team_city': 'Boston', 'team_name': 'Celtics', 'team_abbreviation': 'BOS', 'team_code': 'celtics', 'games_played_bool': 'Y', 'other_league_exp': '11'}
# {'_id': ObjectId('5da78686c40d54eedfe4bd13'), 'id': 1628391, 'name_last_first': 'Wilson, D.J.', 'full_name': 'D.J. Wilson', 'roster_status': 1, 'from_year': '2017', 'to_year': '2019', 'player_code': 'd.j._wilson', 'team_id': 1610612749, 'team_city': 'Milwaukee', 'team_name': 'Bucks', 'team_abbreviation': 'MIL', 'team_code': 'bucks', 'games_played_bool': 'Y', 'other_league_exp': '11'}
# {'_id': ObjectId('5da78686c40d54eedfe4bd1f'), 'id': 1626159, 'name_last_first': 'Winslow, Justise', 'full_name': 'Justise Winslow', 'roster_status': 1, 'from_year': '2015', 'to_year': '2019', 'player_code': 'justise_winslow', 'team_id': 1610612748, 'team_city': 'Miami', 'team_name': 'Heat', 'team_abbreviation': 'MIA', 'team_code': 'heat', 'games_played_bool': 'Y', 'other_league_exp': '00'}
# {'_id': ObjectId('5da78686c40d54eedfe4bd2b'), 'id': 1626174, 'name_last_first': 'Wood, Christian', 'full_name': 'Christian Wood', 'roster_status': 1, 'from_year': '2015', 'to_year': '2019', 'player_code': 'christian_wood', 'team_id': 1610612740, 'team_city': 'New Orleans', 'team_name': 'Pelicans', 'team_abbreviation': 'NOP', 'team_code': 'pelicans', 'games_played_bool': 'Y', 'other_league_exp': '11'}
# {'_id': ObjectId('5da78686c40d54eedfe4bd37'), 'id': 1626153, 'name_last_first': 'Wright, Delon', 'full_name': 'Delon Wright', 'roster_status': 1, 'from_year': '2015', 'to_year': '2019', 'player_code': 'delon_wright', 'team_id': 1610612763, 'team_city': 'Memphis', 'team_name': 'Grizzlies', 'team_abbreviation': 'MEM', 'team_code': 'grizzlies', 'games_played_bool': 'Y', 'other_league_exp': '01'}
# {'_id': ObjectId('5da78686c40d54eedfe4bd44'), 'id': 1627824, 'name_last_first': 'Yabusele, Guerschon', 'full_name': 'Guerschon Yabusele', 'roster_status': 1, 'from_year': '2017', 'to_year': '2018', 'player_code': 'guerschon_yabusele', 'team_id': 1610612738, 'team_city': 'Boston', 'team_name': 'Celtics', 'team_abbreviation': 'BOS', 'team_code': 'celtics', 'games_played_bool': 'Y', 'other_league_exp': '11'}
# {'_id': ObjectId('5da78687c40d54eedfe4bd5a'), 'id': 201152, 'name_last_first': 'Young, Thaddeus', 'full_name': 'Thaddeus Young', 'roster_status': 1, 'from_year': '2007', 'to_year': '2019', 'player_code': 'thaddeus_young', 'team_id': 1610612754, 'team_city': 'Indiana', 'team_name': 'Pacers', 'team_abbreviation': 'IND', 'team_code': 'pacers', 'games_played_bool': 'Y', 'other_league_exp': '00'}
# {'_id': ObjectId('5da78687c40d54eedfe4bd65'), 'id': 1629027, 'name_last_first': 'Young, Trae', 'full_name': 'Trae Young', 'roster_status': 1, 'from_year': '2018', 'to_year': '2019', 'player_code': 'trae_young', 'team_id': 1610612737, 'team_city': 'Atlanta', 'team_name': 'Hawks', 'team_abbreviation': 'ATL', 'team_code': 'hawks', 'games_played_bool': 'Y', 'other_league_exp': '00'}
# {'_id': ObjectId('5da78687c40d54eedfe4bd71'), 'id': 203469, 'name_last_first': 'Zeller, Cody', 'full_name': 'Cody Zeller', 'roster_status': 1, 'from_year': '2013', 'to_year': '2019', 'player_code': 'cody_zeller', 'team_id': 1610612766, 'team_city': 'Charlotte', 'team_name': 'Hornets', 'team_abbreviation': 'CHA', 'team_code': 'hornets', 'games_played_bool': 'Y', 'other_league_exp': '00'}
# {'_id': ObjectId('5da78687c40d54eedfe4bd7c'), 'id': 203092, 'name_last_first': 'Zeller, Tyler', 'full_name': 'Tyler Zeller', 'roster_status': 1, 'from_year': '2012', 'to_year': '2019', 'player_code': 'tyler_zeller', 'team_id': 1610612763, 'team_city': 'Memphis', 'team_name': 'Grizzlies', 'team_abbreviation': 'MEM', 'team_code': 'grizzlies', 'games_played_bool': 'Y', 'other_league_exp': '00'}
# {'_id': ObjectId('5da78687c40d54eedfe4bd92'), 'id': 1627790, 'name_last_first': 'Zizic, Ante', 'full_name': 'Ante Zizic', 'roster_status': 1, 'from_year': '2017', 'to_year': '2019', 'player_code': 'ante_zizic', 'team_id': 1610612739, 'team_city': 'Cleveland', 'team_name': 'Cavaliers', 'team_abbreviation': 'CLE', 'team_code': 'cavaliers', 'games_played_bool': 'Y', 'other_league_exp': '01'}
# {'_id': ObjectId('5da78687c40d54eedfe4bd9d'), 'id': 1627826, 'name_last_first': 'Zubac, Ivica', 'full_name': 'Ivica Zubac', 'roster_status': 1, 'from_year': '2016', 'to_year': '2019', 'player_code': 'ivica_zubac', 'team_id': 1610612746, 'team_city': 'LA', 'team_name': 'Clippers', 'team_abbreviation': 'LAC', 'team_code': 'clippers', 'games_played_bool': 'Y', 'other_league_exp': '01'}
